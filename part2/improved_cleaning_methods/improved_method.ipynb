# %%
# Since we are using Google Colab, we have to first install openclean library.
# !pip install openclean_notebook
# !pip install openclean
# !pip install openclean_geo
# Out:
# Requirement already satisfied: openclean_notebook in /usr/local/lib/python3.7/dist-packages (0.1.7)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from openclean_notebook) (0.16.0)
# Requirement already satisfied: openclean-core>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from openclean_notebook) (0.4.1)
# Requirement already satisfied: jsonschema==3.2.0 in /usr/local/lib/python3.7/dist-packages (from openclean_notebook) (3.2.0)
# Requirement already satisfied: datamart-profiler==0.9 in /usr/local/lib/python3.7/dist-packages (from openclean_notebook) (0.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean_notebook) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean_notebook) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean_notebook) (1.1.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean_notebook) (2019.12.20)
# Requirement already satisfied: datamart-geo==0.2.1 in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean_notebook) (0.2.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean_notebook) (2.8.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean_notebook) (0.12.0)
# Requirement already satisfied: scikit-learn<0.24,>=0.22 in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean_notebook) (0.23.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2.0->openclean_notebook) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2.0->openclean_notebook) (4.8.2)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2.0->openclean_notebook) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2.0->openclean_notebook) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema==3.2.0->openclean_notebook) (21.2.0)
# Requirement already satisfied: refdata>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.4.0->openclean_notebook) (0.2.0)
# Requirement already satisfied: histore>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.4.0->openclean_notebook) (0.4.1)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.4.0->openclean_notebook) (1.4.4)
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.4.0->openclean_notebook) (0.8.9)
# Requirement already satisfied: flowserv-core>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.4.0->openclean_notebook) (0.9.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.4.0->openclean_notebook) (1.4.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.4.0->openclean_notebook) (0.3.4)
# Requirement already satisfied: passlib in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.7.4)
# Requirement already satisfied: paramiko in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (2.8.1)
# Requirement already satisfied: Click in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (7.1.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (5.4.1)
# Requirement already satisfied: pyyaml-include in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.2.post2)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (3.1.24)
# Requirement already satisfied: SQLAlchemy>=1.3.18 in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.4.27)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from histore>=0.4.0->openclean-core>=0.4.0->openclean_notebook) (5.4.8)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datamart-profiler==0.9->openclean_notebook) (2018.9)
# Requirement already satisfied: pooch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (1.5.2)
# Requirement already satisfied: tableprint in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (0.9.1)
# Requirement already satisfied: datasize>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (1.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pooch>=1.3.0->refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24,>=0.22->datamart-profiler==0.9->openclean_notebook) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.24,>=0.22->datamart-profiler==0.9->openclean_notebook) (1.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=1.3.18->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from gitpython->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (3.10.0.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema==3.2.0->openclean_notebook) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pooch>=1.3.0->refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (3.0.6)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.4.0)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (36.0.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (3.2.0)
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (2.21)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->datamart-profiler==0.9->openclean_notebook) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->datamart-profiler==0.9->openclean_notebook) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->datamart-profiler==0.9->openclean_notebook) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->datamart-profiler==0.9->openclean_notebook) (1.24.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from tableprint->refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (0.2.5)
# Requirement already satisfied: openclean in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: openclean-core==0.4.1 in /usr/local/lib/python3.7/dist-packages (from openclean) (0.4.1)
# Requirement already satisfied: flowserv-core>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (0.9.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (2.8.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (0.23.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (0.16.0)
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (0.8.9)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (3.2.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (1.1.5)
# Requirement already satisfied: refdata>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (0.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (2.23.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (0.3.4)
# Requirement already satisfied: histore>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (0.4.1)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean) (1.4.4)
# Requirement already satisfied: paramiko in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (2.8.1)
# Requirement already satisfied: passlib in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.7.4)
# Requirement already satisfied: pyyaml-include in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.2.post2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (5.4.1)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (3.1.24)
# Requirement already satisfied: SQLAlchemy>=1.3.18 in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.4.27)
# Requirement already satisfied: Click in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (7.1.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from histore>=0.4.0->openclean-core==0.4.1->openclean) (5.4.8)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (0.18.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (4.8.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (21.2.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->openclean-core==0.4.1->openclean) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->openclean-core==0.4.1->openclean) (1.19.5)
# Requirement already satisfied: pooch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core==0.4.1->openclean) (1.5.2)
# Requirement already satisfied: tableprint in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core==0.4.1->openclean) (0.9.1)
# Requirement already satisfied: datasize>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core==0.4.1->openclean) (1.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pooch>=1.3.0->refdata>=0.2.0->openclean-core==0.4.1->openclean) (21.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=1.3.18->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from gitpython->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (3.10.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pooch>=1.3.0->refdata>=0.2.0->openclean-core==0.4.1->openclean) (3.0.6)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (36.0.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.4.0)
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (2.21)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean) (2.10)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->openclean-core==0.4.1->openclean) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->openclean-core==0.4.1->openclean) (3.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from tableprint->refdata>=0.2.0->openclean-core==0.4.1->openclean) (0.2.5)
# Requirement already satisfied: openclean_geo in /usr/local/lib/python3.7/dist-packages (0.1.0)
# Requirement already satisfied: Shapely>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from openclean_geo) (1.8.0)
# Requirement already satisfied: openclean-core>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from openclean_geo) (0.4.1)
# Requirement already satisfied: refdata>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (0.2.0)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (1.4.4)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (1.1.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (2.8.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (0.3.4)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (3.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (1.4.1)
# Requirement already satisfied: histore>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (0.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (0.23.2)
# Requirement already satisfied: flowserv-core>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (0.9.2)
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (0.8.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (2.23.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from openclean-core>=0.3.0->openclean_geo) (0.16.0)
# Requirement already satisfied: Click in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (7.1.2)
# Requirement already satisfied: paramiko in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (2.8.1)
# Requirement already satisfied: passlib in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.7.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (5.4.1)
# Requirement already satisfied: pyyaml-include in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.2.post2)
# Requirement already satisfied: SQLAlchemy>=1.3.18 in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.4.27)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (3.1.24)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from histore>=0.4.0->openclean-core>=0.3.0->openclean_geo) (5.4.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core>=0.3.0->openclean_geo) (57.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core>=0.3.0->openclean_geo) (21.2.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core>=0.3.0->openclean_geo) (4.8.2)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core>=0.3.0->openclean_geo) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core>=0.3.0->openclean_geo) (0.18.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->openclean-core>=0.3.0->openclean_geo) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->openclean-core>=0.3.0->openclean_geo) (1.19.5)
# Requirement already satisfied: datasize>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (1.0.0)
# Requirement already satisfied: tableprint in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (0.9.1)
# Requirement already satisfied: pooch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (1.5.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pooch>=1.3.0->refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (21.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=1.3.18->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from gitpython->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (3.10.0.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema>=3.2.0->openclean-core>=0.3.0->openclean_geo) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pooch>=1.3.0->refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (3.0.6)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (36.0.0)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.4.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (3.2.0)
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (2.21)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core>=0.3.0->openclean_geo) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core>=0.3.0->openclean_geo) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core>=0.3.0->openclean_geo) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core>=0.3.0->openclean_geo) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->openclean-core>=0.3.0->openclean_geo) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->openclean-core>=0.3.0->openclean_geo) (1.1.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from tableprint->refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (0.2.5)

# %%
from openclean.pipeline import stream
from pandas import *
import pandas as pd
pd.set_option("max_rows", None)

# Please first mount the drive and make sure that the csvPath points to the correct csv file path.
csvPath = './combine_raw.csv'
# Read the csv.
ds_Full = stream(csvPath)

# %%
# Take a look at the sample data!
ds_Full.to_df()
# Out:
#         origin index          city_name  ...  block   lot community_board
# 0    8fei-z6rz     1              BRONX  ...
# 1    8fei-z6rz     2           BROOKLYN  ...
# 2    bty7-2jhb     1           NEW YORK  ...   1264     5             105
# 3    bty7-2jhb     2             L.I.C.  ...    683     1             502
# 4    bty7-2jhb     3           BROOKLYN  ...   6133    56             310
# 5    bty7-2jhb     4           BROOKLYN  ...   5136    58             317
# 6    bty7-2jhb     5           BROOKLYN  ...   7665     4             314
# 7    bty7-2jhb     6           BROOKLYN  ...   1927     6             303
# 8    bty7-2jhb     7           BROOKLYN  ...   6460   310             311
# 9    bty7-2jhb     8                LIC  ...    741    10             104
# 10   bty7-2jhb     9           BROOKLYN  ...   6832    64             315
# 11   bty7-2jhb    10           BROOKLYN  ...   5519    34             312
# 12   bty7-2jhb    11           BROOKLYN  ...   6861    67             311
# 13   bty7-2jhb    12     ROCKAWAY POINT  ...  16350   400             414
# 14   bty7-2jhb    13                LIC  ...   1518     1             303
# 15   bty7-2jhb    14          MANHATTAN  ...    411  7501             103
# 16   bty7-2jhb    15           BROOKLYN  ...   2913    26             301
# 17   bty7-2jhb    16            JAMAICA  ...    531     3             102
# 18   bty7-2jhb    17           NEW YORK  ...    646    64             307
# 19   bty7-2jhb    18            JAMAICA  ...    531     3             102
# 20   bty7-2jhb    19           BROOKLYN  ...     45    25             302
# 21   bty7-2jhb    20           BROOKLYN  ...   5108    54             317
# 22   bty7-2jhb    21           NEW YORK  ...    857    24             105
# 23   bty7-2jhb    22      STATEN ISLAND  ...   8028    75             503
# 24   bty7-2jhb    23           NEW YORK  ...    857    24             105
# 25   bty7-2jhb    24          MANHATTAN  ...   1147     8             107
# 26   bty7-2jhb    25      NEW HYDE PARK  ...   3969     1             502
# 27   bty7-2jhb    26           BROOKLYN  ...   7239     1             313
# 28   bty7-2jhb    27           NEW YORK  ...    857    24             105
# 29   bty7-2jhb    28                LIC  ...   3247    70             207
# 30   bty7-2jhb    29           NEW YORK  ...    883    14             105
# 31   bty7-2jhb    30           BROOKLYN  ...    439    26             103
# 32   bty7-2jhb    31             L.I.C.  ...   3188    14             205
# 33   bty7-2jhb    32                LIC  ...   3247    70             207
# 34   bty7-2jhb    33       FAR ROCKAWAY  ...  15722    41             414
# 35   bty7-2jhb    34           BROOKLYN  ...    166    51             302
# 36   bty7-2jhb    35           BROOKLYN  ...    166    51             302
# 37   bty7-2jhb    36           BROOKLYN  ...   7962    85             318
# 38   bty7-2jhb    37           NEW YORK  ...   1338    30             106
# 39   bty7-2jhb    38           BROOKLYN  ...    166    51             302
# 40   bty7-2jhb    39           BROOKLYN  ...    166    51             302
# 41   bty7-2jhb    40           BROOKLYN  ...   4168    22             305
# 42   bty7-2jhb    41           NEW YORK  ...   1329     1             106
# 43   bty7-2jhb    42           NEW YORK  ...    803  7502             105
# 44   bty7-2jhb    43           NEW YORK  ...   1819   203             111
# 45   bty7-2jhb    44           BROOKLYN  ...   6603     2             311
# 46   bty7-2jhb    45           NEW YORK  ...   1409    40             108
# 47   bty7-2jhb    46           NEW YORK  ...   1051  7502             104
# 48   bty7-2jhb    47                 NY  ...    555     1             102
# 49   bty7-2jhb    48           NEW YORK  ...   1889    40             107
# 50   bty7-2jhb    49           NEW YORK  ...   1462     5             108
# 51   bty7-2jhb    50           BROOKLYN  ...   8244     1             318
# 52   bty7-2jhb    51           NEW YORK  ...   1269    41             105
# 53   bty7-2jhb    52           BROOKLYN  ...    255    25             302
# 54   bty7-2jhb    53        JERSEY CITY  ...     16   260             101
# 55   bty7-2jhb    54           NEW YORK  ...   1320    46             106
# 56   bty7-2jhb    55           NEW YORK  ...   1094    18             104
# 57   bty7-2jhb    56             L.I.C.  ...   3247   170             207
# 58   bty7-2jhb    57           BROOKLYN  ...   5677    15             312
# 59   bty7-2jhb    58              BRONX  ...   4941    30             212
# 60   bty7-2jhb    59             LIC NY  ...   2306    54             201
# 61   bty7-2jhb    60             ROSLYN  ...   1798    77             303
# 62   bty7-2jhb    61              BRONX  ...   2335    16             201
# 63   bty7-2jhb    62          LAS VEGAS  ...   1326    22             106
# 64   bty7-2jhb    63           NEW YORK  ...   3342     1             304
# 65   bty7-2jhb    64           NEW YORK  ...   3342     1             304
# 66   bty7-2jhb    65          MANHATTAN  ...   1147   111             107
# 67   bty7-2jhb    66              BRONX  ...   3385     1             212
# 68   bty7-2jhb    67           NEW YORK  ...    860    49             105
# 69   bty7-2jhb    68             ROSLYN  ...   1802    51             303
# 70   bty7-2jhb    69           NEW YORK  ...   3342     1             304
# 71   bty7-2jhb    70           NEW YORK  ...   1114  7502             107
# 72   bty7-2jhb    71              BRONX  ...   5020    76             212
# 73   bty7-2jhb    72           NEW YORK  ...   3351     1             304
# 74   bty7-2jhb    73             ROSLYN  ...   1798    20             303
# 75   bty7-2jhb    74           BROOKLYN  ...   4074    36             305
# 76   bty7-2jhb    75           BROOKLYN  ...    784    12             105
# 77   bty7-2jhb    76          NEW  YORK  ...   1266     1             105
# 78   bty7-2jhb    77           BROOKLYN  ...   7104   202             315
# 79   bty7-2jhb    78           BROOKLYN  ...   8221    61             318
# 80   bty7-2jhb    79              BRONX  ...   4988    66             212
# 81   bty7-2jhb    80           BROOKLYN  ...   3170    41             304
# 82   bty7-2jhb    81           NEW YORK  ...   1167  7501             107
# 83   bty7-2jhb    82                 NY  ...   1010    61             105
# 84   bty7-2jhb    83           NEW YORK  ...    569     5             102
# 85   bty7-2jhb    84           BROOKLYN  ...   2747     3             301
# 86   bty7-2jhb    85           NEW YORK  ...   1185     1             107
# 87   bty7-2jhb    86           BROOKLYN  ...   8771   119             315
# 88   bty7-2jhb    87                 BK  ...   1108     3             307
# 89   bty7-2jhb    88              BRONX  ...   3510   158             209
# 90   bty7-2jhb    89           NEW YORK  ...   1061  7502             104
# 91   bty7-2jhb    90           NEW YORK  ...   2215    42             208
# 92   bty7-2jhb    91           NEW YORK  ...   1289    72             105
# 93   bty7-2jhb    92           BROOKLYN  ...    395    30             302
# 94   bty7-2jhb    93           NEW YORK  ...   1137  7501             107
# 95   bty7-2jhb    94    LONG ISLAND CIT  ...    524    66             102
# 96   bty7-2jhb    95                 BK  ...   1508     1             303
# 97   bty7-2jhb    96           BROOKLYN  ...     35  7501             302
# 98   bty7-2jhb    97           BROOKLYN  ...   2171     1             112
# 99   bty7-2jhb    98           BROOKLYN  ...   1596    14             303
# 100  bty7-2jhb    99           NEW YORK  ...    713     1             104
# 101  bty7-2jhb   100           NEW YORK  ...   1493  7504             108
# 102  bty7-2jhb   101           SECAUCUS  ...   1375    49             108
# 103  bty7-2jhb   102           BROOKLYN  ...   1508     1             303
# 104  bty7-2jhb   103           BROOKLYN  ...   3554   125             316
# 105  bty7-2jhb   104           BROOKLYN  ...    789    44             105
# 106  bty7-2jhb   105           NEW YORK  ...    573    43             102
# 107  bty7-2jhb   106           NEW YORK  ...   1381     1             108
# 108  bty7-2jhb   107           NEW YORK  ...   1501    40             108
# 109  bty7-2jhb   108             QUEENS  ...   1701    76             403
# 110  bty7-2jhb   109           NEW YORK  ...   1449    20             108
# 111  bty7-2jhb   110           NEW YORK  ...   1449    20             108
# 112  bty7-2jhb   111           NEW YORK  ...   1158  7504             107
# 113  bty7-2jhb   112           NEW YORK  ...    208    19             102
# 114  bty7-2jhb   113           NEW YORK  ...   2222     7             112
# 115  dm9a-ab7w     1      RICHMOND HILL  ...   7203    14             315
# 116  dm9a-ab7w     2   LONG ISLAND CITY  ...   8666   610             313
# 117  dm9a-ab7w     3           BROOKLYN  ...   2742    15             301
# 118  dm9a-ab7w     4      RICHMOND HILL  ...    461    58             306
# 119  dm9a-ab7w     5           BROOKLYN  ...   2249    37             301
# 120  dm9a-ab7w     6      STATEN ISLAND  ...   5509    36             312
# 121  dm9a-ab7w     7           BROOKLYN  ...   3439    51             304
# 122  dm9a-ab7w     8           BROOKLYN  ...   3439    51             304
# 123  dm9a-ab7w     9           FLUSHING  ...   1122    45             308
# 124  dm9a-ab7w    10           FLUSHING  ...   5530    50             311
# 125  dm9a-ab7w    11         OZONE PARK  ...   2075    28             302
# 126  dm9a-ab7w    12              BRONX  ...   5772    34             310
# 127  ipu4-2q9a     1           NEW YORK  ...   1264     5             105
# 128  ipu4-2q9a     2             L.I.C.  ...    683     1             502
# 129  ipu4-2q9a     3           BROOKLYN  ...   6133    56             310
# 130  ipu4-2q9a     4           BROOKLYN  ...   5136    58             317
# 131  ipu4-2q9a     5           BROOKLYN  ...   7665     4             314
# 132  ipu4-2q9a     6           BROOKLYN  ...   1927     6             303
# 133  ipu4-2q9a     7           BROOKLYN  ...   6460   310             311
# 134  ipu4-2q9a     8                LIC  ...    741    10             104
# 135  ipu4-2q9a     9           BROOKLYN  ...   6832    64             315
# 136  ipu4-2q9a    10           BROOKLYN  ...   5519    34             312
# 137  ipu4-2q9a    11           BROOKLYN  ...   6861    67             311
# 138  ipu4-2q9a    12     ROCKAWAY POINT  ...  16350   400             414
# 139  ipu4-2q9a    13                LIC  ...   1518     1             303
# 140  ipu4-2q9a    14          MANHATTAN  ...    411  7501             103
# 141  ipu4-2q9a    15           BROOKLYN  ...   2913    26             301
# 142  ipu4-2q9a    16            JAMAICA  ...    531     3             102
# 143  ipu4-2q9a    17           NEW YORK  ...    646    64             307
# 144  ipu4-2q9a    18            JAMAICA  ...    531     3             102
# 145  ipu4-2q9a    19           BROOKLYN  ...     45    25             302
# 146  ipu4-2q9a    20           BROOKLYN  ...   5108    54             317
# 147  ipu4-2q9a    21           NEW YORK  ...    857    24             105
# 148  ipu4-2q9a    22      STATEN ISLAND  ...   8028    75             503
# 149  ipu4-2q9a    23           NEW YORK  ...    857    24             105
# 150  ipu4-2q9a    24          MANHATTAN  ...   1147     8             107
# 151  ipu4-2q9a    25      NEW HYDE PARK  ...   3969     1             502
# 152  ipu4-2q9a    26           BROOKLYN  ...   7239     1             313
# 153  ipu4-2q9a    27           NEW YORK  ...    857    24             105
# 154  ipu4-2q9a    28                LIC  ...   3247    70             207
# 155  ipu4-2q9a    29           NEW YORK  ...    883    14             105
# 156  ipu4-2q9a    30           BROOKLYN  ...    439    26             103
# 157  ipu4-2q9a    31             L.I.C.  ...   3188    14             205
# 158  ipu4-2q9a    32                LIC  ...   3247    70             207
# 159  ipu4-2q9a    33       FAR ROCKAWAY  ...  15722    41             414
# 160  ipu4-2q9a    34           BROOKLYN  ...    166    51             302
# 161  ipu4-2q9a    35           BROOKLYN  ...    166    51             302
# 162  ipu4-2q9a    36           BROOKLYN  ...   7962    85             318
# 163  ipu4-2q9a    37           NEW YORK  ...   1338    30             106
# 164  ipu4-2q9a    38           BROOKLYN  ...    166    51             302
# 165  ipu4-2q9a    39           BROOKLYN  ...    166    51             302
# 166  ipu4-2q9a    40           BROOKLYN  ...   4168    22             305
# 167  ipu4-2q9a    41           NEW YORK  ...   1329     1             106
# 168  ipu4-2q9a    42           NEW YORK  ...    803  7502             105
# 169  ipu4-2q9a    43           NEW YORK  ...   1819   203             111
# 170  ipu4-2q9a    44           BROOKLYN  ...   6603     2             311
# 171  ipu4-2q9a    45           NEW YORK  ...   1409    40             108
# 172  ipu4-2q9a    46           NEW YORK  ...   1051  7502             104
# 173  ipu4-2q9a    47                 NY  ...    555     1             102
# 174  ipu4-2q9a    48           NEW YORK  ...   1889    40             107
# 175  ipu4-2q9a    49           NEW YORK  ...   1462     5             108
# 176  ipu4-2q9a    50           BROOKLYN  ...   8244     1             318
# 177  ipu4-2q9a    51           NEW YORK  ...   1269    41             105
# 178  ipu4-2q9a    52           BROOKLYN  ...    255    25             302
# 179  ipu4-2q9a    53        JERSEY CITY  ...     16   260             101
# 180  ipu4-2q9a    54           NEW YORK  ...   1320    46             106
# 181  ipu4-2q9a    55           NEW YORK  ...   1094    18             104
# 182  ipu4-2q9a    56             L.I.C.  ...   3247   170             207
# 183  ipu4-2q9a    57           BROOKLYN  ...   5677    15             312
# 184  ipu4-2q9a    58              BRONX  ...   4941    30             212
# 185  ipu4-2q9a    59             LIC NY  ...   2306    54             201
# 186  ipu4-2q9a    60             ROSLYN  ...   1798    77             303
# 187  ipu4-2q9a    61              BRONX  ...   2335    16             201
# 188  ipu4-2q9a    62          LAS VEGAS  ...   1326    22             106
# 189  ipu4-2q9a    63           NEW YORK  ...   3342     1             304
# 190  ipu4-2q9a    64           NEW YORK  ...   3342     1             304
# 191  ipu4-2q9a    65          MANHATTAN  ...   1147   111             107
# 192  ipu4-2q9a    66              BRONX  ...   3385     1             212
# 193  ipu4-2q9a    67           NEW YORK  ...    860    49             105
# 194  ipu4-2q9a    68             ROSLYN  ...   1802    51             303
# 195  ipu4-2q9a    69           NEW YORK  ...   3342     1             304
# 196  ipu4-2q9a    70           NEW YORK  ...   1114  7502             107
# 197  ipu4-2q9a    71              BRONX  ...   5020    76             212
# 198  ipu4-2q9a    72           NEW YORK  ...   3351     1             304
# 199  ipu4-2q9a    73             ROSLYN  ...   1798    20             303
# 200  ipu4-2q9a    74           BROOKLYN  ...   4074    36             305
# 201  ipu4-2q9a    75           BROOKLYN  ...    784    12             105
# 202  ipu4-2q9a    76          NEW  YORK  ...   1266     1             105
# 203  ipu4-2q9a    77           BROOKLYN  ...   7104   202             315
# 204  ipu4-2q9a    78           BROOKLYN  ...   8221    61             318
# 205  ipu4-2q9a    79              BRONX  ...   4988    66             212
# 206  ipu4-2q9a    80           BROOKLYN  ...   3170    41             304
# 207  ipu4-2q9a    81           NEW YORK  ...   1167  7501             107
# 208  ipu4-2q9a    82           NEW YORK  ...   1010    61             105
# 209  ipu4-2q9a    83           NEW YORK  ...    569     5             102
# 210  ipu4-2q9a    84           BROOKLYN  ...   2747     3             301
# 211  ipu4-2q9a    85           NEW YORK  ...   1185     1             107
# 212  ipu4-2q9a    86           BROOKLYN  ...   8771   119             315
# 213  ipu4-2q9a    87                 BK  ...   1108     3             307
# 214  ipu4-2q9a    88              BRONX  ...   3510   158             209
# 215  ipu4-2q9a    89           NEW YORK  ...   1061  7502             104
# 216  ipu4-2q9a    90           NEW YORK  ...   2215    42             208
# 217  ipu4-2q9a    91           NEW YORK  ...   1289    72             105
# 218  ipu4-2q9a    92           BROOKLYN  ...    395    30             302
# 219  ipu4-2q9a    93           NEW YORK  ...   1137  7501             107
# 220  ipu4-2q9a    94    LONG ISLAND CIT  ...    524    66             102
# 221  ipu4-2q9a    95                 BK  ...   1508     1             303
# 222  ipu4-2q9a    96           BROOKLYN  ...     35  7501             302
# 223  ipu4-2q9a    97           BROOKLYN  ...   2171     1             112
# 224  ipu4-2q9a    98           BROOKLYN  ...   1596    14             303
# 225  ipu4-2q9a    99           NEW YORK  ...    713     1             104
# 226  ipu4-2q9a   100           NEW YORK  ...   1493  7504             108
# 227  ipu4-2q9a    10           SECAUCUS  ...   1375    49             108
# 228  ipu4-2q9a   101           BROOKLYN  ...   1508     1             303
# 229  ipu4-2q9a   102           BROOKLYN  ...   3554   125             316
# 230  ipu4-2q9a   103           BROOKLYN  ...    789    44             105
# 231  ipu4-2q9a   104           NEW YORK  ...    573    43             102
# 232  ipu4-2q9a   105           NEW YORK  ...   1381     1             108
# 233  ipu4-2q9a   106           NEW YORK  ...   1501    40             108
# 234  ipu4-2q9a   107             QUEENS  ...   1701    76             403
# 235  ipu4-2q9a   108           NEW YORK  ...   1449    20             108
# 236  ipu4-2q9a   109           NEW YORK  ...   1449    20             108
# 237  ipu4-2q9a   110           NEW YORK  ...   1158  7504             107
# 238  ipu4-2q9a   111           NEW YORK  ...    208    19             102
# 239  ipu4-2q9a   112           NEW YORK  ...   2222     7             112
# 240  ipu4-2q9a   113           BROOKLYN  ...   7024    71             313
# 241  ipu4-2q9a   114           BROOKLYN  ...   5111    46             317
# 242  ipu4-2q9a   115           NEW YORK  ...   2108    27             112
# 243  ipu4-2q9a   116           NEW YORK  ...   3110    26             206
# 244  ipu4-2q9a   117           NEW YORK  ...   1514     8             108
# 245  ipu4-2q9a   118           NEW YORK  ...   3110    26             206
# 246  ipu4-2q9a   119           NEW YORK  ...    594     8             102
# 247  ipu4-2q9a   120           NEW YORK  ...    930     1             106
# 248  ipu4-2q9a   121           NEW YORK  ...   1701     1             111
# 249  ipu4-2q9a   122           NEW YORK  ...   1701     1             111
# 250  ipu4-2q9a   123           BROOKLYN  ...   1673    45             303
# 251  ipu4-2q9a   124           NEW YORK  ...     68  7502             101
# 252  ipu4-2q9a   125           BROOKLYN  ...   4948     7             317
# 253  ipu4-2q9a   126           NEW YORK  ...     93     1             101
# 254  ipu4-2q9a   127           NEW YORK  ...   3110    26             206
# 255  ipu4-2q9a   128           BROOKLYN  ...   7024    71             313
# 256  ipu4-2q9a   129           NEW YORK  ...    870  7501             105
# 257  ipu4-2q9a   131             QUEENS  ...  11766     1             410
# 258  ipu4-2q9a   132           BROOKLYN  ...   4773    58             317
# 259  ipu4-2q9a   133           BROOKLYN  ...   6082    32             310
# 260  ipu4-2q9a   134           NEW YORK  ...   1513    20             108
# 261  ipu4-2q9a   135           NEW YORK  ...   2061    60             302
# 262  ipu4-2q9a   136             QUEENS  ...   3029    61             206
# 263  ipu4-2q9a   137             L.I.C.  ...    652    35             401
# 264  ipu4-2q9a   138           NEW YORK  ...   1808     1             111
# 265  ipu4-2q9a   139             QUEENS  ...  10863    47             412
# 266  ipu4-2q9a   140      STATEN ISLAND  ...   6319    60             311
# 267  ipu4-2q9a   141           NEW YORK  ...   1290    52             105
# 268  ipu4-2q9a   142      STATEN ISLAND  ...   6319    60             311
# 269  ipu4-2q9a   143              BRONX  ...   2447     1             204
# 270  ipu4-2q9a   144           NEW YORK  ...    591     1             306
# 271  ipu4-2q9a   145           BROOKLYN  ...   6831    21             315
# 272  ipu4-2q9a   146            KATONAH  ...   2134  7503             301
# 273  ipu4-2q9a   147             QUEENS  ...  13055    69             412
# 274  ipu4-2q9a   148           NEW YORK  ...   1290    52             105
# 275  ipu4-2q9a   149             ROSLYN  ...   1799    44             303
# 276  ipu4-2q9a   150     ROSLYN HEIGHTS  ...   3966     8             210
# 277  ipu4-2q9a   151    LONG ISLAND CIT  ...    778    18             105
# 278  ipu4-2q9a   152           BROOKLYN  ...   1208    34             308
# 279  ipu4-2q9a   153          MANHATTAN  ...     16  7507             101
# 280  ipu4-2q9a   154           NEW YORK  ...    764    10             104
# 281  ipu4-2q9a   155             L.I.C.  ...   2128    14             406
# 282  ipu4-2q9a   156           NEW YORK  ...    764    10             104
# 283  ipu4-2q9a   157    ENGLEWOOD CLIFF  ...   1909    33             110
# 284  ipu4-2q9a   158           NEW YORK  ...    529     1             102
# 285  ipu4-2q9a   159           NEW YORK  ...  14228   771             410
# 286  ipu4-2q9a   160           BROOKLYN  ...   8537    67             318
# 287  ipu4-2q9a   161           NEW YORK  ...    701    24             104
# 288  ipu4-2q9a   162           BROOKLYN  ...    914    59             106
# 289  ipu4-2q9a   163           NEW YORK  ...   1134     1             107
# 290  ipu4-2q9a   164           NEW YORK  ...  14243  1219             410
# 291  ipu4-2q9a   165           BROOKLYN  ...    438    27             103
# 292  ipu4-2q9a   166           NEW YORK  ...   5149     1             314
# 293  ipu4-2q9a   167      STATEN ISLAND  ...    626    43             501
# 294  ipu4-2q9a   168           NEW YORK  ...   3315     1             304
# 295  ipu4-2q9a   169           NEW YORK  ...   2138    40             112
# 296  ipu4-2q9a   170      STATEN ISLAND  ...   3581    11             502
# 297  ipu4-2q9a   171             ROSLYN  ...   1804    10             303
# 298  ipu4-2q9a   172           BROOKLYN  ...   6011    35             310
# 299  ipu4-2q9a   173           NEW YORK  ...  15456    15             414
# 300  ipu4-2q9a   174           BROOKLYN  ...   5661    56             312
# 301  iz2q-9x8d     1           BROOKLYN  ...    271    47             302
# 302  kfp4-dz4h     1  LONG ISLAND CITY,  ...   2414     2
# 303  kfp4-dz4h     2           NEW YORK  ...    430    40
# 304  kfp4-dz4h     3              BRONX  ...    537  7502
# 305  kyvb-rbwd     1           FLUSHING  ...   6682    52
# 306  kyvb-rbwd     2           BROOKLYN  ...   6260    19
# 307  kyvb-rbwd     3            JAMAICA  ...   9393     6
# 308  kyvb-rbwd     4           BROOKLYN  ...   6035     6
# 309  kyvb-rbwd     5              BRONX  ...   3965    18
# 310  kyvb-rbwd     6           FLUSHING  ...   6682    54
# 311  kyvb-rbwd     7           BROOKLYN  ...   4659    12
# 312  kyvb-rbwd     8           BROOKLYN  ...   6647    72
# 313  kyvb-rbwd     9           BROOKLYN  ...   6647    71
# 314  kyvb-rbwd    10      STATEN ISLAND  ...   5491   282
# 315  kyvb-rbwd    11      STATEN ISLAND  ...   5680   212
# 316  kyvb-rbwd    12           BROOKLYN  ...    422   143
# 317  kyvb-rbwd    13           BROOKLYN  ...    767    32
# 318  kyvb-rbwd    14           NEW YORK  ...   1008    15
# 319  kyvb-rbwd    15   LONG ISLAND CITY  ...    692    15
# 320  kyvb-rbwd    16              BRONX  ...   3608    69
# 321  kyvb-rbwd    17              BRONX  ...   4295    23
# 322  nyis-y4yr     1           BROOKLYN  ...   5665    14             312
# 323  nyis-y4yr     2             QUEENS  ...   1861    10             404
# 324  nyis-y4yr     3           NEW YORK  ...     63    16             101
# 325  nyis-y4yr     4           BROOKLYN  ...    299    22             402
# 326  nyis-y4yr     5           NEW YORK  ...    810    40             105
# 327  nyis-y4yr     6           NEW YORK  ...    442    18             402
# 328  nyis-y4yr     7           NEW YORK  ...    785     1             105
# 329  nyis-y4yr     8           NEW YORK  ...    687    29             104
# 330  nyis-y4yr     9           GLENDALE  ...   3810   350             405
# 331  nyis-y4yr    10           NEW YORK  ...    687    29             104
# 332  nyis-y4yr    11           BROOKLYN  ...    679     1             307
# 333  nyis-y4yr    12       CORAL GABLES  ...   4357   100             407
# 334  nyis-y4yr    13           NEW YORK  ...   1381  7502             108
# 335  nyis-y4yr    14           GLENDALE  ...   3810   350             405
# 336  nyis-y4yr    15           NEW YORK  ...   1301    23             106
# 337  nyis-y4yr    16                LIC  ...   4363   100             407
# 338  nyis-y4yr    17       CORAL GABLES  ...   4357   100             407
# 339  nyis-y4yr    18      STATEN ISLAND  ...   2400   180             502
# 340  nyis-y4yr    19           NEW YORK  ...   2443    90             204
# 341  nyis-y4yr    20           BROOKLYN  ...   1164     6             308
# 342  nyis-y4yr    21           NEW YORK  ...    687    29             104
# 343  nyis-y4yr    22           NEW YORK  ...    687    29             104
# 344  nyis-y4yr    23      STATEN ISLAND  ...   7580    21             503
# 345  nyis-y4yr    24           BROOKLYN  ...   2550    19             201
# 346  nyis-y4yr    25           NEW YORK  ...   1301    23             106
# 347  nyis-y4yr    26             QUEENS  ...  11679     9             410
# 348  nyis-y4yr    27           GLENDALE  ...   3810   350             405
# 349  nyis-y4yr    28           GLENDALE  ...   3810   350             405
# 350  nyis-y4yr    29           BROOKLYN  ...   4124    52             305
# 351  nyis-y4yr    30           NEW YORK  ...    687    29             104
# 352  nyis-y4yr    31           NEW YORK  ...    442    18             402
# 353  nyis-y4yr    32           BROOKLYN  ...   2550    19             201
# 354  nyis-y4yr    33            HOUSTON  ...    836     7             105
# 355  nyis-y4yr    34           NEW YORK  ...    812    68             105
# 356  nyis-y4yr    35          WOODHAVEN  ...   8914    21             409
# 357  nyis-y4yr    36           BROOKLYN  ...   2643    27             301
# 358  nyis-y4yr    37           GLENDALE  ...   3810   350             405
# 359  nyis-y4yr    38           NEW YORK  ...   1472    47             108
# 360  nyis-y4yr    39         DOUGLASTON  ...   8111   110             411
# 361  nyis-y4yr    40                LIC  ...   4363   100             407
# 362  nyis-y4yr    41           NEW YORK  ...    687    29             104
# 363  nyis-y4yr    42           NEW YORK  ...    442    18             402
# 364  nyis-y4yr    43             VASHON  ...   4318    20             211
# 365  nyis-y4yr    44           NEW YORK  ...  14030     6             410
# 366  nyis-y4yr    45           NEW YORK  ...   5755    41             208
# 367  nyis-y4yr    46           GLENDALE  ...   3810   350             405
# 368  nyis-y4yr    47          WOODHAVEN  ...   8914    21             409
# 369  nyis-y4yr    48       CORAL GABLES  ...   4357   100             407
# 370  nyis-y4yr    49           GLENDALE  ...   3810   350             405
# 371  nyis-y4yr    50                LIC  ...   4363   100             407
# 372  nyis-y4yr    51           NEW YORK  ...    687    29             104
# 373  nyis-y4yr    52      STATEN ISLAND  ...   7584   150             503
# 374  nyis-y4yr    53          HAWTHORNE  ...   9761     1             412
# 375  nyis-y4yr    54             VASHON  ...   4318    20             211
# 376  nyis-y4yr    55           NEW YORK  ...    442    18             402
# 377  nyis-y4yr    56       CORAL GABLES  ...   4357   100             407
# 378  nyis-y4yr    57          HAWTHORNE  ...   9761     1             412
# 379  nyis-y4yr    58           NEW YORK  ...    687    29             104
# 380  nyis-y4yr    59           BROOKLYN  ...    426    41             306
# 381  nyis-y4yr    60           NEW YORK  ...   1381  7502             108
# 382  nyis-y4yr    61             QUEENS  ...  11679     9             410
# 383  nyis-y4yr    62           NEW YORK  ...    687    29             104
# 384  nyis-y4yr    63             QUEENS  ...  11679     9             410
# 385  nyis-y4yr    64           BROOKLYN  ...   5052    27             314
# 386  nyis-y4yr    65           NEW YORK  ...    823  7507             105
# 387  nyis-y4yr    66           NEW YORK  ...   2163    53             112
# 388  nyis-y4yr    67           NEW YORK  ...   1317     1             106
# 389  nyis-y4yr    68         MONROE TWP  ...   2916    30             405
# 390  uxsz-6j5j     1           Brooklyn  ...                   9 BROOKLYN
# 391  w9ak-ipjd     1           NEW YORK  ...   1264     5             105
# 392  w9ak-ipjd     2             L.I.C.  ...    683     1             502
# 393  w9ak-ipjd     3           BROOKLYN  ...   6133    56             310
# 394  w9ak-ipjd     4           BROOKLYN  ...   5136    58             317
# 395  w9ak-ipjd     5           BROOKLYN  ...   7665     4             314
# 396  w9ak-ipjd     6           BROOKLYN  ...   1927     6             303
# 397  w9ak-ipjd     7           BROOKLYN  ...   6460   310             311
# 398  w9ak-ipjd     8                LIC  ...    741    10             104
# 399  w9ak-ipjd     9           BROOKLYN  ...   6832    64             315
# 400  w9ak-ipjd    10           BROOKLYN  ...   5519    34             312
# 401  w9ak-ipjd    11           BROOKLYN  ...   6861    67             311
# 402  w9ak-ipjd    12     ROCKAWAY POINT  ...  16350   400             414
#
# [403 rows x 7 columns]

# %% [markdown]
# #Updated Street Name Fixing
# This part demonstrate the refined street name fixing strategy.
# The problem of redundant period and comma is resolved, which contributes to the improvement of ***Precision*** from 0.xx to 0.yy. Also, the ***Recall*** improves from 0.xx to 0.yy after this modification.

# %%
# Get the clusters of the street names.
from openclean.cluster.key import key_collision
streets = ds_Full.to_df()['street_name'].to_list()
clusters = key_collision(values=streets, minsize=1, threads=4)
# Store the cluster result into a dictionary for further usage.
clusterLookUp = {}
for cluster in clusters:
  standard = cluster.suggestion()
  for sName, _count in cluster.items():
    clusterLookUp[sName] = standard

# %%
# Define the fixing function for street names.
def preCleanStreetName(s):
  # Changing the same street names with different appearances into the same name.
  try:
    s = clusterLookUp[s]
  except: 
    pass
  # Removing "." and "," in so that the following step won't retain them.
  try:
    s = s.replace('.', ' ')
    s = s.replace(',', ' ')
  except:
    pass
  return s

ds_Update = ds_Full.update(columns='street_name', func=preCleanStreetName)

# Call the built-in standardizing func of Openclean to finish the job.
from openclean_geo.address.usstreet import StandardizeUSStreetName
ds_Update = ds_Update.update(columns="street_name", func=StandardizeUSStreetName(characters='upper'))

# %%
ds_Update.to_df()
# Out:
#         origin index          city_name  ...  block   lot community_board
# 0    8fei-z6rz     1              BRONX  ...
# 1    8fei-z6rz     2           BROOKLYN  ...
# 2    bty7-2jhb     1           NEW YORK  ...   1264     5             105
# 3    bty7-2jhb     2             L.I.C.  ...    683     1             502
# 4    bty7-2jhb     3           BROOKLYN  ...   6133    56             310
# 5    bty7-2jhb     4           BROOKLYN  ...   5136    58             317
# 6    bty7-2jhb     5           BROOKLYN  ...   7665     4             314
# 7    bty7-2jhb     6           BROOKLYN  ...   1927     6             303
# 8    bty7-2jhb     7           BROOKLYN  ...   6460   310             311
# 9    bty7-2jhb     8                LIC  ...    741    10             104
# 10   bty7-2jhb     9           BROOKLYN  ...   6832    64             315
# 11   bty7-2jhb    10           BROOKLYN  ...   5519    34             312
# 12   bty7-2jhb    11           BROOKLYN  ...   6861    67             311
# 13   bty7-2jhb    12     ROCKAWAY POINT  ...  16350   400             414
# 14   bty7-2jhb    13                LIC  ...   1518     1             303
# 15   bty7-2jhb    14          MANHATTAN  ...    411  7501             103
# 16   bty7-2jhb    15           BROOKLYN  ...   2913    26             301
# 17   bty7-2jhb    16            JAMAICA  ...    531     3             102
# 18   bty7-2jhb    17           NEW YORK  ...    646    64             307
# 19   bty7-2jhb    18            JAMAICA  ...    531     3             102
# 20   bty7-2jhb    19           BROOKLYN  ...     45    25             302
# 21   bty7-2jhb    20           BROOKLYN  ...   5108    54             317
# 22   bty7-2jhb    21           NEW YORK  ...    857    24             105
# 23   bty7-2jhb    22      STATEN ISLAND  ...   8028    75             503
# 24   bty7-2jhb    23           NEW YORK  ...    857    24             105
# 25   bty7-2jhb    24          MANHATTAN  ...   1147     8             107
# 26   bty7-2jhb    25      NEW HYDE PARK  ...   3969     1             502
# 27   bty7-2jhb    26           BROOKLYN  ...   7239     1             313
# 28   bty7-2jhb    27           NEW YORK  ...    857    24             105
# 29   bty7-2jhb    28                LIC  ...   3247    70             207
# 30   bty7-2jhb    29           NEW YORK  ...    883    14             105
# 31   bty7-2jhb    30           BROOKLYN  ...    439    26             103
# 32   bty7-2jhb    31             L.I.C.  ...   3188    14             205
# 33   bty7-2jhb    32                LIC  ...   3247    70             207
# 34   bty7-2jhb    33       FAR ROCKAWAY  ...  15722    41             414
# 35   bty7-2jhb    34           BROOKLYN  ...    166    51             302
# 36   bty7-2jhb    35           BROOKLYN  ...    166    51             302
# 37   bty7-2jhb    36           BROOKLYN  ...   7962    85             318
# 38   bty7-2jhb    37           NEW YORK  ...   1338    30             106
# 39   bty7-2jhb    38           BROOKLYN  ...    166    51             302
# 40   bty7-2jhb    39           BROOKLYN  ...    166    51             302
# 41   bty7-2jhb    40           BROOKLYN  ...   4168    22             305
# 42   bty7-2jhb    41           NEW YORK  ...   1329     1             106
# 43   bty7-2jhb    42           NEW YORK  ...    803  7502             105
# 44   bty7-2jhb    43           NEW YORK  ...   1819   203             111
# 45   bty7-2jhb    44           BROOKLYN  ...   6603     2             311
# 46   bty7-2jhb    45           NEW YORK  ...   1409    40             108
# 47   bty7-2jhb    46           NEW YORK  ...   1051  7502             104
# 48   bty7-2jhb    47                 NY  ...    555     1             102
# 49   bty7-2jhb    48           NEW YORK  ...   1889    40             107
# 50   bty7-2jhb    49           NEW YORK  ...   1462     5             108
# 51   bty7-2jhb    50           BROOKLYN  ...   8244     1             318
# 52   bty7-2jhb    51           NEW YORK  ...   1269    41             105
# 53   bty7-2jhb    52           BROOKLYN  ...    255    25             302
# 54   bty7-2jhb    53        JERSEY CITY  ...     16   260             101
# 55   bty7-2jhb    54           NEW YORK  ...   1320    46             106
# 56   bty7-2jhb    55           NEW YORK  ...   1094    18             104
# 57   bty7-2jhb    56             L.I.C.  ...   3247   170             207
# 58   bty7-2jhb    57           BROOKLYN  ...   5677    15             312
# 59   bty7-2jhb    58              BRONX  ...   4941    30             212
# 60   bty7-2jhb    59             LIC NY  ...   2306    54             201
# 61   bty7-2jhb    60             ROSLYN  ...   1798    77             303
# 62   bty7-2jhb    61              BRONX  ...   2335    16             201
# 63   bty7-2jhb    62          LAS VEGAS  ...   1326    22             106
# 64   bty7-2jhb    63           NEW YORK  ...   3342     1             304
# 65   bty7-2jhb    64           NEW YORK  ...   3342     1             304
# 66   bty7-2jhb    65          MANHATTAN  ...   1147   111             107
# 67   bty7-2jhb    66              BRONX  ...   3385     1             212
# 68   bty7-2jhb    67           NEW YORK  ...    860    49             105
# 69   bty7-2jhb    68             ROSLYN  ...   1802    51             303
# 70   bty7-2jhb    69           NEW YORK  ...   3342     1             304
# 71   bty7-2jhb    70           NEW YORK  ...   1114  7502             107
# 72   bty7-2jhb    71              BRONX  ...   5020    76             212
# 73   bty7-2jhb    72           NEW YORK  ...   3351     1             304
# 74   bty7-2jhb    73             ROSLYN  ...   1798    20             303
# 75   bty7-2jhb    74           BROOKLYN  ...   4074    36             305
# 76   bty7-2jhb    75           BROOKLYN  ...    784    12             105
# 77   bty7-2jhb    76          NEW  YORK  ...   1266     1             105
# 78   bty7-2jhb    77           BROOKLYN  ...   7104   202             315
# 79   bty7-2jhb    78           BROOKLYN  ...   8221    61             318
# 80   bty7-2jhb    79              BRONX  ...   4988    66             212
# 81   bty7-2jhb    80           BROOKLYN  ...   3170    41             304
# 82   bty7-2jhb    81           NEW YORK  ...   1167  7501             107
# 83   bty7-2jhb    82                 NY  ...   1010    61             105
# 84   bty7-2jhb    83           NEW YORK  ...    569     5             102
# 85   bty7-2jhb    84           BROOKLYN  ...   2747     3             301
# 86   bty7-2jhb    85           NEW YORK  ...   1185     1             107
# 87   bty7-2jhb    86           BROOKLYN  ...   8771   119             315
# 88   bty7-2jhb    87                 BK  ...   1108     3             307
# 89   bty7-2jhb    88              BRONX  ...   3510   158             209
# 90   bty7-2jhb    89           NEW YORK  ...   1061  7502             104
# 91   bty7-2jhb    90           NEW YORK  ...   2215    42             208
# 92   bty7-2jhb    91           NEW YORK  ...   1289    72             105
# 93   bty7-2jhb    92           BROOKLYN  ...    395    30             302
# 94   bty7-2jhb    93           NEW YORK  ...   1137  7501             107
# 95   bty7-2jhb    94    LONG ISLAND CIT  ...    524    66             102
# 96   bty7-2jhb    95                 BK  ...   1508     1             303
# 97   bty7-2jhb    96           BROOKLYN  ...     35  7501             302
# 98   bty7-2jhb    97           BROOKLYN  ...   2171     1             112
# 99   bty7-2jhb    98           BROOKLYN  ...   1596    14             303
# 100  bty7-2jhb    99           NEW YORK  ...    713     1             104
# 101  bty7-2jhb   100           NEW YORK  ...   1493  7504             108
# 102  bty7-2jhb   101           SECAUCUS  ...   1375    49             108
# 103  bty7-2jhb   102           BROOKLYN  ...   1508     1             303
# 104  bty7-2jhb   103           BROOKLYN  ...   3554   125             316
# 105  bty7-2jhb   104           BROOKLYN  ...    789    44             105
# 106  bty7-2jhb   105           NEW YORK  ...    573    43             102
# 107  bty7-2jhb   106           NEW YORK  ...   1381     1             108
# 108  bty7-2jhb   107           NEW YORK  ...   1501    40             108
# 109  bty7-2jhb   108             QUEENS  ...   1701    76             403
# 110  bty7-2jhb   109           NEW YORK  ...   1449    20             108
# 111  bty7-2jhb   110           NEW YORK  ...   1449    20             108
# 112  bty7-2jhb   111           NEW YORK  ...   1158  7504             107
# 113  bty7-2jhb   112           NEW YORK  ...    208    19             102
# 114  bty7-2jhb   113           NEW YORK  ...   2222     7             112
# 115  dm9a-ab7w     1      RICHMOND HILL  ...   7203    14             315
# 116  dm9a-ab7w     2   LONG ISLAND CITY  ...   8666   610             313
# 117  dm9a-ab7w     3           BROOKLYN  ...   2742    15             301
# 118  dm9a-ab7w     4      RICHMOND HILL  ...    461    58             306
# 119  dm9a-ab7w     5           BROOKLYN  ...   2249    37             301
# 120  dm9a-ab7w     6      STATEN ISLAND  ...   5509    36             312
# 121  dm9a-ab7w     7           BROOKLYN  ...   3439    51             304
# 122  dm9a-ab7w     8           BROOKLYN  ...   3439    51             304
# 123  dm9a-ab7w     9           FLUSHING  ...   1122    45             308
# 124  dm9a-ab7w    10           FLUSHING  ...   5530    50             311
# 125  dm9a-ab7w    11         OZONE PARK  ...   2075    28             302
# 126  dm9a-ab7w    12              BRONX  ...   5772    34             310
# 127  ipu4-2q9a     1           NEW YORK  ...   1264     5             105
# 128  ipu4-2q9a     2             L.I.C.  ...    683     1             502
# 129  ipu4-2q9a     3           BROOKLYN  ...   6133    56             310
# 130  ipu4-2q9a     4           BROOKLYN  ...   5136    58             317
# 131  ipu4-2q9a     5           BROOKLYN  ...   7665     4             314
# 132  ipu4-2q9a     6           BROOKLYN  ...   1927     6             303
# 133  ipu4-2q9a     7           BROOKLYN  ...   6460   310             311
# 134  ipu4-2q9a     8                LIC  ...    741    10             104
# 135  ipu4-2q9a     9           BROOKLYN  ...   6832    64             315
# 136  ipu4-2q9a    10           BROOKLYN  ...   5519    34             312
# 137  ipu4-2q9a    11           BROOKLYN  ...   6861    67             311
# 138  ipu4-2q9a    12     ROCKAWAY POINT  ...  16350   400             414
# 139  ipu4-2q9a    13                LIC  ...   1518     1             303
# 140  ipu4-2q9a    14          MANHATTAN  ...    411  7501             103
# 141  ipu4-2q9a    15           BROOKLYN  ...   2913    26             301
# 142  ipu4-2q9a    16            JAMAICA  ...    531     3             102
# 143  ipu4-2q9a    17           NEW YORK  ...    646    64             307
# 144  ipu4-2q9a    18            JAMAICA  ...    531     3             102
# 145  ipu4-2q9a    19           BROOKLYN  ...     45    25             302
# 146  ipu4-2q9a    20           BROOKLYN  ...   5108    54             317
# 147  ipu4-2q9a    21           NEW YORK  ...    857    24             105
# 148  ipu4-2q9a    22      STATEN ISLAND  ...   8028    75             503
# 149  ipu4-2q9a    23           NEW YORK  ...    857    24             105
# 150  ipu4-2q9a    24          MANHATTAN  ...   1147     8             107
# 151  ipu4-2q9a    25      NEW HYDE PARK  ...   3969     1             502
# 152  ipu4-2q9a    26           BROOKLYN  ...   7239     1             313
# 153  ipu4-2q9a    27           NEW YORK  ...    857    24             105
# 154  ipu4-2q9a    28                LIC  ...   3247    70             207
# 155  ipu4-2q9a    29           NEW YORK  ...    883    14             105
# 156  ipu4-2q9a    30           BROOKLYN  ...    439    26             103
# 157  ipu4-2q9a    31             L.I.C.  ...   3188    14             205
# 158  ipu4-2q9a    32                LIC  ...   3247    70             207
# 159  ipu4-2q9a    33       FAR ROCKAWAY  ...  15722    41             414
# 160  ipu4-2q9a    34           BROOKLYN  ...    166    51             302
# 161  ipu4-2q9a    35           BROOKLYN  ...    166    51             302
# 162  ipu4-2q9a    36           BROOKLYN  ...   7962    85             318
# 163  ipu4-2q9a    37           NEW YORK  ...   1338    30             106
# 164  ipu4-2q9a    38           BROOKLYN  ...    166    51             302
# 165  ipu4-2q9a    39           BROOKLYN  ...    166    51             302
# 166  ipu4-2q9a    40           BROOKLYN  ...   4168    22             305
# 167  ipu4-2q9a    41           NEW YORK  ...   1329     1             106
# 168  ipu4-2q9a    42           NEW YORK  ...    803  7502             105
# 169  ipu4-2q9a    43           NEW YORK  ...   1819   203             111
# 170  ipu4-2q9a    44           BROOKLYN  ...   6603     2             311
# 171  ipu4-2q9a    45           NEW YORK  ...   1409    40             108
# 172  ipu4-2q9a    46           NEW YORK  ...   1051  7502             104
# 173  ipu4-2q9a    47                 NY  ...    555     1             102
# 174  ipu4-2q9a    48           NEW YORK  ...   1889    40             107
# 175  ipu4-2q9a    49           NEW YORK  ...   1462     5             108
# 176  ipu4-2q9a    50           BROOKLYN  ...   8244     1             318
# 177  ipu4-2q9a    51           NEW YORK  ...   1269    41             105
# 178  ipu4-2q9a    52           BROOKLYN  ...    255    25             302
# 179  ipu4-2q9a    53        JERSEY CITY  ...     16   260             101
# 180  ipu4-2q9a    54           NEW YORK  ...   1320    46             106
# 181  ipu4-2q9a    55           NEW YORK  ...   1094    18             104
# 182  ipu4-2q9a    56             L.I.C.  ...   3247   170             207
# 183  ipu4-2q9a    57           BROOKLYN  ...   5677    15             312
# 184  ipu4-2q9a    58              BRONX  ...   4941    30             212
# 185  ipu4-2q9a    59             LIC NY  ...   2306    54             201
# 186  ipu4-2q9a    60             ROSLYN  ...   1798    77             303
# 187  ipu4-2q9a    61              BRONX  ...   2335    16             201
# 188  ipu4-2q9a    62          LAS VEGAS  ...   1326    22             106
# 189  ipu4-2q9a    63           NEW YORK  ...   3342     1             304
# 190  ipu4-2q9a    64           NEW YORK  ...   3342     1             304
# 191  ipu4-2q9a    65          MANHATTAN  ...   1147   111             107
# 192  ipu4-2q9a    66              BRONX  ...   3385     1             212
# 193  ipu4-2q9a    67           NEW YORK  ...    860    49             105
# 194  ipu4-2q9a    68             ROSLYN  ...   1802    51             303
# 195  ipu4-2q9a    69           NEW YORK  ...   3342     1             304
# 196  ipu4-2q9a    70           NEW YORK  ...   1114  7502             107
# 197  ipu4-2q9a    71              BRONX  ...   5020    76             212
# 198  ipu4-2q9a    72           NEW YORK  ...   3351     1             304
# 199  ipu4-2q9a    73             ROSLYN  ...   1798    20             303
# 200  ipu4-2q9a    74           BROOKLYN  ...   4074    36             305
# 201  ipu4-2q9a    75           BROOKLYN  ...    784    12             105
# 202  ipu4-2q9a    76          NEW  YORK  ...   1266     1             105
# 203  ipu4-2q9a    77           BROOKLYN  ...   7104   202             315
# 204  ipu4-2q9a    78           BROOKLYN  ...   8221    61             318
# 205  ipu4-2q9a    79              BRONX  ...   4988    66             212
# 206  ipu4-2q9a    80           BROOKLYN  ...   3170    41             304
# 207  ipu4-2q9a    81           NEW YORK  ...   1167  7501             107
# 208  ipu4-2q9a    82           NEW YORK  ...   1010    61             105
# 209  ipu4-2q9a    83           NEW YORK  ...    569     5             102
# 210  ipu4-2q9a    84           BROOKLYN  ...   2747     3             301
# 211  ipu4-2q9a    85           NEW YORK  ...   1185     1             107
# 212  ipu4-2q9a    86           BROOKLYN  ...   8771   119             315
# 213  ipu4-2q9a    87                 BK  ...   1108     3             307
# 214  ipu4-2q9a    88              BRONX  ...   3510   158             209
# 215  ipu4-2q9a    89           NEW YORK  ...   1061  7502             104
# 216  ipu4-2q9a    90           NEW YORK  ...   2215    42             208
# 217  ipu4-2q9a    91           NEW YORK  ...   1289    72             105
# 218  ipu4-2q9a    92           BROOKLYN  ...    395    30             302
# 219  ipu4-2q9a    93           NEW YORK  ...   1137  7501             107
# 220  ipu4-2q9a    94    LONG ISLAND CIT  ...    524    66             102
# 221  ipu4-2q9a    95                 BK  ...   1508     1             303
# 222  ipu4-2q9a    96           BROOKLYN  ...     35  7501             302
# 223  ipu4-2q9a    97           BROOKLYN  ...   2171     1             112
# 224  ipu4-2q9a    98           BROOKLYN  ...   1596    14             303
# 225  ipu4-2q9a    99           NEW YORK  ...    713     1             104
# 226  ipu4-2q9a   100           NEW YORK  ...   1493  7504             108
# 227  ipu4-2q9a    10           SECAUCUS  ...   1375    49             108
# 228  ipu4-2q9a   101           BROOKLYN  ...   1508     1             303
# 229  ipu4-2q9a   102           BROOKLYN  ...   3554   125             316
# 230  ipu4-2q9a   103           BROOKLYN  ...    789    44             105
# 231  ipu4-2q9a   104           NEW YORK  ...    573    43             102
# 232  ipu4-2q9a   105           NEW YORK  ...   1381     1             108
# 233  ipu4-2q9a   106           NEW YORK  ...   1501    40             108
# 234  ipu4-2q9a   107             QUEENS  ...   1701    76             403
# 235  ipu4-2q9a   108           NEW YORK  ...   1449    20             108
# 236  ipu4-2q9a   109           NEW YORK  ...   1449    20             108
# 237  ipu4-2q9a   110           NEW YORK  ...   1158  7504             107
# 238  ipu4-2q9a   111           NEW YORK  ...    208    19             102
# 239  ipu4-2q9a   112           NEW YORK  ...   2222     7             112
# 240  ipu4-2q9a   113           BROOKLYN  ...   7024    71             313
# 241  ipu4-2q9a   114           BROOKLYN  ...   5111    46             317
# 242  ipu4-2q9a   115           NEW YORK  ...   2108    27             112
# 243  ipu4-2q9a   116           NEW YORK  ...   3110    26             206
# 244  ipu4-2q9a   117           NEW YORK  ...   1514     8             108
# 245  ipu4-2q9a   118           NEW YORK  ...   3110    26             206
# 246  ipu4-2q9a   119           NEW YORK  ...    594     8             102
# 247  ipu4-2q9a   120           NEW YORK  ...    930     1             106
# 248  ipu4-2q9a   121           NEW YORK  ...   1701     1             111
# 249  ipu4-2q9a   122           NEW YORK  ...   1701     1             111
# 250  ipu4-2q9a   123           BROOKLYN  ...   1673    45             303
# 251  ipu4-2q9a   124           NEW YORK  ...     68  7502             101
# 252  ipu4-2q9a   125           BROOKLYN  ...   4948     7             317
# 253  ipu4-2q9a   126           NEW YORK  ...     93     1             101
# 254  ipu4-2q9a   127           NEW YORK  ...   3110    26             206
# 255  ipu4-2q9a   128           BROOKLYN  ...   7024    71             313
# 256  ipu4-2q9a   129           NEW YORK  ...    870  7501             105
# 257  ipu4-2q9a   131             QUEENS  ...  11766     1             410
# 258  ipu4-2q9a   132           BROOKLYN  ...   4773    58             317
# 259  ipu4-2q9a   133           BROOKLYN  ...   6082    32             310
# 260  ipu4-2q9a   134           NEW YORK  ...   1513    20             108
# 261  ipu4-2q9a   135           NEW YORK  ...   2061    60             302
# 262  ipu4-2q9a   136             QUEENS  ...   3029    61             206
# 263  ipu4-2q9a   137             L.I.C.  ...    652    35             401
# 264  ipu4-2q9a   138           NEW YORK  ...   1808     1             111
# 265  ipu4-2q9a   139             QUEENS  ...  10863    47             412
# 266  ipu4-2q9a   140      STATEN ISLAND  ...   6319    60             311
# 267  ipu4-2q9a   141           NEW YORK  ...   1290    52             105
# 268  ipu4-2q9a   142      STATEN ISLAND  ...   6319    60             311
# 269  ipu4-2q9a   143              BRONX  ...   2447     1             204
# 270  ipu4-2q9a   144           NEW YORK  ...    591     1             306
# 271  ipu4-2q9a   145           BROOKLYN  ...   6831    21             315
# 272  ipu4-2q9a   146            KATONAH  ...   2134  7503             301
# 273  ipu4-2q9a   147             QUEENS  ...  13055    69             412
# 274  ipu4-2q9a   148           NEW YORK  ...   1290    52             105
# 275  ipu4-2q9a   149             ROSLYN  ...   1799    44             303
# 276  ipu4-2q9a   150     ROSLYN HEIGHTS  ...   3966     8             210
# 277  ipu4-2q9a   151    LONG ISLAND CIT  ...    778    18             105
# 278  ipu4-2q9a   152           BROOKLYN  ...   1208    34             308
# 279  ipu4-2q9a   153          MANHATTAN  ...     16  7507             101
# 280  ipu4-2q9a   154           NEW YORK  ...    764    10             104
# 281  ipu4-2q9a   155             L.I.C.  ...   2128    14             406
# 282  ipu4-2q9a   156           NEW YORK  ...    764    10             104
# 283  ipu4-2q9a   157    ENGLEWOOD CLIFF  ...   1909    33             110
# 284  ipu4-2q9a   158           NEW YORK  ...    529     1             102
# 285  ipu4-2q9a   159           NEW YORK  ...  14228   771             410
# 286  ipu4-2q9a   160           BROOKLYN  ...   8537    67             318
# 287  ipu4-2q9a   161           NEW YORK  ...    701    24             104
# 288  ipu4-2q9a   162           BROOKLYN  ...    914    59             106
# 289  ipu4-2q9a   163           NEW YORK  ...   1134     1             107
# 290  ipu4-2q9a   164           NEW YORK  ...  14243  1219             410
# 291  ipu4-2q9a   165           BROOKLYN  ...    438    27             103
# 292  ipu4-2q9a   166           NEW YORK  ...   5149     1             314
# 293  ipu4-2q9a   167      STATEN ISLAND  ...    626    43             501
# 294  ipu4-2q9a   168           NEW YORK  ...   3315     1             304
# 295  ipu4-2q9a   169           NEW YORK  ...   2138    40             112
# 296  ipu4-2q9a   170      STATEN ISLAND  ...   3581    11             502
# 297  ipu4-2q9a   171             ROSLYN  ...   1804    10             303
# 298  ipu4-2q9a   172           BROOKLYN  ...   6011    35             310
# 299  ipu4-2q9a   173           NEW YORK  ...  15456    15             414
# 300  ipu4-2q9a   174           BROOKLYN  ...   5661    56             312
# 301  iz2q-9x8d     1           BROOKLYN  ...    271    47             302
# 302  kfp4-dz4h     1  LONG ISLAND CITY,  ...   2414     2
# 303  kfp4-dz4h     2           NEW YORK  ...    430    40
# 304  kfp4-dz4h     3              BRONX  ...    537  7502
# 305  kyvb-rbwd     1           FLUSHING  ...   6682    52
# 306  kyvb-rbwd     2           BROOKLYN  ...   6260    19
# 307  kyvb-rbwd     3            JAMAICA  ...   9393     6
# 308  kyvb-rbwd     4           BROOKLYN  ...   6035     6
# 309  kyvb-rbwd     5              BRONX  ...   3965    18
# 310  kyvb-rbwd     6           FLUSHING  ...   6682    54
# 311  kyvb-rbwd     7           BROOKLYN  ...   4659    12
# 312  kyvb-rbwd     8           BROOKLYN  ...   6647    72
# 313  kyvb-rbwd     9           BROOKLYN  ...   6647    71
# 314  kyvb-rbwd    10      STATEN ISLAND  ...   5491   282
# 315  kyvb-rbwd    11      STATEN ISLAND  ...   5680   212
# 316  kyvb-rbwd    12           BROOKLYN  ...    422   143
# 317  kyvb-rbwd    13           BROOKLYN  ...    767    32
# 318  kyvb-rbwd    14           NEW YORK  ...   1008    15
# 319  kyvb-rbwd    15   LONG ISLAND CITY  ...    692    15
# 320  kyvb-rbwd    16              BRONX  ...   3608    69
# 321  kyvb-rbwd    17              BRONX  ...   4295    23
# 322  nyis-y4yr     1           BROOKLYN  ...   5665    14             312
# 323  nyis-y4yr     2             QUEENS  ...   1861    10             404
# 324  nyis-y4yr     3           NEW YORK  ...     63    16             101
# 325  nyis-y4yr     4           BROOKLYN  ...    299    22             402
# 326  nyis-y4yr     5           NEW YORK  ...    810    40             105
# 327  nyis-y4yr     6           NEW YORK  ...    442    18             402
# 328  nyis-y4yr     7           NEW YORK  ...    785     1             105
# 329  nyis-y4yr     8           NEW YORK  ...    687    29             104
# 330  nyis-y4yr     9           GLENDALE  ...   3810   350             405
# 331  nyis-y4yr    10           NEW YORK  ...    687    29             104
# 332  nyis-y4yr    11           BROOKLYN  ...    679     1             307
# 333  nyis-y4yr    12       CORAL GABLES  ...   4357   100             407
# 334  nyis-y4yr    13           NEW YORK  ...   1381  7502             108
# 335  nyis-y4yr    14           GLENDALE  ...   3810   350             405
# 336  nyis-y4yr    15           NEW YORK  ...   1301    23             106
# 337  nyis-y4yr    16                LIC  ...   4363   100             407
# 338  nyis-y4yr    17       CORAL GABLES  ...   4357   100             407
# 339  nyis-y4yr    18      STATEN ISLAND  ...   2400   180             502
# 340  nyis-y4yr    19           NEW YORK  ...   2443    90             204
# 341  nyis-y4yr    20           BROOKLYN  ...   1164     6             308
# 342  nyis-y4yr    21           NEW YORK  ...    687    29             104
# 343  nyis-y4yr    22           NEW YORK  ...    687    29             104
# 344  nyis-y4yr    23      STATEN ISLAND  ...   7580    21             503
# 345  nyis-y4yr    24           BROOKLYN  ...   2550    19             201
# 346  nyis-y4yr    25           NEW YORK  ...   1301    23             106
# 347  nyis-y4yr    26             QUEENS  ...  11679     9             410
# 348  nyis-y4yr    27           GLENDALE  ...   3810   350             405
# 349  nyis-y4yr    28           GLENDALE  ...   3810   350             405
# 350  nyis-y4yr    29           BROOKLYN  ...   4124    52             305
# 351  nyis-y4yr    30           NEW YORK  ...    687    29             104
# 352  nyis-y4yr    31           NEW YORK  ...    442    18             402
# 353  nyis-y4yr    32           BROOKLYN  ...   2550    19             201
# 354  nyis-y4yr    33            HOUSTON  ...    836     7             105
# 355  nyis-y4yr    34           NEW YORK  ...    812    68             105
# 356  nyis-y4yr    35          WOODHAVEN  ...   8914    21             409
# 357  nyis-y4yr    36           BROOKLYN  ...   2643    27             301
# 358  nyis-y4yr    37           GLENDALE  ...   3810   350             405
# 359  nyis-y4yr    38           NEW YORK  ...   1472    47             108
# 360  nyis-y4yr    39         DOUGLASTON  ...   8111   110             411
# 361  nyis-y4yr    40                LIC  ...   4363   100             407
# 362  nyis-y4yr    41           NEW YORK  ...    687    29             104
# 363  nyis-y4yr    42           NEW YORK  ...    442    18             402
# 364  nyis-y4yr    43             VASHON  ...   4318    20             211
# 365  nyis-y4yr    44           NEW YORK  ...  14030     6             410
# 366  nyis-y4yr    45           NEW YORK  ...   5755    41             208
# 367  nyis-y4yr    46           GLENDALE  ...   3810   350             405
# 368  nyis-y4yr    47          WOODHAVEN  ...   8914    21             409
# 369  nyis-y4yr    48       CORAL GABLES  ...   4357   100             407
# 370  nyis-y4yr    49           GLENDALE  ...   3810   350             405
# 371  nyis-y4yr    50                LIC  ...   4363   100             407
# 372  nyis-y4yr    51           NEW YORK  ...    687    29             104
# 373  nyis-y4yr    52      STATEN ISLAND  ...   7584   150             503
# 374  nyis-y4yr    53          HAWTHORNE  ...   9761     1             412
# 375  nyis-y4yr    54             VASHON  ...   4318    20             211
# 376  nyis-y4yr    55           NEW YORK  ...    442    18             402
# 377  nyis-y4yr    56       CORAL GABLES  ...   4357   100             407
# 378  nyis-y4yr    57          HAWTHORNE  ...   9761     1             412
# 379  nyis-y4yr    58           NEW YORK  ...    687    29             104
# 380  nyis-y4yr    59           BROOKLYN  ...    426    41             306
# 381  nyis-y4yr    60           NEW YORK  ...   1381  7502             108
# 382  nyis-y4yr    61             QUEENS  ...  11679     9             410
# 383  nyis-y4yr    62           NEW YORK  ...    687    29             104
# 384  nyis-y4yr    63             QUEENS  ...  11679     9             410
# 385  nyis-y4yr    64           BROOKLYN  ...   5052    27             314
# 386  nyis-y4yr    65           NEW YORK  ...    823  7507             105
# 387  nyis-y4yr    66           NEW YORK  ...   2163    53             112
# 388  nyis-y4yr    67           NEW YORK  ...   1317     1             106
# 389  nyis-y4yr    68         MONROE TWP  ...   2916    30             405
# 390  uxsz-6j5j     1           Brooklyn  ...                   9 BROOKLYN
# 391  w9ak-ipjd     1           NEW YORK  ...   1264     5             105
# 392  w9ak-ipjd     2             L.I.C.  ...    683     1             502
# 393  w9ak-ipjd     3           BROOKLYN  ...   6133    56             310
# 394  w9ak-ipjd     4           BROOKLYN  ...   5136    58             317
# 395  w9ak-ipjd     5           BROOKLYN  ...   7665     4             314
# 396  w9ak-ipjd     6           BROOKLYN  ...   1927     6             303
# 397  w9ak-ipjd     7           BROOKLYN  ...   6460   310             311
# 398  w9ak-ipjd     8                LIC  ...    741    10             104
# 399  w9ak-ipjd     9           BROOKLYN  ...   6832    64             315
# 400  w9ak-ipjd    10           BROOKLYN  ...   5519    34             312
# 401  w9ak-ipjd    11           BROOKLYN  ...   6861    67             311
# 402  w9ak-ipjd    12     ROCKAWAY POINT  ...  16350   400             414
#
# [403 rows x 7 columns]

# %% [markdown]
# #Updated City Name Fixing
# This part demonstrate the refined city name fixing strategy. The problem of (...) is resolved, which contributes to the improvement of Precision from 0.xx to 0.yy. Also, the Recall improves from 0.xx to 0.yy after this modification.

# %%
# Define Levenshtein distance function (from the mentioned link) - Levensthtein Algorithm
def levenshtein(s1, s2):

    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 
            deletions = current_row[j] + 1  
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row

    return previous_row[-1]

names_list = ds_Full\
              .to_df()\
              ['city_name'].tolist()
good_names = ['LONG ISLAND CITY', 
              'NEW YORK', 
              'FLUSHING', 
              'MANHATTAN', 
              'ROOSEVELT ISLAND', 
              'ENGLEWOOD CLIFF', 
              'BROOKLYN', 
              'BRONX',
              'ROCKAWAY POINT',
              'JAMAICA',
              'STATEN ISLAND',
              'NEW HYDE PARK',
              'FAR ROCKAWAY',
              'JERSEY CITY',
              'ROSLYN',
              'LAS VEGAS',
              'SECAUCUS',
              'QUEENS',
              'RICHMOND HILL',
              'OZONE PARK',
              'KATONAH',
              'ROSLYN HEIGHTS',
              'GLENDALE',
              'CORAL GABLES',
              'HOUSTON',
              'WOODHAVEN',
              'DOUGLASTON',
              'VASHON',
              'HAWTHORNE',
              'MONROE TWP']
# Define a function that returns the best match
def get_closest_match(name, real_names):

    levdist = [levenshtein(name, real_name) for real_name in real_names]

    for i in range(len(levdist)):
        if levdist[i] == min(levdist):
            return real_names[i]

# Loops the first list
final_list=[]
LIC=["L.I.C.","LIC", "LIC NY"]
for name in names_list: #For abbreviation, we seperate it to a different task
    if name in LIC:
      name="LONG ISLAND CITY"
    # elif name=="BK":
    #   name="BROOKLYN"
    # elif name=="NY":
    #   name="NEW YORK"
    else:
      name=get_closest_match(name, good_names)
    final_list.append(name)


# for name in names_list: #For abbreviation, we seperate it to a different task
#     name=get_closest_match(name, good_names)
#     final_list.append(name)

# %%
def correctCityName(city):
  city=final_list[0]
  final_list.pop(0)
  return city

# %%
ds_Update = ds_Update.update(columns="city_name", func=correctCityName)

# %%
ds_Update = ds_Update.to_df()

# %%
ds_Update.to_csv('./improved.csv')
