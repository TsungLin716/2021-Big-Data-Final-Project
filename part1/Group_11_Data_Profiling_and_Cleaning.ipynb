# %% [markdown]
# # Group 11: DOB Job Application Filings - Data Profiling and Data Cleaning
# Team members: Peng-Yuan Chen (pc2973), Chun-Yen Liou (cyl625), Tsung-Lin Yang (ty2065)
#
# In the following we perform the data profiling and data cleaning on the dataset of [DOB Job Application Filings](https://data.cityofnewyork.us/Housing-Development/DOB-Job-Application-Filings/ic3t-wcy2).
#
# This dataset includes all the job applications submitted to Department of Buildings (DOB) through the Borough Offices, through eFiling, or through the HUB. It has a "Latest Action Date" since January 1, 2000.
#
# The dataset consists of over 1.77 million rows and the data file is about 1 GB in size. The dataset is available for download via the Socrata Open Data API (SODA).

# %%
# Since we are using Google Colab, we have to first install openclean library.
# !pip install openclean_notebook
# !pip install openclean
# !pip install openclean_geo
# Out:
# Requirement already satisfied: openclean_notebook in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.1.7)
# Requirement already satisfied: openclean-core>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean_notebook) (0.4.1)
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean_notebook) (0.18.2)
# Requirement already satisfied: jsonschema==3.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean_notebook) (3.2.0)
# Requirement already satisfied: datamart-profiler==0.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean_notebook) (0.9)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datamart-profiler==0.9->openclean_notebook) (1.21.4)
# Requirement already satisfied: scikit-learn<0.24,>=0.22 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datamart-profiler==0.9->openclean_notebook) (0.23.2)
# Requirement already satisfied: prometheus-client in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datamart-profiler==0.9->openclean_notebook) (0.12.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datamart-profiler==0.9->openclean_notebook) (1.3.4)
# Requirement already satisfied: python-dateutil in /Users/yangzonglin/Library/Python/3.9/lib/python/site-packages (from datamart-profiler==0.9->openclean_notebook) (2.8.2)
# Requirement already satisfied: regex in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datamart-profiler==0.9->openclean_notebook) (2021.11.10)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datamart-profiler==0.9->openclean_notebook) (2.26.0)
# Requirement already satisfied: datamart-geo==0.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datamart-profiler==0.9->openclean_notebook) (0.2.1)
# Requirement already satisfied: attrs>=17.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema==3.2.0->openclean_notebook) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in /Users/yangzonglin/Library/Python/3.9/lib/python/site-packages (from jsonschema==3.2.0->openclean_notebook) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema==3.2.0->openclean_notebook) (0.18.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema==3.2.0->openclean_notebook) (57.4.0)
# Requirement already satisfied: refdata>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.4.0->openclean_notebook) (0.2.0)
# Requirement already satisfied: appdirs>=1.4.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.4.0->openclean_notebook) (1.4.4)
# Requirement already satisfied: jellyfish in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.4.0->openclean_notebook) (0.8.9)
# Requirement already satisfied: dill in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.4.0->openclean_notebook) (0.3.4)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.4.0->openclean_notebook) (1.7.2)
# Requirement already satisfied: histore>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.4.0->openclean_notebook) (0.4.1)
# Requirement already satisfied: flowserv-core>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.4.0->openclean_notebook) (0.9.2)
# Requirement already satisfied: SQLAlchemy>=1.3.18 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.4.27)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (5.4.1)
# Requirement already satisfied: Click in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (8.0.3)
# Requirement already satisfied: passlib in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.7.4)
# Requirement already satisfied: gitpython in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (3.1.24)
# Requirement already satisfied: pyyaml-include in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.2.post2)
# Requirement already satisfied: paramiko in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (2.8.0)
# Requirement already satisfied: psutil in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from histore>=0.4.0->openclean-core>=0.4.0->openclean_notebook) (5.8.0)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->datamart-profiler==0.9->openclean_notebook) (2021.3)
# Requirement already satisfied: tableprint in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (0.9.1)
# Requirement already satisfied: pooch>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (1.5.2)
# Requirement already satisfied: datasize>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (1.0.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pooch>=1.3.0->refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn<0.24,>=0.22->datamart-profiler==0.9->openclean_notebook) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn<0.24,>=0.22->datamart-profiler==0.9->openclean_notebook) (1.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from SQLAlchemy>=1.3.18->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gitpython->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gitpython->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (4.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (5.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from packaging->pooch>=1.3.0->refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (3.0.6)
# Requirement already satisfied: bcrypt>=3.1.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.4.0)
# Requirement already satisfied: cryptography>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (35.0.0)
# Requirement already satisfied: cffi>=1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (1.15.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core>=0.4.0->openclean_notebook) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->datamart-profiler==0.9->openclean_notebook) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->datamart-profiler==0.9->openclean_notebook) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yangzonglin/Library/Python/3.9/lib/python/site-packages (from requests->datamart-profiler==0.9->openclean_notebook) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->datamart-profiler==0.9->openclean_notebook) (2.0.7)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tableprint->refdata>=0.2.0->openclean-core>=0.4.0->openclean_notebook) (0.2.5)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: openclean in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.2.1)
# Requirement already satisfied: openclean-core==0.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean) (0.4.1)
# Requirement already satisfied: flowserv-core>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (0.9.2)
# Requirement already satisfied: python-dateutil in /Users/yangzonglin/Library/Python/3.9/lib/python/site-packages (from openclean-core==0.4.1->openclean) (2.8.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (2.26.0)
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (0.18.2)
# Requirement already satisfied: jsonschema>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (3.2.0)
# Requirement already satisfied: dill in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (0.3.4)
# Requirement already satisfied: pandas>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (1.3.4)
# Requirement already satisfied: histore>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (0.4.1)
# Requirement already satisfied: refdata>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (0.2.0)
# Requirement already satisfied: jellyfish in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (0.8.9)
# Requirement already satisfied: appdirs>=1.4.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (1.4.4)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (1.7.2)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core==0.4.1->openclean) (0.23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (5.4.1)
# Requirement already satisfied: passlib in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.7.4)
# Requirement already satisfied: SQLAlchemy>=1.3.18 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.4.27)
# Requirement already satisfied: paramiko in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (2.8.0)
# Requirement already satisfied: pyyaml-include in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.2.post2)
# Requirement already satisfied: gitpython in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (3.1.24)
# Requirement already satisfied: Click in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (8.0.3)
# Requirement already satisfied: psutil in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from histore>=0.4.0->openclean-core==0.4.1->openclean) (5.8.0)
# Requirement already satisfied: six>=1.11.0 in /Users/yangzonglin/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (1.16.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (57.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean) (21.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.0.0->openclean-core==0.4.1->openclean) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.0.0->openclean-core==0.4.1->openclean) (2021.3)
# Requirement already satisfied: datasize>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core==0.4.1->openclean) (1.0.0)
# Requirement already satisfied: pooch>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core==0.4.1->openclean) (1.5.2)
# Requirement already satisfied: tableprint in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core==0.4.1->openclean) (0.9.1)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pooch>=1.3.0->refdata>=0.2.0->openclean-core==0.4.1->openclean) (21.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from SQLAlchemy>=1.3.18->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gitpython->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (4.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gitpython->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (5.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from packaging->pooch>=1.3.0->refdata>=0.2.0->openclean-core==0.4.1->openclean) (3.0.6)
# Requirement already satisfied: cryptography>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (35.0.0)
# Requirement already satisfied: pynacl>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.4.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (3.2.0)
# Requirement already satisfied: cffi>=1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (1.15.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->openclean-core==0.4.1->openclean) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yangzonglin/Library/Python/3.9/lib/python/site-packages (from requests->openclean-core==0.4.1->openclean) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->openclean-core==0.4.1->openclean) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->openclean-core==0.4.1->openclean) (2.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->openclean-core==0.4.1->openclean) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->openclean-core==0.4.1->openclean) (1.1.0)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tableprint->refdata>=0.2.0->openclean-core==0.4.1->openclean) (0.2.5)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: openclean_geo in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.1.0)
# Requirement already satisfied: Shapely>=1.7.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean_geo) (1.8.0)
# Requirement already satisfied: openclean-core>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean_geo) (0.4.1)
# Requirement already satisfied: jellyfish in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (0.8.9)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (2.26.0)
# Requirement already satisfied: refdata>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (0.2.0)
# Requirement already satisfied: appdirs>=1.4.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (1.4.4)
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (0.18.2)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (1.7.2)
# Requirement already satisfied: dill in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (0.3.4)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (0.23.2)
# Requirement already satisfied: flowserv-core>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (0.9.2)
# Requirement already satisfied: histore>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (0.4.1)
# Requirement already satisfied: jsonschema>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (3.2.0)
# Requirement already satisfied: pandas>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from openclean-core>=0.3.0->openclean_geo) (1.3.4)
# Requirement already satisfied: python-dateutil in /Users/yangzonglin/Library/Python/3.9/lib/python/site-packages (from openclean-core>=0.3.0->openclean_geo) (2.8.2)
# Requirement already satisfied: pyyaml-include in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.2.post2)
# Requirement already satisfied: passlib in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.7.4)
# Requirement already satisfied: Click in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (8.0.3)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (5.4.1)
# Requirement already satisfied: SQLAlchemy>=1.3.18 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.4.27)
# Requirement already satisfied: paramiko in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (2.8.0)
# Requirement already satisfied: gitpython in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (3.1.24)
# Requirement already satisfied: psutil in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from histore>=0.4.0->openclean-core>=0.3.0->openclean_geo) (5.8.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema>=3.2.0->openclean-core>=0.3.0->openclean_geo) (57.4.0)
# Requirement already satisfied: six>=1.11.0 in /Users/yangzonglin/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.2.0->openclean-core>=0.3.0->openclean_geo) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema>=3.2.0->openclean-core>=0.3.0->openclean_geo) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema>=3.2.0->openclean-core>=0.3.0->openclean_geo) (21.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.0.0->openclean-core>=0.3.0->openclean_geo) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.0.0->openclean-core>=0.3.0->openclean_geo) (2021.3)
# Requirement already satisfied: datasize>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (1.0.0)
# Requirement already satisfied: tableprint in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (0.9.1)
# Requirement already satisfied: pooch>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (1.5.2)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pooch>=1.3.0->refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (21.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from SQLAlchemy>=1.3.18->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gitpython->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gitpython->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (4.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (5.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from packaging->pooch>=1.3.0->refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (3.0.6)
# Requirement already satisfied: bcrypt>=3.1.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (3.2.0)
# Requirement already satisfied: cryptography>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (35.0.0)
# Requirement already satisfied: pynacl>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from paramiko->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.4.0)
# Requirement already satisfied: cffi>=1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (1.15.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core>=0.3.0->openclean_geo) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->openclean-core>=0.3.0->openclean_geo) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yangzonglin/Library/Python/3.9/lib/python/site-packages (from requests->openclean-core>=0.3.0->openclean_geo) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->openclean-core>=0.3.0->openclean_geo) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->openclean-core>=0.3.0->openclean_geo) (3.3)
# Requirement already satisfied: joblib>=0.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->openclean-core>=0.3.0->openclean_geo) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->openclean-core>=0.3.0->openclean_geo) (3.0.0)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tableprint->refdata>=0.2.0->openclean-core>=0.3.0->openclean_geo) (0.2.5)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3 -m pip install --upgrade pip' command.

# %%
# Import necessary libraries
import os
import requests
from openclean.pipeline import stream
import pandas as pd
pd.set_option("max_rows", None)

# Download the full 'DOB Job Application Filings' dataset.
csvPath = './ic3t-wcy2.csv'
if not os.path.isfile(csvPath):
  csvUrl = "https://data.cityofnewyork.us/api/views/ic3t-wcy2/rows.csv"
  req = requests.get(csvUrl)
  url_content = req.content
  outfile = open(csvPath, 'wb')
  outfile.write(url_content)
  outfile.close()

# %% [markdown]
# # Data Profiling
#
# Let's first do some preliminary profiling on the dataset so that we can gain some insight about the data.

# %%
# Do the preliminary profiling
from openclean.profiling.column import DefaultColumnProfiler

ds_Full = stream(csvPath)
profiles = ds_Full.profile(default_profiler=DefaultColumnProfiler)
# Out:
# /Users/yangzonglin/Library/Python/3.9/lib/python/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname LLC identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
# Take a look at the column names in this dataset
ds_Full.columns
# Out:
# ['Job #',
#  'Doc #',
#  'Borough',
#  'House #',
#  'Street Name',
#  'Block',
#  'Lot',
#  'Bin #',
#  'Job Type',
#  'Job Status',
#  'Job Status Descrp',
#  'Latest Action Date',
#  'Building Type',
#  'Community - Board',
#  'Cluster',
#  'Landmarked',
#  'Adult Estab',
#  'Loft Board',
#  'City Owned',
#  'Little e',
#  'PC Filed',
#  'eFiling Filed',
#  'Plumbing',
#  'Mechanical',
#  'Boiler',
#  'Fuel Burning',
#  'Fuel Storage',
#  'Standpipe',
#  'Sprinkler',
#  'Fire Alarm',
#  'Equipment',
#  'Fire Suppression',
#  'Curb Cut',
#  'Other',
#  'Other Description',
#  "Applicant's First Name",
#  "Applicant's Last Name",
#  'Applicant Professional Title',
#  'Applicant License #',
#  'Professional Cert',
#  'Pre- Filing Date',
#  'Paid',
#  'Fully Paid',
#  'Assigned',
#  'Approved',
#  'Fully Permitted',
#  'Initial Cost',
#  'Total Est. Fee',
#  'Fee Status',
#  'Existing Zoning Sqft',
#  'Proposed Zoning Sqft',
#  'Horizontal Enlrgmt',
#  'Vertical Enlrgmt',
#  'Enlargement SQ Footage',
#  'Street Frontage',
#  'ExistingNo. of Stories',
#  'Proposed No. of Stories',
#  'Existing Height',
#  'Proposed Height',
#  'Existing Dwelling Units',
#  'Proposed Dwelling Units',
#  'Existing Occupancy',
#  'Proposed Occupancy',
#  'Site Fill',
#  'Zoning Dist1',
#  'Zoning Dist2',
#  'Zoning Dist3',
#  'Special District 1',
#  'Special District 2',
#  'Owner Type',
#  'Non-Profit',
#  "Owner's First Name",
#  "Owner's Last Name",
#  "Owner's Business Name",
#  "Owner's House Number",
#  "Owner'sHouse Street Name",
#  'City ',
#  'State',
#  'Zip',
#  "Owner'sPhone #",
#  'Job Description',
#  'DOBRunDate',
#  'JOB_S1_NO',
#  'TOTAL_CONSTRUCTION_FLOOR_AREA',
#  'WITHDRAWAL_FLAG',
#  'SIGNOFF_DATE',
#  'SPECIAL_ACTION_STATUS',
#  'SPECIAL_ACTION_DATE',
#  'BUILDING_CLASS',
#  'JOB_NO_GOOD_COUNT',
#  'GIS_LATITUDE',
#  'GIS_LONGITUDE',
#  'GIS_COUNCIL_DISTRICT',
#  'GIS_CENSUS_TRACT',
#  'GIS_NTA_NAME',
#  'GIS_BIN']

# %%
# Take a look at the first 10 rows
ds_Full.head()
# Out:
#        Job # Doc #   Borough House #          Street Name  Block    Lot  \
# 0  440673512    01    QUEENS   10040           222 STREET  10780  00019
# 1  421133972    02    QUEENS   88-36         139TH STREET  09620  00033
# 2  421133972    03    QUEENS   88-36         139TH STREET  09620  00033
# 3  210182309    02     BRONX      97      WEST 169 STREET  02519  00027
# 4  210182309    03     BRONX      97      WEST 169 STREET  02519  00027
# 5  440673497    01    QUEENS  215-02            93 AVENUE  10618  00028
# 6  421902374    01    QUEENS   34-74           113 STREET  01756  00025
# 7  340810947    01  BROOKLYN     770           RUGBY ROAD  06688  00034
# 8  340810910    01  BROOKLYN      39         RUTLAND ROAD  05034  00090
# 9  201204552    02     BRONX    1000  EAST TREMONT AVENUE  03005  00010
#
#      Bin # Job Type Job Status  ... SPECIAL_ACTION_STATUS SPECIAL_ACTION_DATE  \
# 0  4231025       A2          R  ...                     N
# 1  4623670       NB          P  ...                     N
# 2  4623670       NB          P  ...                     N
# 3  2130622       NB          P  ...                     N
# 4  2130622       NB          P  ...                     N
# 5  4226672       A2          X  ...                     N
# 6  4043827       A2          P  ...                     N
# 7  3178977       A2          R  ...                     N
# 8  3115124       A2          R  ...                     N
# 9  2010892       A2          P  ...                     N
#
#   BUILDING_CLASS JOB_NO_GOOD_COUNT GIS_LATITUDE GIS_LONGITUDE  \
# 0             A1                 0    40.714365    -73.731171
# 1             G7                 0    40.703428    -73.813796
# 2             G7                 0    40.703428    -73.813796
# 3             V0                 0    40.839538    -73.923177
# 4             V0                 0    40.839538    -73.923177
# 5             A1                 0    40.720067    -73.742696
# 6             W1                 0    40.755435    -73.855185
# 7             A1                 0    40.630504    -73.963353
# 8             B3                 0    40.658878    -73.959067
# 9             W1                 0    40.840755    -73.881707
#
#   GIS_COUNCIL_DISTRICT GIS_CENSUS_TRACT                       GIS_NTA_NAME  \
# 0                   27              568                     Queens Village
# 1                   24              214            Briarwood-Jamaica Hills
# 2                   24              214            Briarwood-Jamaica Hills
# 3                   16              211                         Highbridge
# 4                   16              211                         Highbridge
# 5                   23              542                     Queens Village
# 6                   21              381                       North Corona
# 7                   45              528                           Flatbush
# 8                   40            79801  Prospect Lefferts Gardens-Wingate
# 9                   17              359                       East Tremont
#
#    GIS_BIN
# 0  4231025
# 1
# 2
# 3
# 4
# 5  4226672
# 6  4043827
# 7  3178977
# 8  3115124
# 9  2010892
#
# [10 rows x 96 columns]

# %%
# See how many rows are there in this dataset
ds_Full.count()
# Out:
# 1775898

# %%
# Output the profiling result
profiles
# Out:
# [{'column': 'Job #',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 1585321})}),
#    'minmaxValues': {'int': {'minimum': 100321046, 'maximum': 577777776}},
#    'distinctValueCount': 1585321,
#    'entropy': 20.51637312295198,
#    'topValues': [('103408705', 20),
#     ('120438240', 13),
#     ('122705000', 13),
#     ('320843110', 12),
#     ('121189828', 11),
#     ('302136203', 11),
#     ('200478250', 11),
#     ('421102327', 10),
#     ('302144935', 10),
#     ('201011001', 10)]}},
#  {'column': 'Doc #',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 20})}),
#    'minmaxValues': {'int': {'minimum': 1, 'maximum': 20}},
#    'distinctValueCount': 20,
#    'entropy': 0.6255856158594904,
#    'topValues': [('01', 1584895),
#     ('02', 135019),
#     ('03', 40782),
#     ('04', 9874),
#     ('05', 3374),
#     ('06', 1188),
#     ('07', 467),
#     ('08', 176),
#     ('09', 70),
#     ('10', 22)]}},
#  {'column': 'Borough',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775898}),
#                 'distinct': Counter({'str': 5})}),
#    'minmaxValues': {'str': {'minimum': 'BRONX', 'maximum': 'STATEN ISLAND'}},
#    'distinctValueCount': 5,
#    'entropy': 1.9983982520862276,
#    'topValues': [('MANHATTAN', 775417),
#     ('BROOKLYN', 406689),
#     ('QUEENS', 349784),
#     ('BRONX', 143597),
#     ('STATEN ISLAND', 100411)]}},
#  {'column': 'House #',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 6,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1443385, 'str': 332037, 'date': 470}),
#                 'distinct': Counter({'int': 9830,
#                          'str': 25704,
#                          'date': 182})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 154019},
#     'str': {'minimum': '000000029-06', 'maximum': '_547'},
#     'date': {'minimum': datetime.datetime(100, 1, 2, 0, 0),
#      'maximum': datetime.datetime(7447, 1, 4, 0, 0)}},
#    'distinctValueCount': 35716,
#    'entropy': 11.797104915702459,
#    'topValues': [('1', 17364),
#     ('200', 11854),
#     ('100', 8116),
#     ('11', 7234),
#     ('10', 7193),
#     ('55', 7166),
#     ('40', 7109),
#     ('30', 7099),
#     ('2', 6428),
#     ('150', 6382)]}},
#  {'column': 'Street Name',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 6,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1774621, 'date': 1225, 'int': 46}),
#                 'distinct': Counter({'str': 29096, 'date': 459, 'int': 20})}),
#    'minmaxValues': {'str': {'minimum': ',MYRTLE AVENUE',
#      'maximum': '`WEST 61ST ST'},
#     'date': {'minimum': datetime.datetime(100, 12, 11, 0, 0),
#      'maximum': datetime.datetime(2070, 12, 11, 0, 0)},
#     'int': {'minimum': 41, 'maximum': 248}},
#    'distinctValueCount': 29575,
#    'entropy': 11.613875273159815,
#    'topValues': [('BROADWAY', 52277),
#     ('PARK AVENUE', 29812),
#     ('MADISON AVENUE', 25099),
#     ('FIFTH AVENUE', 16968),
#     ('5 AVENUE', 14143),
#     ('LEXINGTON AVENUE', 12581),
#     ('AVENUE OF THE AMERICAS', 11717),
#     ('THIRD AVENUE', 10273),
#     ('3 AVENUE', 8267),
#     ('5TH AVENUE', 7934)]}},
#  {'column': 'Block',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 752,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775143, 'str': 3}),
#                 'distinct': Counter({'int': 13814, 'str': 3})}),
#    'minmaxValues': {'int': {'minimum': -1948, 'maximum': 99999},
#     'str': {'minimum': 'O2275', 'maximum': 'O6534'}},
#    'distinctValueCount': 13817,
#    'entropy': 12.482810236968017,
#    'topValues': [('00016', 6810),
#     ('00835', 2984),
#     ('00972', 2845),
#     ('01293', 2822),
#     ('01284', 2706),
#     ('01280', 2702),
#     ('01287', 2696),
#     ('00962', 2694),
#     ('01290', 2687),
#     ('01292', 2608)]}},
#  {'column': 'Lot',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 756,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775138, 'str': 4}),
#                 'distinct': Counter({'int': 1967, 'str': 4})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 99917},
#     'str': {'minimum': '...28', 'maximum': 'OOO58'}},
#    'distinctValueCount': 1971,
#    'entropy': 6.5884201494392265,
#    'topValues': [('00001', 216517),
#     ('07501', 68592),
#     ('00029', 35314),
#     ('00033', 28077),
#     ('00005', 27864),
#     ('00021', 25912),
#     ('00014', 25428),
#     ('00020', 24894),
#     ('00023', 24827),
#     ('00010', 24573)]}},
#  {'column': 'Bin #',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 364292})}),
#    'minmaxValues': {'int': {'minimum': 109162, 'maximum': 5869021}},
#    'distinctValueCount': 364292,
#    'entropy': 16.77499275176322,
#    'topValues': [('1015862', 2413),
#     ('1014387', 2193),
#     ('1076262', 1850),
#     ('1813346', 1423),
#     ('1085735', 1415),
#     ('1083346', 1394),
#     ('1036082', 1309),
#     ('1000058', 1306),
#     ('4045999', 1290),
#     ('1013043', 1245)]}},
#  {'column': 'Job Type',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775898}),
#                 'distinct': Counter({'str': 9})}),
#    'minmaxValues': {'str': {'minimum': 'A1', 'maximum': 'SI'}},
#    'distinctValueCount': 9,
#    'entropy': 1.7127652485968192,
#    'topValues': [('A2', 1117728),
#     ('A3', 304105),
#     ('A1', 141170),
#     ('NB', 124467),
#     ('DM', 48988),
#     ('PA', 21039),
#     ('SI', 10641),
#     ('SC', 7753),
#     ('SG', 7)]}},
#  {'column': 'Job Status',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775802, 'int': 96}),
#                 'distinct': Counter({'str': 16, 'int': 1})}),
#    'minmaxValues': {'str': {'minimum': 'A', 'maximum': 'X'},
#     'int': {'minimum': 3, 'maximum': 3}},
#    'distinctValueCount': 17,
#    'entropy': 1.8354773804543707,
#    'topValues': [('X', 1052932),
#     ('R', 411283),
#     ('P', 89772),
#     ('J', 80947),
#     ('Q', 48703),
#     ('U', 28902),
#     ('H', 28742),
#     ('D', 20973),
#     ('A', 6332),
#     ('E', 4671)]}},
#  {'column': 'Job Status Descrp',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775898}),
#                 'distinct': Counter({'str': 17})}),
#    'minmaxValues': {'str': {'minimum': 'APPLICATION ASSIGNED TO PLAN EXAMINER',
#      'maximum': 'SUSPENDED'}},
#    'distinctValueCount': 17,
#    'entropy': 1.8354773804543707,
#    'topValues': [('SIGNED OFF', 1052932),
#     ('PERMIT ISSUED - ENTIRE JOB/WORK', 411283),
#     ('PLAN EXAM - APPROVED', 89772),
#     ('PLAN EXAM - DISAPPROVED', 80947),
#     ('PERMIT ISSUED - PARTIAL JOB', 48703),
#     ('COMPLETED', 28902),
#     ('PLAN EXAM - IN PROCESS', 28742),
#     ('APPLICATION PROCESSED - ENTIRE', 20973),
#     ('PRE-FILING', 6332),
#     ('APPLICATION PROCESSED - NO PLAN EXAM', 4671)]}},
#  {'column': 'Latest Action Date',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 1775898}),
#                 'distinct': Counter({'date': 7398})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(1403, 6, 11, 0, 0),
#      'maximum': datetime.datetime(2021, 12, 10, 0, 0)}},
#    'distinctValueCount': 7398,
#    'entropy': 12.382657072907037,
#    'topValues': [('10/13/2017', 792),
#     ('05/18/2017', 774),
#     ('01/25/2017', 744),
#     ('02/12/2018', 739),
#     ('11/30/2016', 733),
#     ('07/11/2016', 716),
#     ('11/29/2016', 700),
#     ('04/30/2018', 699),
#     ('05/04/2017', 683),
#     ('04/20/2016', 674)]}},
#  {'column': 'Building Type',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775898}),
#                 'distinct': Counter({'str': 2})}),
#    'minmaxValues': {'str': {'minimum': '1-2-3 FAMILY', 'maximum': 'OTHERS'}},
#    'distinctValueCount': 2,
#    'entropy': 0.75516121853754,
#    'topValues': [('OTHERS', 1390039), ('1-2-3 FAMILY', 385859)]}},
#  {'column': 'Community - Board',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1295,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1774602, 'str': 1}),
#                 'distinct': Counter({'int': 105, 'str': 1})}),
#    'minmaxValues': {'int': {'minimum': 1, 'maximum': 609},
#     'str': {'minimum': '3-4', 'maximum': '3-4'}},
#    'distinctValueCount': 106,
#    'entropy': 5.4604926245484,
#    'topValues': [('105', 210733),
#     ('108', 88028),
#     ('102', 80309),
#     ('101', 71393),
#     ('106', 70243),
#     ('104', 63126),
#     ('107', 61202),
#     ('407', 47781),
#     ('301', 47337),
#     ('302', 43130)]}},
#  {'column': 'Cluster',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 643494,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1132404}),
#                 'distinct': Counter({'str': 2})}),
#    'minmaxValues': {'str': {'minimum': 'N', 'maximum': 'Y'}},
#    'distinctValueCount': 2,
#    'entropy': 0.0635840873964815,
#    'topValues': [('N', 1123933), ('Y', 8471)]}},
#  {'column': 'Landmarked',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 104120,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1671778}),
#                 'distinct': Counter({'str': 4})}),
#    'minmaxValues': {'str': {'minimum': 'C', 'maximum': 'Y'}},
#    'distinctValueCount': 4,
#    'entropy': 0.5466156435527483,
#    'topValues': [('N', 1462500), ('Y', 208886), ('L', 369), ('C', 23)]}},
#  {'column': 'Adult Estab',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 193528,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1582370}),
#                 'distinct': Counter({'str': 2})}),
#    'minmaxValues': {'str': {'minimum': 'N', 'maximum': 'Y'}},
#    'distinctValueCount': 2,
#    'entropy': 0.001596392957753057,
#    'topValues': [('N', 1582197), ('Y', 173)]}},
#  {'column': 'Loft Board',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 374040,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1401858}),
#                 'distinct': Counter({'str': 2})}),
#    'minmaxValues': {'str': {'minimum': 'N', 'maximum': 'Y'}},
#    'distinctValueCount': 2,
#    'entropy': 0.04772602518409024,
#    'topValues': [('N', 1394422), ('Y', 7436)]}},
#  {'column': 'City Owned',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1626355,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 149543}),
#                 'distinct': Counter({'str': 4})}),
#    'minmaxValues': {'str': {'minimum': 'I', 'maximum': 'Y'}},
#    'distinctValueCount': 4,
#    'entropy': 0.0003737964617143072,
#    'topValues': [('Y', 149540), ('I', 1), ('M', 1), ('N', 1)]}},
#  {'column': 'Little e',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 728435,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1047463}),
#                 'distinct': Counter({'str': 5})}),
#    'minmaxValues': {'str': {'minimum': 'H', 'maximum': 'Y'}},
#    'distinctValueCount': 5,
#    'entropy': 0.35603594346886086,
#    'topValues': [('N', 990555),
#     ('Y', 36109),
#     ('H', 20794),
#     ('M', 4),
#     ('X', 1)]}},
#  {'column': 'PC Filed',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1173692,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 602206}),
#                 'distinct': Counter({'str': 2})}),
#    'minmaxValues': {'str': {'minimum': 'N', 'maximum': 'Y'}},
#    'distinctValueCount': 2,
#    'entropy': 0.9436326846031167,
#    'topValues': [('Y', 384720), ('N', 217486)]}},
#  {'column': 'eFiling Filed',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 693354,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1082544}),
#                 'distinct': Counter({'str': 2})}),
#    'minmaxValues': {'str': {'minimum': 'R', 'maximum': 'Y'}},
#    'distinctValueCount': 2,
#    'entropy': 3.785285021574681e-05,
#    'topValues': [('Y', 1082542), ('R', 2)]}},
#  {'column': 'Plumbing',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1220198,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 555700}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 555700)]}},
#  {'column': 'Mechanical',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1491602,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 284296}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 284296)]}},
#  {'column': 'Boiler',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1725940,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 49958}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 49958)]}},
#  {'column': 'Fuel Burning',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1754447,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 21451}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 21451)]}},
#  {'column': 'Fuel Storage',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1761643,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 14255}),
#                 'distinct': Counter({'str': 2})}),
#    'minmaxValues': {'str': {'minimum': 'N', 'maximum': 'X'}},
#    'distinctValueCount': 2,
#    'entropy': 0.001069226577019155,
#    'topValues': [('X', 14254), ('N', 1)]}},
#  {'column': 'Standpipe',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1761512,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 14386}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 14386)]}},
#  {'column': 'Sprinkler',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1659513,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 116385}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 116385)]}},
#  {'column': 'Fire Alarm',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1688195,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 87703}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 87703)]}},
#  {'column': 'Equipment',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1469030,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 306868}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 306868)]}},
#  {'column': 'Fire Suppression',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1732528,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 43370}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 43370)]}},
#  {'column': 'Curb Cut',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1714685,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 61213}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 61213)]}},
#  {'column': 'Other',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 733338,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1042560}),
#                 'distinct': Counter({'str': 1})}),
#    'minmaxValues': {'str': {'minimum': 'X', 'maximum': 'X'}},
#    'distinctValueCount': 1,
#    'entropy': 0.0,
#    'topValues': [('X', 1042560)]}},
#  {'column': 'Other Description',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 735133,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1040677, 'int': 84, 'float': 4}),
#                 'distinct': Counter({'str': 16583, 'int': 43, 'float': 4})}),
#    'minmaxValues': {'str': {'minimum': '!nt. St. & San.',
#      'maximum': 'unerpin & shori'},
#     'int': {'minimum': 0, 'maximum': 402145754},
#     'float': {'minimum': 1000.0, 'maximum': 125000.0}},
#    'distinctValueCount': 16630,
#    'entropy': 4.851463237263918,
#    'topValues': [('GEN. CONSTR.', 316612),
#     ('GC', 116243),
#     ('GEN. CONSTR', 87350),
#     ('STRUCTURAL', 55580),
#     ('BPP', 50840),
#     ('GEN CONST', 42153),
#     ('SOLAR TAX', 34138),
#     ('GEN.CONSTRUCTN.', 26544),
#     ('FACADE', 22632),
#     ('CONSTRUCTION', 20501)]}},
#  {'column': "Applicant's First Name",
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 32,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775860, 'int': 5, 'date': 1}),
#                 'distinct': Counter({'str': 17362, 'int': 4, 'date': 1})}),
#    'minmaxValues': {'str': {'minimum': '+EINING', 'maximum': 'zoilo'},
#     'int': {'minimum': 2, 'maximum': 7186054055},
#     'date': {'minimum': datetime.datetime(2021, 4, 11, 0, 0),
#      'maximum': datetime.datetime(2021, 4, 11, 0, 0)}},
#    'distinctValueCount': 17367,
#    'entropy': 9.286591559861831,
#    'topValues': [('MICHAEL', 51062),
#     ('JOHN', 44296),
#     ('ROBERT', 41772),
#     ('DAVID', 35926),
#     ('PAUL', 32699),
#     ('ANTHONY', 29891),
#     ('JAMES', 27116),
#     ('JOSEPH', 26997),
#     ('THOMAS', 24226),
#     ('PETER', 21929)]}},
#  {'column': "Applicant's Last Name",
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775893, 'float': 1, 'int': 4}),
#                 'distinct': Counter({'str': 35231, 'float': 1, 'int': 4})}),
#    'minmaxValues': {'str': {'minimum': "'BRIEN", 'maximum': 'zori'},
#     'float': {'minimum': nan, 'maximum': nan},
#     'int': {'minimum': 1212, 'maximum': 420865380}},
#    'distinctValueCount': 35236,
#    'entropy': 11.501511970811501,
#    'topValues': [('HOQUE', 19156),
#     ('KATZ', 15137),
#     ('LEE', 14520),
#     ('RUDIKOFF', 12109),
#     ('GERAZOUNIS', 11126),
#     ('BAILEY', 10824),
#     ('CALIENDO', 9310),
#     ('CHEN', 9108),
#     ('SYED-NAQVI', 7297),
#     ('MASS', 6665)]}},
#  {'column': 'Applicant Professional Title',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 37,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775847, 'int': 14}),
#                 'distinct': Counter({'str': 903, 'int': 11})}),
#    'minmaxValues': {'str': {'minimum': "'", 'maximum': 'signhanger'},
#     'int': {'minimum': 0, 'maximum': 50069}},
#    'distinctValueCount': 914,
#    'entropy': 1.294960971716021,
#    'topValues': [('PE', 924799),
#     ('RA', 797144),
#     ('GC', 12762),
#     ('OT', 10657),
#     ('G.C', 5707),
#     ('CONTRACTOR', 3314),
#     ('DEMO CONTRACTOR', 2087),
#     ('DEMO', 1973),
#     ('PERMIT BROKER', 1765),
#     ('GEN CONTRACTOR', 1504)]}},
#  {'column': 'Applicant License #',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 49201,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1726536, 'str': 155, 'float': 6}),
#                 'distinct': Counter({'int': 27031, 'str': 63, 'float': 6})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 999999},
#     'str': {'minimum': '00000D', 'maximum': 'X02689'},
#     'float': {'minimum': 0.18963, 'maximum': 688.6}},
#    'distinctValueCount': 27100,
#    'entropy': 11.417538911080467,
#    'topValues': [('083278', 19192),
#     ('050579', 16342),
#     ('066709', 12092),
#     ('013529', 10886),
#     ('082770', 10709),
#     ('020419', 10230),
#     ('020241', 9354),
#     ('080123', 8244),
#     ('038964', 7523),
#     ('045101', 6730)]}},
#  {'column': 'Professional Cert',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 378194,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1397704}),
#                 'distinct': Counter({'str': 5})}),
#    'minmaxValues': {'str': {'minimum': 'F', 'maximum': 'Y'}},
#    'distinctValueCount': 5,
#    'entropy': 0.9613638696453557,
#    'topValues': [('Y', 859981), ('N', 537719), ('J', 2), ('F', 1), ('R', 1)]}},
#  {'column': 'Pre- Filing Date',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 1775898}),
#                 'distinct': Counter({'date': 6645})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(1992, 8, 11, 0, 0),
#      'maximum': datetime.datetime(2021, 12, 10, 0, 0)}},
#    'distinctValueCount': 6645,
#    'entropy': 12.380911237458673,
#    'topValues': [('06/28/2019', 1717),
#     ('12/30/2014', 1466),
#     ('06/27/2019', 1388),
#     ('06/26/2008', 1006),
#     ('06/25/2008', 842),
#     ('06/26/2019', 833),
#     ('09/30/2016', 831),
#     ('12/29/2014', 808),
#     ('02/04/2011', 763),
#     ('02/15/2008', 738)]}},
#  {'column': 'Paid',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 9073,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 1766825}),
#                 'distinct': Counter({'date': 6664})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(1992, 8, 17, 0, 0),
#      'maximum': datetime.datetime(2021, 12, 10, 0, 0)}},
#    'distinctValueCount': 6664,
#    'entropy': 12.38500933345041,
#    'topValues': [('06/28/2019', 1700),
#     ('12/30/2014', 1484),
#     ('06/27/2019', 1319),
#     ('06/26/2008', 1259),
#     ('02/15/2008', 978),
#     ('02/04/2011', 915),
#     ('06/30/2009', 879),
#     ('06/25/2008', 866),
#     ('09/30/2016', 839),
#     ('12/29/2014', 807)]}},
#  {'column': 'Fully Paid',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 6583,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 1769315}),
#                 'distinct': Counter({'date': 6731})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(1992, 8, 17, 0, 0),
#      'maximum': datetime.datetime(2021, 12, 10, 0, 0)}},
#    'distinctValueCount': 6731,
#    'entropy': 12.387221173585903,
#    'topValues': [('06/28/2019', 1702),
#     ('12/30/2014', 1515),
#     ('06/27/2019', 1310),
#     ('06/26/2008', 1222),
#     ('02/15/2008', 978),
#     ('02/04/2011', 916),
#     ('06/30/2009', 857),
#     ('09/30/2016', 844),
#     ('12/29/2014', 795),
#     ('06/26/2019', 790)]}},
#  {'column': 'Assigned',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 579162,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 1196736}),
#                 'distinct': Counter({'date': 6805})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(1993, 12, 14, 0, 0),
#      'maximum': datetime.datetime(2021, 12, 10, 0, 0)}},
#    'distinctValueCount': 6805,
#    'entropy': 12.420005298941872,
#    'topValues': [('07/01/2009', 575),
#     ('01/12/2018', 523),
#     ('03/22/2018', 512),
#     ('08/09/2001', 492),
#     ('12/30/2014', 487),
#     ('10/28/2015', 469),
#     ('06/28/2019', 448),
#     ('07/18/2017', 442),
#     ('06/26/2008', 438),
#     ('09/20/2017', 433)]}},
#  {'column': 'Approved',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 329920,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 1445977, 'str': 1}),
#                 'distinct': Counter({'date': 6909, 'str': 1})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(1992, 10, 21, 0, 0),
#      'maximum': datetime.datetime(2021, 12, 10, 0, 0)},
#     'str': {'minimum': '60/20/2001', 'maximum': '60/20/2001'}},
#    'distinctValueCount': 6910,
#    'entropy': 12.410716187369031,
#    'topValues': [('06/26/2008', 663),
#     ('06/25/2008', 529),
#     ('06/27/2019', 521),
#     ('06/28/2019', 514),
#     ('05/21/2015', 500),
#     ('11/10/2005', 476),
#     ('12/03/2015', 474),
#     ('08/03/2016', 446),
#     ('10/11/2017', 444),
#     ('09/30/2016', 442)]}},
#  {'column': 'Fully Permitted',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 464955,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 1310937, 'str': 6}),
#                 'distinct': Counter({'date': 6135, 'str': 6})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(1209, 3, 20, 0, 0),
#      'maximum': datetime.datetime(3008, 3, 31, 0, 0)},
#     'str': {'minimum': '02/0/2012', 'maximum': '85/09/2010'}},
#    'distinctValueCount': 6141,
#    'entropy': 12.365721303823369,
#    'topValues': [('11/12/2015', 487),
#     ('05/17/2017', 439),
#     ('11/15/2016', 439),
#     ('07/25/2017', 435),
#     ('11/04/2015', 429),
#     ('08/15/2001', 429),
#     ('11/06/2013', 429),
#     ('11/09/2006', 425),
#     ('09/13/2016', 422),
#     ('11/09/2017', 421)]}},
#  {'column': 'Initial Cost',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775898}),
#                 'distinct': Counter({'str': 98811})}),
#    'minmaxValues': {'str': {'minimum': '$-100.00',
#      'maximum': '$999999999.00'}},
#    'distinctValueCount': 98811,
#    'entropy': 7.625420295221288,
#    'topValues': [('$0.00', 477931),
#     ('$10000.00', 57798),
#     ('$1000.00', 55282),
#     ('$3000.00', 51160),
#     ('$5000.00', 50536),
#     ('$20000.00', 43245),
#     ('$15000.00', 38849),
#     ('$25000.00', 35438),
#     ('$30000.00', 30254),
#     ('$50000.00', 30055)]}},
#  {'column': 'Total Est. Fee',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775898}),
#                 'distinct': Counter({'str': 93209})}),
#    'minmaxValues': {'str': {'minimum': '$-85.80', 'maximum': '$99995.85'}},
#    'distinctValueCount': 93209,
#    'entropy': 9.704941119630375,
#    'topValues': [('$100.00', 144859),
#     ('$0.00', 58847),
#     ('$160.00', 58084),
#     ('$130.00', 55739),
#     ('$225.00', 42234),
#     ('$140.00', 33609),
#     ('$200.00', 31423),
#     ('$191.50', 26906),
#     ('$294.50', 20432),
#     ('$346.00', 18524)]}},
#  {'column': 'Fee Status',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775898}),
#                 'distinct': Counter({'str': 3})}),
#    'minmaxValues': {'str': {'minimum': 'DEFERRED', 'maximum': 'STANDARD'}},
#    'distinctValueCount': 3,
#    'entropy': 0.4829836123292425,
#    'topValues': [('STANDARD', 1601932),
#     ('EXEMPT', 168227),
#     ('DEFERRED', 5739)]}},
#  {'column': 'Existing Zoning Sqft',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 18064})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 29214765}},
#    'distinctValueCount': 18064,
#    'entropy': 0.7510065935136935,
#    'topValues': [('0', 1705896),
#     ('1', 794),
#     ('2000', 304),
#     ('2500', 239),
#     ('3000', 233),
#     ('5000', 199),
#     ('2400', 161),
#     ('4000', 157),
#     ('3300', 145),
#     ('1000', 144)]}},
#  {'column': 'Proposed Zoning Sqft',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 24630})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 29214765}},
#    'distinctValueCount': 24630,
#    'entropy': 1.075662070154603,
#    'topValues': [('0', 1674016),
#     ('1', 1235),
#     ('300', 914),
#     ('2000', 374),
#     ('240', 340),
#     ('5000', 288),
#     ('4000', 287),
#     ('3000', 281),
#     ('2400', 273),
#     ('2500', 268)]}},
#  {'column': 'Horizontal Enlrgmt',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1730079,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 45819}),
#                 'distinct': Counter({'str': 2})}),
#    'minmaxValues': {'str': {'minimum': 'N', 'maximum': 'Y'}},
#    'distinctValueCount': 2,
#    'entropy': 0.002157013855107164,
#    'topValues': [('Y', 45812), ('N', 7)]}},
#  {'column': 'Vertical Enlrgmt',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1743748,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 32150}),
#                 'distinct': Counter({'str': 2})}),
#    'minmaxValues': {'str': {'minimum': 'N', 'maximum': 'Y'}},
#    'distinctValueCount': 2,
#    'entropy': 0.0037078038210714495,
#    'topValues': [('Y', 32141), ('N', 9)]}},
#  {'column': 'Enlargement SQ Footage',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 6970})}),
#    'minmaxValues': {'int': {'minimum': -9, 'maximum': 22304116}},
#    'distinctValueCount': 6970,
#    'entropy': 0.6103165989867199,
#    'topValues': [('0', 1714554),
#     ('200', 309),
#     ('300', 265),
#     ('600', 263),
#     ('1000', 258),
#     ('400', 237),
#     ('500', 226),
#     ('800', 206),
#     ('180', 184),
#     ('240', 179)]}},
#  {'column': 'Street Frontage',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 1184})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 98558}},
#    'distinctValueCount': 1184,
#    'entropy': 0.6544877197514247,
#    'topValues': [('0', 1678279),
#     ('25', 11057),
#     ('50', 9038),
#     ('40', 8976),
#     ('20', 7209),
#     ('60', 4009),
#     ('100', 2872),
#     ('30', 2752),
#     ('75', 2152),
#     ('80', 1659)]}},
#  {'column': 'ExistingNo. of Stories',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 152})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 999}},
#    'distinctValueCount': 152,
#    'entropy': 3.340813960469858,
#    'topValues': [('0', 821687),
#     ('2', 176226),
#     ('3', 108322),
#     ('1', 99554),
#     ('6', 88741),
#     ('4', 84316),
#     ('5', 76898),
#     ('12', 27764),
#     ('7', 26002),
#     ('8', 16305)]}},
#  {'column': 'Proposed No. of Stories',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 319})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 999}},
#    'distinctValueCount': 319,
#    'entropy': 4.101117846379424,
#    'topValues': [('0', 396687),
#     ('2', 273867),
#     ('3', 185488),
#     ('4', 124858),
#     ('6', 120745),
#     ('1', 120630),
#     ('5', 109901),
#     ('12', 38994),
#     ('7', 37188),
#     ('8', 23780)]}},
#  {'column': 'Existing Height',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 945})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 99999}},
#    'distinctValueCount': 945,
#    'entropy': 4.895984953849218,
#    'topValues': [('0', 821705),
#     ('25', 43210),
#     ('30', 40409),
#     ('60', 38810),
#     ('40', 28376),
#     ('50', 27514),
#     ('20', 26430),
#     ('35', 24774),
#     ('55', 24486),
#     ('65', 21098)]}},
#  {'column': 'Proposed Height',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 1102})}),
#    'minmaxValues': {'int': {'minimum': -12, 'maximum': 99999}},
#    'distinctValueCount': 1102,
#    'entropy': 6.1558659109188785,
#    'topValues': [('0', 454438),
#     ('25', 65608),
#     ('30', 61408),
#     ('60', 52978),
#     ('40', 40533),
#     ('50', 39646),
#     ('35', 38292),
#     ('20', 33020),
#     ('55', 32631),
#     ('24', 27831)]}},
#  {'column': 'Existing Dwelling Units',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1131058,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 644836, 'str': 4}),
#                 'distinct': Counter({'int': 1079, 'str': 3})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 52121},
#     'str': {'minimum': '.', 'maximum': '....4'}},
#    'distinctValueCount': 1082,
#    'entropy': 5.977224770103707,
#    'topValues': [('1', 118145),
#     ('2', 95195),
#     ('0', 40080),
#     ('3', 28820),
#     ('4', 20867),
#     ('6', 16949),
#     ('8', 15408),
#     ('5', 9768),
#     ('10', 9575),
#     ('20', 9306)]}},
#  {'column': 'Proposed Dwelling Units',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 856512,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 919380, 'str': 6}),
#                 'distinct': Counter({'int': 1168, 'str': 5})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 52121},
#     'str': {'minimum': '.', 'maximum': 'NONE'}},
#    'distinctValueCount': 1173,
#    'entropy': 5.684398162740477,
#    'topValues': [('1', 172367),
#     ('2', 166523),
#     ('3', 57942),
#     ('0', 38886),
#     ('4', 30846),
#     ('6', 24245),
#     ('8', 23538),
#     ('5', 14771),
#     ('10', 14424),
#     ('20', 12757)]}},
#  {'column': 'Existing Occupancy',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 504491,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1271407}),
#                 'distinct': Counter({'str': 47})}),
#    'minmaxValues': {'str': {'minimum': '.COM', 'maximum': 'U'}},
#    'distinctValueCount': 47,
#    'entropy': 3.341353680539116,
#    'topValues': [('RES', 411873),
#     ('COM', 251557),
#     ('E', 111698),
#     ('J-2', 98844),
#     ('J-3', 84060),
#     ('R-2', 51143),
#     ('R-3', 45205),
#     ('PUB', 36838),
#     ('B', 31805),
#     ('C', 27083)]}},
#  {'column': 'Proposed Occupancy',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 712472,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1063425, 'int': 1}),
#                 'distinct': Counter({'str': 48, 'int': 1})}),
#    'minmaxValues': {'str': {'minimum': '.RES', 'maximum': 'U'},
#     'int': {'minimum': 1, 'maximum': 1}},
#    'distinctValueCount': 49,
#    'entropy': 3.6478079442382008,
#    'topValues': [('RES', 290176),
#     ('COM', 169571),
#     ('J-3', 82431),
#     ('R-3', 79845),
#     ('J-2', 75153),
#     ('R-2', 74802),
#     ('E', 74087),
#     ('B', 38291),
#     ('PUB', 26799),
#     ('C', 17271)]}},
#  {'column': 'Site Fill',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 350112,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1425786}),
#                 'distinct': Counter({'str': 5})}),
#    'minmaxValues': {'str': {'minimum': 'NONE',
#      'maximum': 'USE UNDER 300 CU.YD'}},
#    'distinctValueCount': 5,
#    'entropy': 1.4931122990637595,
#    'topValues': [('NOT APPLICABLE', 717755),
#     ('NONE', 568891),
#     ('ON-SITE', 79054),
#     ('OFF-SITE', 32965),
#     ('USE UNDER 300 CU.YD', 27121)]}},
#  {'column': 'Zoning Dist1',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 334811,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1441086, 'int': 1}),
#                 'distinct': Counter({'str': 229, 'int': 1})}),
#    'minmaxValues': {'str': {'minimum': '.4-4', 'maximum': '____R4'},
#     'int': {'minimum': 15, 'maximum': 15}},
#    'distinctValueCount': 230,
#    'entropy': 5.911609198027445,
#    'topValues': [('R6', 149776),
#     ('R5', 84499),
#     ('C5-3', 64139),
#     ('R3-2', 60495),
#     ('R7-2', 59835),
#     ('R4', 56850),
#     ('R6B', 47929),
#     ('R8', 42874),
#     ('R8B', 39379),
#     ('R7-1', 38846)]}},
#  {'column': 'Zoning Dist2',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1582219,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 193612, 'int': 67}),
#                 'distinct': Counter({'str': 176, 'int': 20})}),
#    'minmaxValues': {'str': {'minimum': 'BPC', 'maximum': 'R9X'},
#     'int': {'minimum': 729, 'maximum': 91222}},
#    'distinctValueCount': 196,
#    'entropy': 5.670211957012544,
#    'topValues': [('R8B', 19306),
#     ('C5-2.5', 14918),
#     ('R6', 14544),
#     ('C5-3', 10766),
#     ('R5', 8204),
#     ('C6-6', 7327),
#     ('R7-2', 6441),
#     ('R8', 5552),
#     ('C6-4.5', 5046),
#     ('R6B', 4891)]}},
#  {'column': 'Zoning Dist3',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1765629,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 10268, 'date': 1}),
#                 'distinct': Counter({'str': 134, 'date': 1})}),
#    'minmaxValues': {'str': {'minimum': 'BPC', 'maximum': 'R9X'},
#     'date': {'minimum': datetime.datetime(2021, 1, 3, 0, 0, 3),
#      'maximum': datetime.datetime(2021, 1, 3, 0, 0, 3)}},
#    'distinctValueCount': 135,
#    'entropy': 5.546742230390638,
#    'topValues': [('C6-6', 1554),
#     ('R8B', 683),
#     ('C6-6.5', 351),
#     ('R6B', 332),
#     ('C2-8', 331),
#     ('R6', 323),
#     ('C5-25/C67', 282),
#     ('C1-9', 275),
#     ('C6-1', 269),
#     ('C5-5', 256)]}},
#  {'column': 'Special District 1',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1513629,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 259943, 'int': 2326}),
#                 'distinct': Counter({'str': 115, 'int': 1})}),
#    'minmaxValues': {'str': {'minimum': '.', 'maximum': 'WP'},
#     'int': {'minimum': 125, 'maximum': 125}},
#    'distinctValueCount': 116,
#    'entropy': 4.262626022663093,
#    'topValues': [('MID', 84266),
#     ('LM', 19172),
#     ('SRD', 16627),
#     ('OP', 11202),
#     ('PI', 9937),
#     ('CL', 9898),
#     ('DB', 8224),
#     ('BR', 6878),
#     ('TMU', 6471),
#     ('GC', 6146)]}},
#  {'column': 'Special District 2',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1695704,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 80194}),
#                 'distinct': Counter({'str': 15})}),
#    'minmaxValues': {'str': {'minimum': 'BPRK', 'maximum': 'POPS'}},
#    'distinctValueCount': 15,
#    'entropy': 2.3712835152454104,
#    'topValues': [('POPS', 27849),
#     ('IBZ', 23891),
#     ('MS4', 10840),
#     ('GW', 6717),
#     ('JAM', 5929),
#     ('MIH', 2992),
#     ('HILI', 1007),
#     ('CONH', 450),
#     ('BPRK', 389),
#     ('GCP2', 79)]}},
#  {'column': 'Owner Type',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 73395,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1702503}),
#                 'distinct': Counter({'str': 14})}),
#    'minmaxValues': {'str': {'minimum': 'CONDO/CO-OP',
#      'maximum': 'PARTNERSHIP'}},
#    'distinctValueCount': 14,
#    'entropy': 2.1021388724761985,
#    'topValues': [('CORPORATION', 575764),
#     ('INDIVIDUAL', 544048),
#     ('PARTNERSHIP', 423319),
#     ('CONDO/CO-OP', 51940),
#     ('OTHER', 43337),
#     ("OTHER GOV'T AGENCY", 32536),
#     ('NYCHA/HHC', 9414),
#     ('NYC AGENCY', 8374),
#     ('NYCHA', 7296),
#     ('HPD', 3661)]}},
#  {'column': 'Non-Profit',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 71548,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1704350}),
#                 'distinct': Counter({'str': 2})}),
#    'minmaxValues': {'str': {'minimum': 'N', 'maximum': 'Y'}},
#    'distinctValueCount': 2,
#    'entropy': 0.34331045307762864,
#    'topValues': [('N', 1595189), ('Y', 109161)]}},
#  {'column': "Owner's First Name",
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 3,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775671, 'int': 130, 'float': 94}),
#                 'distinct': Counter({'str': 93153, 'int': 64, 'float': 3})}),
#    'minmaxValues': {'str': {'minimum': '& 56 ST ASSOCC', 'maximum': 'zygmund'},
#     'int': {'minimum': 0, 'maximum': 16872},
#     'float': {'minimum': nan, 'maximum': nan}},
#    'distinctValueCount': 93220,
#    'entropy': 10.94970427070999,
#    'topValues': [('MICHAEL', 40965),
#     ('JOSEPH', 34916),
#     ('ROBERT', 34592),
#     ('JOHN', 34033),
#     ('DAVID', 32644),
#     ('JAMES', 19447),
#     ('RICHARD', 19024),
#     ('STEVE', 17302),
#     ('ANTHONY', 16663),
#     ('PETER', 16119)]}},
#  {'column': "Owner's Last Name",
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 5,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1775796, 'int': 81, 'float': 16}),
#                 'distinct': Counter({'str': 156930, 'int': 54, 'float': 2})}),
#    'minmaxValues': {'str': {'minimum': '& NICOLE  LLC', 'maximum': '{FLORES'},
#     'int': {'minimum': 0, 'maximum': 19309},
#     'float': {'minimum': nan, 'maximum': nan}},
#    'distinctValueCount': 156986,
#    'entropy': 13.891162538540193,
#    'topValues': [('SINGH', 23632),
#     ('COHEN', 12284),
#     ('SONITIS', 8907),
#     ('CHEN', 7229),
#     ('ABNERI', 7202),
#     ('JOSEPH', 5555),
#     ('LEE', 5254),
#     ('Joseph', 4727),
#     ('LIN', 4306),
#     ('GROOM', 4015)]}},
#  {'column': "Owner's Business Name",
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 44180,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1731385,
#                          'int': 300,
#                          'date': 23,
#                          'float': 10}),
#                 'distinct': Counter({'str': 412634,
#                          'int': 209,
#                          'date': 19,
#                          'float': 1})}),
#    'minmaxValues': {'str': {'minimum': '# 1 DUMPLING',
#      'maximum': '¢ENNSYLVANIA BLDG CORP'},
#     'int': {'minimum': 0, 'maximum': 71888476765925},
#     'date': {'minimum': datetime.datetime(102, 1, 31, 0, 0),
#      'maximum': datetime.datetime(5110, 7, 11, 0, 0)},
#     'float': {'minimum': nan, 'maximum': nan}},
#    'distinctValueCount': 412863,
#    'entropy': 14.219812265784013,
#    'topValues': [('N/A', 260735),
#     ('NA', 42547),
#     ('OWNER', 11057),
#     ('NY SCHOOL CONSTRUCTION AUTHORITY', 9760),
#     ('NONE', 9560),
#     ('NYC SCA', 9243),
#     ('VORNADO OFFICE MANAGEMENT', 6991),
#     ('NYCHA', 6652),
#     ('SL GREEN REALTY CORP.', 5697),
#     ('NYC HOUSING AUTHORITY', 5696)]}},
#  {'column': "Owner's House Number",
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1774895,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 808, 'str': 194, 'date': 1}),
#                 'distinct': Counter({'int': 406, 'str': 142, 'date': 1})}),
#    'minmaxValues': {'int': {'minimum': 1, 'maximum': 33088},
#     'str': {'minimum': '-', 'maximum': 'PO. BOX'},
#     'date': {'minimum': datetime.datetime(205, 9, 11, 0, 0),
#      'maximum': datetime.datetime(205, 9, 11, 0, 0)}},
#    'distinctValueCount': 549,
#    'entropy': 8.55327798496135,
#    'topValues': [('2', 19),
#     ('30-30', 18),
#     ('555', 17),
#     ('22', 16),
#     ('100', 16),
#     ('1950', 16),
#     ('10', 12),
#     ('32', 11),
#     ('250', 11),
#     ('35', 10)]}},
#  {'column': "Owner'sHouse Street Name",
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1774895,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1003}),
#                 'distinct': Counter({'str': 756})}),
#    'minmaxValues': {'str': {'minimum': '- P.O. BOX 6356',
#      'maximum': 'PO. BOX 131431'}},
#    'distinctValueCount': 756,
#    'entropy': 9.292286541605892,
#    'topValues': [('555 WEST 23RD STREET', 17),
#     ('22 CHAPEL STREET', 10),
#     ('1559 49TH STREET', 9),
#     ('30-30 THOMSON AVENUE', 9),
#     ('35 N TYSON AVENUE STE#102', 8),
#     ('199 LEE AVENUE', 6),
#     ('250 BROADWAY', 6),
#     ('579 FIFTH AVENUE, 4TH FLOOR', 6),
#     ('1950 Coney Island Avenue', 6),
#     ('32 COURT ST SUITE 205', 5)]}},
#  {'column': 'City ',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1774895,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1003}),
#                 'distinct': Counter({'str': 114})}),
#    'minmaxValues': {'str': {'minimum': 'ARVERNE', 'maximum': 'YONKERS'}},
#    'distinctValueCount': 114,
#    'entropy': 3.8846042534012852,
#    'topValues': [('BROOKLYN', 309),
#     ('NEW YORK', 273),
#     ('QUEENS', 56),
#     ('NY', 37),
#     ('BRONX', 32),
#     ('STATEN ISLAND', 19),
#     ('LIC', 18),
#     ('New York', 18),
#     ('FLUSHING', 15),
#     ('BKLYN', 14)]}},
#  {'column': 'State',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1774895,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1003}),
#                 'distinct': Counter({'str': 9})}),
#    'minmaxValues': {'str': {'minimum': 'CA', 'maximum': 'VA'}},
#    'distinctValueCount': 9,
#    'entropy': 0.20255975718206054,
#    'topValues': [('NY', 981),
#     ('NJ', 11),
#     ('CA', 3),
#     ('CT', 3),
#     ('MD', 1),
#     ('MA', 1),
#     ('KY', 1),
#     ('VA', 1),
#     ('MO', 1)]}},
#  {'column': 'Zip',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1774897,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1001}),
#                 'distinct': Counter({'int': 212})}),
#    'minmaxValues': {'int': {'minimum': 1056, 'maximum': 212550500}},
#    'distinctValueCount': 212,
#    'entropy': 6.839797538339762,
#    'topValues': [('11201', 46),
#     ('10011', 31),
#     ('11220', 30),
#     ('10022', 30),
#     ('11219', 27),
#     ('11101', 26),
#     ('11211', 25),
#     ('10007', 24),
#     ('10019', 22),
#     ('11204', 21)]}},
#  {'column': "Owner'sPhone #",
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 11467,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1764145, 'str': 280, 'float': 6}),
#                 'distinct': Counter({'int': 359552, 'str': 219, 'float': 6})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 9999999999},
#     'str': {'minimum': ',A,CF,10,A', 'maximum': '\x86F&FF'},
#     'float': {'minimum': 7183.8209, 'maximum': 71861518.6}},
#    'distinctValueCount': 359777,
#    'entropy': 15.564351998442456,
#    'topValues': [('7184728000', 12745),
#     ('2128947000', 10347),
#     ('2128637625', 5610),
#     ('7183924921', 4411),
#     ('2122161664', 4190),
#     ('2124072400', 3922),
#     ('7184728534', 3350),
#     ('2125295688', 3313),
#     ('5169355555', 3288),
#     ('7186280500', 2992)]}},
#  {'column': 'Job Description',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 180171,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1595708, 'int': 18, 'float': 1}),
#                 'distinct': Counter({'str': 1247478, 'int': 9, 'float': 1})}),
#    'minmaxValues': {'str': {'minimum': '!INSTALLATION OF TEMPORARY PLATFORMS FOR DIOR GUGGENHEIM ANNUAL GALA, LOCATED AT 1071 5TH AVE., NY, FIRST FLOOR, SCHEDULED FOR NOV. 15-16, 2017 A TPA PERMIT IS REQUIRED. PRODUCER IS RESPONSIBLE TO MONITOR EVENT CONDITIONS AND IMPLEMENT APPROPRIATE ACTIONS, IF NECESSARY. ALL PROD EQUIP REMOVED UPON EVENT COMPLETION.',
#      'maximum': '~INSTALLATION OF NEW FIRE ALARM DEVICES TO BE TIED INTO EXISTING BASE BUILDING CLASS E FIRE ALARM SIGNAL SYSTE M SHOWN ON SUBMITTED RISER DIAGRAM'},
#     'int': {'minimum': 0, 'maximum': 320314922},
#     'float': {'minimum': 3.465, 'maximum': 3.465}},
#    'distinctValueCount': 1247488,
#    'entropy': 19.38256920821671,
#    'topValues': [('PROPOSED INSTALLATION OF HEAVY DUTY SIDEWALK SHED FILED FOR REMEDIAL REPAIRS AS PER PLANS. NO CHANGE IN USE OCCUPANCY OR EGRESS UNDER THIS APPLICATION. LIVE LOAD 300 PER SQUARE FEET. SIDEWALK SHED SHALL COMPLY WITH CHAPTER # 33 OF THE 2008 CODE.',
#      3985),
#     ('INSTALLATION OF SOLAR PANELS ON EXISTING ROOF. NO CHANGE IN USE, OCCUPANCY,  OR EGRESS. NO CHANGE IN BULK.',
#      3692),
#     ('INSTALLATION OF SOLAR ENERGY SYSTEM ON ROOF. NO CHANGE OF OCCUPANCY, USE OR EGRESS.',
#      3370),
#     ('PROPOSED INSTALLATION OF PIPE SCAFFOLD AS PER PLANS. NO CHANGE IN USE, EGRESS OR OCCUPANCY.',
#      2882),
#     ('FILING HEREWITH TAX ABATEMENT APPLICATION FOR INSTALLATION OF ROOF MOUNTED SOLAR PANELS. NO CHANGE IN USE, EGRESS OR OCCUPANCY.',
#      2724),
#     ('PROPOSED INSTALLATION OF HEAVY DUTY SIDEWALK SHED AS PER PLANS. NO CHANGE IN USE, EGRESS OR OCCUPANCY.',
#      2720),
#     ('INSTALLATION OF SOLAR PANELS ON ROOF. NO CHANGE IN USE, EGRESS, OR OCCUPANCY.',
#      2681),
#     ('FILLING HEREWITH TAX ABATEMENT APPLICATION FOR INSTALLATION OF ROOF MOUNTED SOLAR PANELS. NO CHANGE IN USE, EGRESS OR OCCUPANCY.',
#      1994),
#     ('MODIFICATION TO EXISTING SPRINKLER SYSTEM AS PER PLANS FILED HEREWITH. NO CHANGE IN USE, EGRESS OR OCCUPANCY UNDER THIS APPLICATION.',
#      1752),
#     ('REMOVAL AND INSTALLATION OF INTERIOR NON BEARING PARTITIONS AND RELATED FINISHES AS PER PLANS FILED HEREWITH. NO CHANGE IN USE, EGRESS OR OCCUPANCY UNDER THIS APPLICATION.',
#      1749)]}},
#  {'column': 'DOBRunDate',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 1775898}),
#                 'distinct': Counter({'date': 319})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(2018, 3, 1, 0, 0),
#      'maximum': datetime.datetime(2021, 12, 11, 0, 0)}},
#    'distinctValueCount': 319,
#    'entropy': 0.7211855418389679,
#    'topValues': [('04/28/2021 00:00:00', 1668586),
#     ('07/09/2021 00:00:00', 16872),
#     ('09/16/2021 00:00:00', 6815),
#     ('11/16/2021 00:00:00', 3258),
#     ('08/02/2021 00:00:00', 2643),
#     ('11/23/2021 00:00:00', 1730),
#     ('12/07/2021 00:00:00', 1709),
#     ('11/03/2021 00:00:00', 1668),
#     ('11/30/2021 00:00:00', 1259),
#     ('05/25/2021 00:00:00', 1236)]}},
#  {'column': 'JOB_S1_NO',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 1775898})}),
#    'minmaxValues': {'int': {'minimum': 35932, 'maximum': 3327524}},
#    'distinctValueCount': 1775898,
#    'entropy': 20.760117291147434,
#    'topValues': [('3294002', 1),
#     ('3293961', 1),
#     ('3293963', 1),
#     ('3293964', 1),
#     ('3293967', 1),
#     ('3293955', 1),
#     ('3294100', 1),
#     ('3294045', 1),
#     ('3294010', 1),
#     ('3294099', 1)]}},
#  {'column': 'TOTAL_CONSTRUCTION_FLOOR_AREA',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 26607})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 999999999}},
#    'distinctValueCount': 26607,
#    'entropy': 1.5482800862475525,
#    'topValues': [('0', 1620569),
#     ('1', 1319),
#     ('300', 1239),
#     ('240', 1124),
#     ('3000', 873),
#     ('3600', 742),
#     ('200', 681),
#     ('400', 573),
#     ('2500', 520),
#     ('2000', 520)]}},
#  {'column': 'WITHDRAWAL_FLAG',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 13})}),
#    'minmaxValues': {'int': {'minimum': -3, 'maximum': 29}},
#    'distinctValueCount': 13,
#    'entropy': 0.10383150758933017,
#    'topValues': [('0', 1753657),
#     ('1', 20025),
#     ('2', 1921),
#     ('3', 239),
#     ('4', 38),
#     ('6', 5),
#     ('5', 5),
#     ('7', 3),
#     ('-3', 1),
#     ('28', 1)]}},
#  {'column': 'SIGNOFF_DATE',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 710064,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 1065833, 'str': 1}),
#                 'distinct': Counter({'date': 5937, 'str': 1})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(2000, 1, 12, 0, 0),
#      'maximum': datetime.datetime(2021, 12, 10, 0, 0)},
#     'str': {'minimum': '31/51/2004', 'maximum': '31/51/2004'}},
#    'distinctValueCount': 5938,
#    'entropy': 12.29242932101354,
#    'topValues': [('02/12/2018', 603),
#     ('01/25/2017', 593),
#     ('05/18/2017', 580),
#     ('10/13/2017', 576),
#     ('11/30/2016', 572),
#     ('07/11/2016', 558),
#     ('07/19/2012', 540),
#     ('11/29/2016', 535),
#     ('01/23/2018', 526),
#     ('04/30/2018', 526)]}},
#  {'column': 'SPECIAL_ACTION_STATUS',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 20208,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1755690}),
#                 'distinct': Counter({'str': 4})}),
#    'minmaxValues': {'str': {'minimum': 'A', 'maximum': 'W'}},
#    'distinctValueCount': 4,
#    'entropy': 0.7420304201644077,
#    'topValues': [('N', 1519877), ('W', 146431), ('A', 63370), ('C', 26012)]}},
#  {'column': 'SPECIAL_ACTION_DATE',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 1603119,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'date': 172779}),
#                 'distinct': Counter({'date': 6395})}),
#    'minmaxValues': {'date': {'minimum': datetime.datetime(2000, 1, 19, 0, 0),
#      'maximum': datetime.datetime(2021, 12, 10, 0, 0)}},
#    'distinctValueCount': 6395,
#    'entropy': 11.890291298840351,
#    'topValues': [('10/24/2012', 5513),
#     ('05/12/2017', 510),
#     ('10/23/2012', 229),
#     ('02/10/2017', 224),
#     ('08/13/2019', 188),
#     ('03/02/2015', 186),
#     ('06/27/2017', 181),
#     ('03/02/2017', 172),
#     ('11/10/2015', 156),
#     ('11/19/2020', 154)]}},
#  {'column': 'BUILDING_CLASS',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 6832,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1769066}),
#                 'distinct': Counter({'str': 199})}),
#    'minmaxValues': {'str': {'minimum': 'A0', 'maximum': 'Z9'}},
#    'distinctValueCount': 199,
#    'entropy': 5.645768815144321,
#    'topValues': [('R0', 211192),
#     ('O4', 141856),
#     ('D4', 91283),
#     ('O6', 70448),
#     ('A1', 67715),
#     ('B2', 59796),
#     ('C0', 58030),
#     ('C7', 56956),
#     ('C1', 52085),
#     ('B1', 49007)]}},
#  {'column': 'JOB_NO_GOOD_COUNT',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 0,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1775898}),
#                 'distinct': Counter({'int': 13})}),
#    'minmaxValues': {'int': {'minimum': 0, 'maximum': 44}},
#    'distinctValueCount': 13,
#    'entropy': 0.013640961147939541,
#    'topValues': [('0', 1773995),
#     ('11', 1301),
#     ('22', 360),
#     ('10', 160),
#     ('33', 32),
#     ('1', 20),
#     ('21', 17),
#     ('20', 7),
#     ('32', 2),
#     ('31', 1)]}},
#  {'column': 'GIS_LATITUDE',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 5661,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'float': 1770237}),
#                 'distinct': Counter({'float': 217699})}),
#    'minmaxValues': {'float': {'minimum': 40.498807, 'maximum': 40.913711}},
#    'distinctValueCount': 217699,
#    'entropy': 16.313765521810314,
#    'topValues': [('40.748276', 2409),
#     ('40.751098', 2194),
#     ('40.758754', 1542),
#     ('40.754162', 1415),
#     ('40.703608', 1404),
#     ('40.733848', 1297),
#     ('40.764020', 1291),
#     ('40.711537', 1276),
#     ('40.740704', 1198),
#     ('40.752532', 1170)]}},
#  {'column': 'GIS_LONGITUDE',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 5661,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'float': 1770237}),
#                 'distinct': Counter({'float': 228528})}),
#    'minmaxValues': {'float': {'minimum': -74.254897, 'maximum': -73.700376}},
#    'distinctValueCount': 228528,
#    'entropy': 16.29379227951357,
#    'topValues': [('-73.984690', 2413),
#     ('-73.992926', 2187),
#     ('-73.978692', 1574),
#     ('-73.976557', 1415),
#     ('-74.009691', 1395),
#     ('-74.015673', 1299),
#     ('-73.973189', 1293),
#     ('-73.871578', 1289),
#     ('-74.001844', 1230),
#     ('-73.978662', 1175)]}},
#  {'column': 'GIS_COUNCIL_DISTRICT',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 5661,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1770237}),
#                 'distinct': Counter({'int': 51})}),
#    'minmaxValues': {'int': {'minimum': 1, 'maximum': 51}},
#    'distinctValueCount': 51,
#    'entropy': 5.191713442632571,
#    'topValues': [('4', 236671),
#     ('3', 150056),
#     ('1', 125021),
#     ('2', 72285),
#     ('33', 58694),
#     ('6', 55000),
#     ('5', 42080),
#     ('39', 38486),
#     ('50', 36293),
#     ('34', 35409)]}},
#  {'column': 'GIS_CENSUS_TRACT',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 5661,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1770237}),
#                 'distinct': Counter({'int': 1328})}),
#    'minmaxValues': {'int': {'minimum': 1, 'maximum': 157903}},
#    'distinctValueCount': 1328,
#    'entropy': 9.43164622167019,
#    'topValues': [('7', 16442),
#     ('102', 15631),
#     ('33', 14137),
#     ('104', 13873),
#     ('92', 13758),
#     ('9', 13587),
#     ('96', 13077),
#     ('94', 12487),
#     ('137', 12366),
#     ('113', 12356)]}},
#  {'column': 'GIS_NTA_NAME',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 5661,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'str': 1770237}),
#                 'distinct': Counter({'str': 194})}),
#    'minmaxValues': {'str': {'minimum': 'Airport',
#      'maximum': 'park-cemetery-etc-Queens'}},
#    'distinctValueCount': 194,
#    'entropy': 6.8324088023400416,
#    'topValues': [('Midtown-Midtown South', 153877),
#     ('Hudson Yards-Chelsea-Flatiron-Union Square', 65697),
#     ('SoHo-TriBeCa-Civic Center-Little Italy', 57644),
#     ('Turtle Bay-East Midtown', 53331),
#     ('Upper East Side-Carnegie Hill', 48410),
#     ('West Village', 47277),
#     ('Battery Park City-Lower Manhattan', 45009),
#     ('Upper West Side', 37747),
#     ('Murray Hill-Kips Bay', 29817),
#     ('Lenox Hill-Roosevelt Island', 23298)]}},
#  {'column': 'GIS_BIN',
#   'stats': {'totalValueCount': 1775898,
#    'emptyValueCount': 22169,
#    'datatypes': defaultdict(collections.Counter,
#                {'total': Counter({'int': 1753729}),
#                 'distinct': Counter({'int': 343266})}),
#    'minmaxValues': {'int': {'minimum': 1000000, 'maximum': 5799501}},
#    'distinctValueCount': 343266,
#    'entropy': 16.43594135982682,
#    'topValues': [('3000000', 15646),
#     ('4000000', 14105),
#     ('1000000', 10236),
#     ('2000000', 5654),
#     ('5000000', 4661),
#     ('1015862', 2413),
#     ('1014387', 2193),
#     ('1076262', 1793),
#     ('1085735', 1415),
#     ('1083346', 1394)]}}]

# %%
profiles.stats()
# Out:
#                                  total    empty  distinct    uniqueness  \
# Job #                          1775898        0   1585321  8.926870e-01
# Doc #                          1775898        0        20  1.126191e-05
# Borough                        1775898        0         5  2.815477e-06
# House #                        1775898        6     35716  2.011158e-02
# Street Name                    1775898        6     29575  1.665360e-02
# Block                          1775898      752     13817  7.783585e-03
# Lot                            1775898      756      1971  1.110334e-03
# Bin #                          1775898        0    364292  2.051312e-01
# Job Type                       1775898        0         9  5.067859e-06
# Job Status                     1775898        0        17  9.572622e-06
# Job Status Descrp              1775898        0        17  9.572622e-06
# Latest Action Date             1775898        0      7398  4.165780e-03
# Building Type                  1775898        0         2  1.126191e-06
# Community - Board              1775898     1295       106  5.973167e-05
# Cluster                        1775898   643494         2  1.766154e-06
# Landmarked                     1775898   104120         4  2.392662e-06
# Adult Estab                    1775898   193528         2  1.263927e-06
# Loft Board                     1775898   374040         2  1.426678e-06
# City Owned                     1775898  1626355         4  2.674816e-05
# Little e                       1775898   728435         5  4.773438e-06
# PC Filed                       1775898  1173692         2  3.321123e-06
# eFiling Filed                  1775898   693354         2  1.847500e-06
# Plumbing                       1775898  1220198         1  1.799532e-06
# Mechanical                     1775898  1491602         1  3.517461e-06
# Boiler                         1775898  1725940         1  2.001681e-05
# Fuel Burning                   1775898  1754447         1  4.661787e-05
# Fuel Storage                   1775898  1761643         2  1.403016e-04
# Standpipe                      1775898  1761512         1  6.951203e-05
# Sprinkler                      1775898  1659513         1  8.592173e-06
# Fire Alarm                     1775898  1688195         1  1.140212e-05
# Equipment                      1775898  1469030         1  3.258730e-06
# Fire Suppression               1775898  1732528         1  2.305741e-05
# Curb Cut                       1775898  1714685         1  1.633640e-05
# Other                          1775898   733338         1  9.591774e-07
# Other Description              1775898   735133     16630  1.597863e-02
# Applicant's First Name         1775898       32     17367  9.779454e-03
# Applicant's Last Name          1775898        0     35236  1.984123e-02
# Applicant Professional Title   1775898       37       914  5.146799e-04
# Applicant License #            1775898    49201     27100  1.569470e-02
# Professional Cert              1775898   378194         5  3.577295e-06
# Pre- Filing Date               1775898        0      6645  3.741769e-03
# Paid                           1775898     9073      6664  3.771737e-03
# Fully Paid                     1775898     6583      6731  3.804297e-03
# Assigned                       1775898   579162      6805  5.686300e-03
# Approved                       1775898   329920      6910  4.778773e-03
# Fully Permitted                1775898   464955      6141  4.684414e-03
# Initial Cost                   1775898        0     98811  5.564002e-02
# Total Est. Fee                 1775898        0     93209  5.248556e-02
# Fee Status                     1775898        0         3  1.689286e-06
# Existing Zoning Sqft           1775898        0     18064  1.017176e-02
# Proposed Zoning Sqft           1775898        0     24630  1.386904e-02
# Horizontal Enlrgmt             1775898  1730079         2  4.365001e-05
# Vertical Enlrgmt               1775898  1743748         2  6.220840e-05
# Enlargement SQ Footage         1775898        0      6970  3.924775e-03
# Street Frontage                1775898        0      1184  6.667050e-04
# ExistingNo. of Stories         1775898        0       152  8.559050e-05
# Proposed No. of Stories        1775898        0       319  1.796274e-04
# Existing Height                1775898        0       945  5.321252e-04
# Proposed Height                1775898        0      1102  6.205311e-04
# Existing Dwelling Units        1775898  1131058      1082  1.677936e-03
# Proposed Dwelling Units        1775898   856512      1173  1.275851e-03
# Existing Occupancy             1775898   504491        47  3.696692e-05
# Proposed Occupancy             1775898   712472        49  4.607749e-05
# Site Fill                      1775898   350112         5  3.506838e-06
# Zoning Dist1                   1775898   334811       230  1.596017e-04
# Zoning Dist2                   1775898  1582219       196  1.011984e-03
# Zoning Dist3                   1775898  1765629       135  1.314636e-02
# Special District 1             1775898  1513629       116  4.422940e-04
# Special District 2             1775898  1695704        15  1.870464e-04
# Owner Type                     1775898    73395        14  8.223187e-06
# Non-Profit                     1775898    71548         2  1.173468e-06
# Owner's First Name             1775898        3     93220  5.249184e-02
# Owner's Last Name              1775898        5    156986  8.839834e-02
# Owner's Business Name          1775898    44180    412863  2.384124e-01
# Owner's House Number           1775898  1774895       549  5.473579e-01
# Owner'sHouse Street Name       1775898  1774895       756  7.537388e-01
# City                           1775898  1774895       114  1.136590e-01
# State                          1775898  1774895         9  8.973081e-03
# Zip                            1775898  1774897       212  2.117882e-01
# Owner'sPhone #                 1775898    11467    359777  2.039054e-01
# Job Description                1775898   180171   1247488  7.817678e-01
# DOBRunDate                     1775898        0       319  1.796274e-04
# JOB_S1_NO                      1775898        0   1775898  1.000000e+00
# TOTAL_CONSTRUCTION_FLOOR_AREA  1775898        0     26607  1.498228e-02
# WITHDRAWAL_FLAG                1775898        0        13  7.320240e-06
# SIGNOFF_DATE                   1775898   710064      5938  5.571224e-03
# SPECIAL_ACTION_STATUS          1775898    20208         4  2.278307e-06
# SPECIAL_ACTION_DATE            1775898  1603119      6395  3.701260e-02
# BUILDING_CLASS                 1775898     6832       199  1.124887e-04
# JOB_NO_GOOD_COUNT              1775898        0        13  7.320240e-06
# GIS_LATITUDE                   1775898     5661    217699  1.229773e-01
# GIS_LONGITUDE                  1775898     5661    228528  1.290946e-01
# GIS_COUNCIL_DISTRICT           1775898     5661        51  2.880970e-05
# GIS_CENSUS_TRACT               1775898     5661      1328  7.501820e-04
# GIS_NTA_NAME                   1775898     5661       194  1.095898e-04
# GIS_BIN                        1775898    22169    343266  1.957349e-01
#
#                                  entropy
# Job #                          20.516373
# Doc #                           0.625586
# Borough                         1.998398
# House #                        11.797105
# Street Name                    11.613875
# Block                          12.482810
# Lot                             6.588420
# Bin #                          16.774993
# Job Type                        1.712765
# Job Status                      1.835477
# Job Status Descrp               1.835477
# Latest Action Date             12.382657
# Building Type                   0.755161
# Community - Board               5.460493
# Cluster                         0.063584
# Landmarked                      0.546616
# Adult Estab                     0.001596
# Loft Board                      0.047726
# City Owned                      0.000374
# Little e                        0.356036
# PC Filed                        0.943633
# eFiling Filed                   0.000038
# Plumbing                        0.000000
# Mechanical                      0.000000
# Boiler                          0.000000
# Fuel Burning                    0.000000
# Fuel Storage                    0.001069
# Standpipe                       0.000000
# Sprinkler                       0.000000
# Fire Alarm                      0.000000
# Equipment                       0.000000
# Fire Suppression                0.000000
# Curb Cut                        0.000000
# Other                           0.000000
# Other Description               4.851463
# Applicant's First Name          9.286592
# Applicant's Last Name          11.501512
# Applicant Professional Title    1.294961
# Applicant License #            11.417539
# Professional Cert               0.961364
# Pre- Filing Date               12.380911
# Paid                           12.385009
# Fully Paid                     12.387221
# Assigned                       12.420005
# Approved                       12.410716
# Fully Permitted                12.365721
# Initial Cost                    7.625420
# Total Est. Fee                  9.704941
# Fee Status                      0.482984
# Existing Zoning Sqft            0.751007
# Proposed Zoning Sqft            1.075662
# Horizontal Enlrgmt              0.002157
# Vertical Enlrgmt                0.003708
# Enlargement SQ Footage          0.610317
# Street Frontage                 0.654488
# ExistingNo. of Stories          3.340814
# Proposed No. of Stories         4.101118
# Existing Height                 4.895985
# Proposed Height                 6.155866
# Existing Dwelling Units         5.977225
# Proposed Dwelling Units         5.684398
# Existing Occupancy              3.341354
# Proposed Occupancy              3.647808
# Site Fill                       1.493112
# Zoning Dist1                    5.911609
# Zoning Dist2                    5.670212
# Zoning Dist3                    5.546742
# Special District 1              4.262626
# Special District 2              2.371284
# Owner Type                      2.102139
# Non-Profit                      0.343310
# Owner's First Name             10.949704
# Owner's Last Name              13.891163
# Owner's Business Name          14.219812
# Owner's House Number            8.553278
# Owner'sHouse Street Name        9.292287
# City                            3.884604
# State                           0.202560
# Zip                             6.839798
# Owner'sPhone #                 15.564352
# Job Description                19.382569
# DOBRunDate                      0.721186
# JOB_S1_NO                      20.760117
# TOTAL_CONSTRUCTION_FLOOR_AREA   1.548280
# WITHDRAWAL_FLAG                 0.103832
# SIGNOFF_DATE                   12.292429
# SPECIAL_ACTION_STATUS           0.742030
# SPECIAL_ACTION_DATE            11.890291
# BUILDING_CLASS                  5.645769
# JOB_NO_GOOD_COUNT               0.013641
# GIS_LATITUDE                   16.313766
# GIS_LONGITUDE                  16.293792
# GIS_COUNCIL_DISTRICT            5.191713
# GIS_CENSUS_TRACT                9.431646
# GIS_NTA_NAME                    6.832409
# GIS_BIN                        16.435941

# %%
# Detect which column has empty value and its amount
profiles.stats()['empty']
# Out:
# Job #                                  0
# Doc #                                  0
# Borough                                0
# House #                                6
# Street Name                            6
# Block                                752
# Lot                                  756
# Bin #                                  0
# Job Type                               0
# Job Status                             0
# Job Status Descrp                      0
# Latest Action Date                     0
# Building Type                          0
# Community - Board                   1295
# Cluster                           643494
# Landmarked                        104120
# Adult Estab                       193528
# Loft Board                        374040
# City Owned                       1626355
# Little e                          728435
# PC Filed                         1173692
# eFiling Filed                     693354
# Plumbing                         1220198
# Mechanical                       1491602
# Boiler                           1725940
# Fuel Burning                     1754447
# Fuel Storage                     1761643
# Standpipe                        1761512
# Sprinkler                        1659513
# Fire Alarm                       1688195
# Equipment                        1469030
# Fire Suppression                 1732528
# Curb Cut                         1714685
# Other                             733338
# Other Description                 735133
# Applicant's First Name                32
# Applicant's Last Name                  0
# Applicant Professional Title          37
# Applicant License #                49201
# Professional Cert                 378194
# Pre- Filing Date                       0
# Paid                                9073
# Fully Paid                          6583
# Assigned                          579162
# Approved                          329920
# Fully Permitted                   464955
# Initial Cost                           0
# Total Est. Fee                         0
# Fee Status                             0
# Existing Zoning Sqft                   0
# Proposed Zoning Sqft                   0
# Horizontal Enlrgmt               1730079
# Vertical Enlrgmt                 1743748
# Enlargement SQ Footage                 0
# Street Frontage                        0
# ExistingNo. of Stories                 0
# Proposed No. of Stories                0
# Existing Height                        0
# Proposed Height                        0
# Existing Dwelling Units          1131058
# Proposed Dwelling Units           856512
# Existing Occupancy                504491
# Proposed Occupancy                712472
# Site Fill                         350112
# Zoning Dist1                      334811
# Zoning Dist2                     1582219
# Zoning Dist3                     1765629
# Special District 1               1513629
# Special District 2               1695704
# Owner Type                         73395
# Non-Profit                         71548
# Owner's First Name                     3
# Owner's Last Name                      5
# Owner's Business Name              44180
# Owner's House Number             1774895
# Owner'sHouse Street Name         1774895
# City                             1774895
# State                            1774895
# Zip                              1774897
# Owner'sPhone #                     11467
# Job Description                   180171
# DOBRunDate                             0
# JOB_S1_NO                              0
# TOTAL_CONSTRUCTION_FLOOR_AREA          0
# WITHDRAWAL_FLAG                        0
# SIGNOFF_DATE                      710064
# SPECIAL_ACTION_STATUS              20208
# SPECIAL_ACTION_DATE              1603119
# BUILDING_CLASS                      6832
# JOB_NO_GOOD_COUNT                      0
# GIS_LATITUDE                        5661
# GIS_LONGITUDE                       5661
# GIS_COUNCIL_DISTRICT                5661
# GIS_CENSUS_TRACT                    5661
# GIS_NTA_NAME                        5661
# GIS_BIN                            22169
# Name: empty, dtype: int64

# %%
# Check the inconsistent datatype
# Now we can investigate the outliers issue in this dataset
profiles.multitype_columns().types()
# Out:
#                               date  float     int      str
# House #                        182      0    9830    25704
# Street Name                    459      0      20    29096
# Block                            0      0   13814        3
# Lot                              0      0    1967        4
# Job Status                       0      0       1       16
# Community - Board                0      0     105        1
# Other Description                0      4      43    16583
# Applicant's First Name           1      0       4    17362
# Applicant's Last Name            0      1       4    35231
# Applicant Professional Title     0      0      11      903
# Applicant License #              0      6   27031       63
# Approved                      6909      0       0        1
# Fully Permitted               6135      0       0        6
# Existing Dwelling Units          0      0    1079        3
# Proposed Dwelling Units          0      0    1168        5
# Proposed Occupancy               0      0       1       48
# Zoning Dist1                     0      0       1      229
# Zoning Dist2                     0      0      20      176
# Zoning Dist3                     1      0       0      134
# Special District 1               0      0       1      115
# Owner's First Name               0      3      64    93153
# Owner's Last Name                0      2      54   156930
# Owner's Business Name           19      1     209   412634
# Owner's House Number             1      0     406      142
# Owner'sPhone #                   0      6  359552      219
# Job Description                  0      1       9  1247478
# SIGNOFF_DATE                  5937      0       0        1

# %% [markdown]
# # Data Cleaning

# %%
from openclean.operator.transform.update import update
from openclean.function.eval.base import Col
from openclean.function.eval.datatype import IsDatetime
from openclean.function.eval.null import IsEmpty
from openclean.function.eval.null import IsNotEmpty
from openclean.function.eval.datatype import IsInt
from openclean.operator.transform.filter import filter
from openclean.function.eval.datatype import IsFloat
from openclean.function.eval.logic import And

# %% [markdown]
# ## Remove rows with empty/problematic values that are not possible to recover
#
# There are columns in this dataset that have empty or wrong values. Normally, we will try to recover the mnissing values. Yet, values in some columns are just not able to be infer from other values. In this case, we can only choose to remove those rows.

# %%
# As we can see in the profile result of "House #", there are a few rows without "House #".
# We decided to remove those rows.
profiles[4]
# Out:
# {'column': 'Street Name',
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 6,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 1774621, 'date': 1225, 'int': 46}),
#                'distinct': Counter({'str': 29096, 'date': 459, 'int': 20})}),
#   'minmaxValues': {'str': {'minimum': ',MYRTLE AVENUE',
#     'maximum': '`WEST 61ST ST'},
#    'date': {'minimum': datetime.datetime(100, 12, 11, 0, 0),
#     'maximum': datetime.datetime(2070, 12, 11, 0, 0)},
#    'int': {'minimum': 41, 'maximum': 248}},
#   'distinctValueCount': 29575,
#   'entropy': 11.613875273159815,
#   'topValues': [('BROADWAY', 52277),
#    ('PARK AVENUE', 29812),
#    ('MADISON AVENUE', 25099),
#    ('FIFTH AVENUE', 16968),
#    ('5 AVENUE', 14143),
#    ('LEXINGTON AVENUE', 12581),
#    ('AVENUE OF THE AMERICAS', 11717),
#    ('THIRD AVENUE', 10273),
#    ('3 AVENUE', 8267),
#    ('5TH AVENUE', 7934)]}}

# %%
# Remove rows where "House #" is null
ds_Update = ds_Full.filter(predicate=IsNotEmpty("House #"))

# %%
# As we can see in "Latest Action Date", there are date that is earlier than 2000-01-01. 
# However, the description of the dataset states that the "Latest Action Date"s are all later than 2000-01-01.
# Thus, we remove the rows with earlier dates.
profiles[12]
# Out:
# {'column': 'Building Type',
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 0,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 1775898}),
#                'distinct': Counter({'str': 2})}),
#   'minmaxValues': {'str': {'minimum': '1-2-3 FAMILY', 'maximum': 'OTHERS'}},
#   'distinctValueCount': 2,
#   'entropy': 0.75516121853754,
#   'topValues': [('OTHERS', 1390039), ('1-2-3 FAMILY', 385859)]}}

# %%
# Remove rows that have a "Latest Action Date" before "January 1, 2000".
from openclean.function.eval.datatype import Datetime
from datetime import datetime

ds_Update = ds_Update.filter(Datetime("Latest Action Date") >= datetime(2000, 1, 1))

# %%
#As the result, we can see that there are 5 rows where Applicant's First Name are integer type which is odd.
#Also, we can recognize that there are 32 empty values which is incorrect
#Thus, we will remove them
profiles[35]
# Out:
# {'column': "Applicant's First Name",
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 32,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 1775860, 'int': 5, 'date': 1}),
#                'distinct': Counter({'str': 17362, 'int': 4, 'date': 1})}),
#   'minmaxValues': {'str': {'minimum': '+EINING', 'maximum': 'zoilo'},
#    'int': {'minimum': 2, 'maximum': 7186054055},
#    'date': {'minimum': datetime.datetime(2021, 4, 11, 0, 0),
#     'maximum': datetime.datetime(2021, 4, 11, 0, 0)}},
#   'distinctValueCount': 17367,
#   'entropy': 9.286591559861831,
#   'topValues': [('MICHAEL', 51062),
#    ('JOHN', 44296),
#    ('ROBERT', 41772),
#    ('DAVID', 35926),
#    ('PAUL', 32699),
#    ('ANTHONY', 29891),
#    ('JAMES', 27116),
#    ('JOSEPH', 26997),
#    ('THOMAS', 24226),
#    ('PETER', 21929)]}}

# %%
#remove rows where "Applicant's First name" has the int value and empty value
ds_Update = ds_Update.filter(And(IsNotEmpty("Applicant's First Name"), Col("Applicant's First Name") != 2, Col("Applicant's First Name") != 2126202794, Col("Applicant's First Name") != 6312100, Col("Applicant's First Name") != 7186054055))

# %%
#As the result, we can observe that there are 1 value with 'nan' and other 4 values with integer as Applicant's Last Name which is odd.
#Thus, we will remove them
profiles[36]
# Out:
# {'column': "Applicant's Last Name",
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 0,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 1775893, 'float': 1, 'int': 4}),
#                'distinct': Counter({'str': 35231, 'float': 1, 'int': 4})}),
#   'minmaxValues': {'str': {'minimum': "'BRIEN", 'maximum': 'zori'},
#    'float': {'minimum': nan, 'maximum': nan},
#    'int': {'minimum': 1212, 'maximum': 420865380}},
#   'distinctValueCount': 35236,
#   'entropy': 11.501511970811501,
#   'topValues': [('HOQUE', 19156),
#    ('KATZ', 15137),
#    ('LEE', 14520),
#    ('RUDIKOFF', 12109),
#    ('GERAZOUNIS', 11126),
#    ('BAILEY', 10824),
#    ('CALIENDO', 9310),
#    ('CHEN', 9108),
#    ('SYED-NAQVI', 7297),
#    ('MASS', 6665)]}}

# %%
#remove rows where "Applicant's Last name" has the value other than string type
ds_Update = ds_Update.filter(And(Col("Applicant's Last Name") != 1212, Col("Applicant's Last Name") != 21029677, Col("Applicant's Last Name") != 420865380, Col("Applicant's Last Name") != 73020012, Col("Applicant's Last Name") != 'NAN', Col("Applicant's Last Name") != 73020012, Col("Applicant's Last Name") != 21029677))

# %%
#From the result, we cannot actually recognize the issue within this column but only empty values
#We will do some further research
profiles[37]
# Out:
# {'column': 'Applicant Professional Title',
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 37,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 1775847, 'int': 14}),
#                'distinct': Counter({'str': 903, 'int': 11})}),
#   'minmaxValues': {'str': {'minimum': "'", 'maximum': 'signhanger'},
#    'int': {'minimum': 0, 'maximum': 50069}},
#   'distinctValueCount': 914,
#   'entropy': 1.294960971716021,
#   'topValues': [('PE', 924799),
#    ('RA', 797144),
#    ('GC', 12762),
#    ('OT', 10657),
#    ('G.C', 5707),
#    ('CONTRACTOR', 3314),
#    ('DEMO CONTRACTOR', 2087),
#    ('DEMO', 1973),
#    ('PERMIT BROKER', 1765),
#    ('GEN CONTRACTOR', 1504)]}}

# %%
# Further research
# As the result, we can see that except empty values, there are a few rows with abnormal characters and also "N/A", "N/S", "None"
# Furthermore, we can see that most of the professional Title are related to job title or the name of their company
# Thus, we can conclude that the professional Title must not include integers
# Finally, we will remove them
ds_Full.distinct("Applicant Professional Title")
# Out:
# Counter({'RA': 797144,
#          'PE': 924799,
#          'OT': 10657,
#          'GEN CONTRACTOR': 1504,
#          'GC': 12762,
#          'CONTRACTOR': 3314,
#          'LA': 267,
#          'G.C': 5707,
#          'PLLC': 161,
#          'EXPEDIT(H66172)': 63,
#          'GEN. CONTRACTOR': 451,
#          'SIGN HANGER': 350,
#          'OWNER': 1228,
#          'Contractor': 1355,
#          'owner': 47,
#          'EXPEDITOR': 53,
#          'DEMO CONTRACTOR': 2087,
#          'PERMIT BROKER': 1765,
#          'Owner': 194,
#          'DEMO': 1973,
#          'SUBCONTRACTOR': 232,
#          'CONTR': 70,
#          'G.C.': 1492,
#          'G C': 94,
#          'SIGNHANGER': 65,
#          'General Contrac': 124,
#          'CG': 32,
#          'G CONTRACTOR': 93,
#          'DEMO CONTR': 476,
#          'G. CONTRACTOR': 177,
#          'GENERAL CONTRAC': 348,
#          'EXPEDITER/CONTR': 17,
#          'G.X': 2,
#          'GEN CONTR': 22,
#          'demo': 43,
#          'PERMIT AGENCY': 15,
#          '--': 3,
#          'Demo Contractor': 639,
#          'DEM CONTR': 18,
#          'LAND SURVEYOR': 131,
#          'G.C FEKETTE': 1,
#          'GEN.CONT': 80,
#          '050069': 1,
#          'General Cont.': 37,
#          'GEN CONT': 108,
#          'HOME OWNER': 47,
#          'DEMO CONT': 106,
#          '': 37,
#          'X': 534,
#          'contractor': 100,
#          'DEMO CONTRATOR': 18,
#          'OTHER': 38,
#          "GEN'L CONSTRUCT": 2,
#          'Demolition Cont': 242,
#          'Demo Contr': 59,
#          'gc': 60,
#          'SIGN PERMIT': 28,
#          'EXPEDITING/CONT': 5,
#          'DEM. CONTRACTOR': 11,
#          'Demo Cont.': 44,
#          'LRA': 7,
#          'G/C': 51,
#          'DEM. CONTR': 77,
#          'GEN.CONTR': 11,
#          'D.C': 7,
#          'CONTRACRTOR': 1,
#          'Demo Contr.': 65,
#          '13328': 1,
#          'CONTRACTER': 4,
#          'ARCHITECT': 5,
#          'Gen.Cont': 2,
#          'DEM CONTRACTOR': 32,
#          'DEMO-CONTRACTOR': 7,
#          'DEMO 1341946': 3,
#          'DC': 17,
#          'Gen. Contractor': 95,
#          'V': 67,
#          'GERNARAL CONTRA': 1,
#          'Constractor': 4,
#          'CC': 2,
#          'DEMO. CONTR': 105,
#          'DEMOL CONTR': 11,
#          'X 4129892': 1,
#          'DEMO CO': 1,
#          'GEN. CONT': 25,
#          'PASTOR': 4,
#          'GNE.CONT': 2,
#          'GC DEMO': 2,
#          'DEMOL. CONTR.': 1,
#          'PRESIDENT': 25,
#          'GC/Demo': 9,
#          'H.OWNER': 1,
#          'N/A': 31,
#          'DEM': 13,
#          'DEMO.CONT': 6,
#          'DEMOL. CONTR': 29,
#          'demo contractor': 24,
#          'GENERAL CONTR': 38,
#          'ONWER': 3,
#          'DEMO CONSTRUCT': 1,
#          'DEMOLITION CONT': 61,
#          'DEM CONT': 5,
#          'DEM. CONT': 3,
#          'GENERAL CONST': 8,
#          'MANAGING MEMBER': 7,
#          'SIGN PERMIT AGT': 248,
#          'Landscape Arch.': 8,
#          'Expediter': 8,
#          'LAND SUREYOR': 2,
#          'Gen Contractor': 36,
#          'HOMEOWNER': 66,
#          'Project Manager': 36,
#          'DM': 3,
#          'Pres.': 3,
#          'AGENT': 33,
#          'PERMOIT BROKER': 1,
#          'Demo': 12,
#          'GEN. CONT.': 79,
#          'LS': 8,
#          'SIGN PER AGENT': 3,
#          'NONE': 1,
#          'demo G.C.': 1,
#          'GEN.CONTRACTOR': 172,
#          'Husbannd': 1,
#          'general contrac': 17,
#          'Partner': 5,
#          'Officer': 9,
#          'REGSTR.LANDSCAP': 1,
#          'EXPEDITER': 26,
#          'GEN. CONST.': 13,
#          'DEMOL.CONTRCTR': 1,
#          'SIGN PERNIT AGT': 2,
#          'DEMOL.CONTR': 7,
#          'DEMO CONTRCTOR': 4,
#          'Developer': 5,
#          'CONT': 20,
#          'YES': 38,
#          'DEMLO': 1,
#          '..OWNER': 2,
#          '...GC': 6,
#          'DEVELOPER': 2,
#          'SIGN..HANGER': 1,
#          'home owner': 3,
#          'President': 7,
#          'Gen. Const.': 11,
#          'LIC CONTRACTOR': 1,
#          "Gen'l Contracto": 1,
#          'DemoContractor': 9,
#          'NA': 15,
#          'Permit  Broker': 5,
#          'CURB CUT': 3,
#          'DEMO CONTRACTIN': 2,
#          'GEN': 1,
#          'SIGN PERMIT AGE': 27,
#          'Gen. Cont.': 91,
#          'SIGN PERMIT AGN': 2,
#          'EQ': 1,
#          'SIGN PERMIT ANT': 1,
#          'LANDSCAPE ARCHI': 13,
#          'Homeowner': 5,
#          '.........GC': 1,
#          'G .C': 2,
#          '.GC': 6,
#          'DEMO CONTRACT': 29,
#          'RLA - 818': 1,
#          'Owners': 2,
#          'LAND SURVEYING': 5,
#          '?': 1,
#          'Contactor': 1,
#          'DEMO. CONTRACTO': 27,
#          'Demo. Contr.': 8,
#          'Expeditor': 4,
#          'Demolitin Cont': 1,
#          'DEMO CNTR': 1,
#          'OWNET': 1,
#          '.DEMO': 1,
#          'general con.': 2,
#          'Home Owner': 6,
#          'General Super.': 1,
#          'HOME IMPROVEMEN': 1,
#          'DEMOLITION CON': 5,
#          'G.E': 1,
#          'G.C/SIGN HANGER': 1,
#          'OWNER/CONTACTOR': 3,
#          'CONTRACTOR/OWNE': 2,
#          'OWNER/CONTRACTO': 7,
#          'CONSTRACTOR': 12,
#          'DEMO CONST': 27,
#          'DEM. CONSTR': 3,
#          'LAND SUREYVOR': 1,
#          'DEMOLITION.CONT': 1,
#          'DEMO. CONTRE': 1,
#          'DEM. CONTR,': 1,
#          'CONTRACOR': 8,
#          'GENERAL CONT': 7,
#          'GEN, CONSTR': 1,
#          'LESSEE': 3,
#          'GEN.CONTRACT': 1,
#          'GEN CONST': 9,
#          'GE': 4,
#          'CONTRACTRO': 1,
#          'GEN. CONTR': 11,
#          '082-36-1245': 1,
#          'CONST. MGR': 1,
#          'MASTER PLUMBER': 5,
#          'REG. LANDSCAPE': 1,
#          'GEN CONT,': 1,
#          'PROF.LAND.SURVE': 1,
#          'GEN  CONTRACTOR': 5,
#          'GEN. CONST': 2,
#          'landscape archi': 1,
#          'CONTRACTO': 5,
#          'DEMO  CONTRACTO': 1,
#          'ASSISTANT OFFIC': 1,
#          'ASST. OFFICER': 1,
#          'EXPED/SIGN HANG': 1,
#          'OWNER CONTRACTO': 1,
#          'LESSE': 1,
#          'PROFESSIONAL LA': 1,
#          'GEN CONTRACTORS': 1,
#          'GENERAL CONTR.': 13,
#          'CONTRACTROR': 1,
#          'LICENSED LAND': 2,
#          'CONTACTOR': 6,
#          'HOUSE OWNER': 1,
#          'LEESEE': 1,
#          'GENRAL CONTRACT': 3,
#          'CONTRACTATOR': 1,
#          'LESEE': 1,
#          'CONTRATOR': 13,
#          'SIGN MANGAGER': 1,
#          'CONTARACTOR': 1,
#          'AWNING': 3,
#          'CONTRACTORT': 1,
#          'CONTRACTOR 1340': 1,
#          'PROPERTY OWNER': 1,
#          'CONSTRUCTION': 13,
#          'SIGN HAMGER': 1,
#          'Gen.Contractor': 3,
#          'GERNERAL CONTRA': 2,
#          'SIGN': 22,
#          'LANDSURVEYER': 1,
#          'CONTRACTR': 1,
#          'CONTRACOTR': 2,
#          'GENERAL': 2,
#          'DEM CONTRACTION': 1,
#          'GENERAL CONST.': 3,
#          'DEMO CONTRACTO': 6,
#          'DEMO CONSTRUCTI': 3,
#          'DEM.CONTR': 4,
#          'G,C': 12,
#          'GEN.COTNRACTOR': 1,
#          'DEM.CONTRACTOR': 9,
#          'LAND SUREVOR': 1,
#          'GENERAL  CONTRA': 1,
#          'GEN CONTRRACTOR': 1,
#          'Gen. Con.': 2,
#          'AWNING SIGN': 2,
#          'AWNING/SIGN CON': 5,
#          'Gen Constr.': 1,
#          'DEMO.CONTRATOR': 1,
#          'CONTRACTING': 13,
#          'AWNING/CONT': 1,
#          'GEN. COTRACTOR': 1,
#          'CONTRACTORR': 2,
#          'CONTRACTORS': 11,
#          'EXPEDITIOR': 1,
#          'EXPEIDTOR': 1,
#          'EPEDITER/CONTRA': 1,
#          'DEM. CONTR.,': 1,
#          'EXPEDITER DD886': 1,
#          'CONTRAVTOR': 1,
#          'EXPEDTING': 1,
#          'sign hanger': 17,
#          'EXPEDITING': 4,
#          'LAND SURVEIOR': 1,
#          'EXPEDITING SERV': 1,
#          'DEMO CNOTRACTOR': 1,
#          'GEN.CNOTRACTOR': 1,
#          'SIGN COURT': 1,
#          'GEN .CONT': 6,
#          'SIGN HANGE': 10,
#          'OTHER SIGNS': 1,
#          'EXPED/CONTRAC': 1,
#          'CONTRACTOR DEM': 1,
#          'CONRACTOR': 2,
#          'DEMO.CONTRACTOR': 9,
#          'EXPEDITOR/CONT': 7,
#          'GEN. CONTRACT': 1,
#          'EXPEDITOR/CONTR': 21,
#          'EXPEDTING/CONTR': 1,
#          'CONTRACTOR{': 1,
#          'CNOTRACTOR': 1,
#          'EXPEDITOR/CONTA': 1,
#          'GEN.CONTRACTO': 1,
#          'GEN;.CONTRACTOR': 1,
#          'EXPEDITOR/CON': 4,
#          'EXPED/CONTR': 4,
#          'GEN. CONSTR': 1,
#          'GEN..CONTRACTOR': 2,
#          'GEN..CONT': 3,
#          'GC 1028350': 1,
#          'PERMIT BROOKER': 3,
#          'PERT BROKER': 1,
#          'TRUE': 1,
#          'G. C': 18,
#          'GEN.COTRACTOR': 2,
#          'CONT/EXPEDITOR': 1,
#          'EXPEDITOR CONTR': 1,
#          'DEM CONTRATOR': 2,
#          'LAND SURVEYER': 3,
#          'CONTRACTOR 1012': 1,
#          'GEN  CONT': 2,
#          'GEM CONTRACTOR': 1,
#          'Contractors': 3,
#          'GENERAL CONTRA': 6,
#          '11234': 1,
#          'EXPEDOTOR/CON': 1,
#          'True': 1,
#          'EXPEDOTIR/CONTR': 1,
#          'EXP/CON': 2,
#          'General COntrac': 13,
#          'GENERALCONTRACT': 2,
#          'G.C.,': 1,
#          'PERMIT': 3,
#          'SIGN AGENT': 9,
#          'DEMO CONSTR': 6,
#          'EX': 3,
#          'GENERAL CONT.': 35,
#          'General': 8,
#          'DEMO COTRACTOR': 1,
#          'G. C.': 129,
#          'SIGN COMPANY': 7,
#          'GEN.CCONT': 1,
#          'G': 4,
#          'general const.': 9,
#          'Demo. Contracto': 6,
#          'Demo contractor': 11,
#          'AWNING CONT': 3,
#          'CONSTRUCTION/EX': 1,
#          'expediter': 1,
#          'Home Improv.': 2,
#          'SIGN OERMIT AGE': 1,
#          'EXPEDITER/CONT': 1,
#          'SIGN PERMIT AG': 8,
#          'GEN CONTRACTER': 1,
#          'GENRAL.CONTRACT': 1,
#          '00': 1,
#          'Gen Cont': 59,
#          'PERMITS BROKER': 1,
#          'Demo-Contractor': 7,
#          'GEN CONT.': 1,
#          'GENERAL   CONTR': 3,
#          'PROF. LAND SURV': 2,
#          'MANAGEING AGENT': 1,
#          'GIC': 1,
#          'COTRACTOR': 9,
#          'RLA': 22,
#          '029649': 1,
#          'EXPEDITORC99792': 2,
#          'COTNRACTOR': 4,
#          'ADMINST': 1,
#          'GENERAL CONTRAT': 5,
#          'EXPED.R4466': 6,
#          'DEMO CONTRACYOR': 1,
#          'G.CONTRACTOR': 5,
#          'CONTRACTOR`': 2,
#          'JHJK': 1,
#          'g. contractor': 60,
#          'LS 31,721': 1,
#          'g. constractor': 7,
#          'GEN.CON': 38,
#          'C.C': 1,
#          'g.contractor': 3,
#          'DEMO. CONTRACT': 7,
#          'Gen. Constr.': 4,
#          'OWNER/EXPEDITOR': 2,
#          'EXPEDITOR/OWNER': 1,
#          'ARCH': 1,
#          'CONTROCTOR': 1,
#          'DEMO CONTACTOR': 4,
#          'DEMOO CONTRACT': 1,
#          'Demo Const.': 1,
#          'GC.': 3,
#          'g. contrator': 1,
#          'DEMCONTRACTOR': 1,
#          'SURVEYOR': 13,
#          'GENERAL CONSTRU': 3,
#          'GEN, CONTR': 1,
#          'BC': 1,
#          'BROOKLYN': 1,
#          'DEMO CONSTRUCTO': 1,
#          'General Constru': 18,
#          'DEMO CONTRA': 7,
#          'EXP': 35,
#          'GENERAL CONTRCT': 1,
#          'GENERAK CONTRAC': 1,
#          'DEMO CON': 2,
#          '10457': 1,
#          'GENER. CONTRACT': 1,
#          'GENERAL CONTRAR': 2,
#          'DEMO COMTRACTOR': 1,
#          'Demo Contracter': 25,
#          'GENERAL CNCTR': 2,
#          'GENERAL CNTRC': 1,
#          'GENERAL CNTRACT': 1,
#          'DEMO CONTACRTOR': 1,
#          'GENERAL CONTRCR': 2,
#          'GENERAL CONTRC': 1,
#          'DEMO CONTRAC': 7,
#          'DEMO CONT.': 4,
#          'Greneral Const.': 1,
#          'CONTRACTOR SPEN': 1,
#          'EXPEDITER /CONT': 2,
#          '32820': 1,
#          'General Contra.': 2,
#          'Demolition': 3,
#          'DEMO CONTRACTIO': 2,
#          'CNTRACTOR': 1,
#          'CONTRUCTION': 1,
#          'gen contractor': 3,
#          'XXXXXX': 1,
#          'XXXXX': 1,
#          'Demolition Co.': 4,
#          'Vice-President': 2,
#          'GEN CON': 2,
#          'DEMOL. CONTRA': 1,
#          '0WNER': 1,
#          'DEMOLIT.CONSTRA': 1,
#          'SIAGN AGENT': 1,
#          'DENO CONACTOR': 1,
#          'GENERAL CON': 2,
#          'GC 1221073': 1,
#          'GEN.CONT.': 1,
#          'GENERAL CONSTAC': 1,
#          'DEMOLITION CON.': 1,
#          'DEMOLITION': 47,
#          'DEMO CONTRUCTIO': 1,
#          'general con': 1,
#          'CONTRACT': 3,
#          'HOME OWNERS': 1,
#          'DEMO CONSTRACTI': 1,
#          'General Contrca': 5,
#          'DEMO. CONTRAC': 3,
#          'Office': 5,
#          'Demo Cont': 2,
#          'gen. contractor': 2,
#          'PERMIT.BROKER': 1,
#          'AGENCY': 12,
#          'C0NTRACTOR': 1,
#          'gen. conctrator': 1,
#          'DEMO CONTR.': 4,
#          'DEMO CONSTRACTO': 4,
#          'DEMO CONSTRACT': 3,
#          'Demol. Contract': 2,
#          'T. 31132': 1,
#          'CONSTACTOR': 1,
#          'Agent': 40,
#          'Project manager': 1,
#          'DEMOS': 1,
#          'ot': 2,
#          'DEMOLITION G.C.': 2,
#          "OWNER'S REP": 1,
#          'GenContractor': 2,
#          'PRMIT BROKER': 2,
#          'DEMO CONTRACTER': 3,
#          'CON': 1,
#          'OWENR': 2,
#          'CONTRACTER 1167': 1,
#          'G.C 1037579': 1,
#          'GC(DEMO)': 2,
#          'SIGN CONTRACTOR': 3,
#          'Demo Agent': 4,
#          'GEN.CONSTRUCTIO': 1,
#          'SIGN CONTR': 2,
#          'DEMOLITON CONTR': 3,
#          'Gen. Cont': 1,
#          'DEMOLITONER': 1,
#          'GERAL CONTRACTO': 1,
#          'Other': 1,
#          'gen cont': 1,
#          'DEMO-HPD': 1,
#          'Demo.': 1,
#          'DEMO CONRTACTOR': 1,
#          'GARAGE': 1,
#          'owners': 1,
#          'DEMO CONRACTOR': 1,
#          'D C': 2,
#          'DEMO  CONTRACT': 1,
#          'DEMO, CONTR': 1,
#          'DEM, CONTR': 1,
#          'demolition': 2,
#          'DEMOLOLITION': 1,
#          'SIGN PERMIT SGT': 1,
#          'SIGN HANGER TOU': 1,
#          'oWNER': 1,
#          'SI': 13,
#          'LAND SURV': 4,
#          'OWNER/CONTRA': 1,
#          'PROF LAND SUR': 8,
#          'LAND SUR': 7,
#          '16294': 1,
#          'PROF. LAND SUR': 1,
#          'DEMO OCNTRACTOR': 12,
#          'DEMO GC': 4,
#          'L.S': 3,
#          'SIGN PERMIT HAN': 2,
#          'SIHN PERMIT AG': 1,
#          'GVC': 1,
#          'LIC LAND SUV': 1,
#          'LIC LAND SURV': 1,
#          'SAME': 3,
#          'LIC LAND SUR': 4,
#          'DEMO CONTRACOR': 2,
#          'CONSSTRACTOR': 1,
#          'DEMO CONTRATCOR': 2,
#          'DEOM CONTRACTOR': 3,
#          'LICENSED LAND S': 1,
#          'LAND SURVEYOE': 1,
#          'GC DHILLOM': 1,
#          'GEN CONS': 1,
#          'GS': 1,
#          'DEMO CONTRAVTOR': 1,
#          'SIGN HANGER SSH': 1,
#          'DEO CONTRACTOR': 1,
#          'CONTRACTOR 13-3': 1,
#          'CONTRACTOR 13-4': 1,
#          'CONSTRUCTOR': 1,
#          'CONST': 3,
#          'CONTRACTOOR': 3,
#          'CONTAINER': 1,
#          'CONTRAACTOR': 3,
#          'HOMEOWNWER': 1,
#          'SURYOR': 1,
#          'SURVOR': 1,
#          'DEMO CONTARCTOR': 3,
#          'SIGN PERM.AGENT': 3,
#          'SIGH PERM.AGENT': 1,
#          'SIGN.AGENT': 1,
#          'CONTRACTIR': 1,
#          'CONTRATCING': 1,
#          'LICENSED SURVEY': 1,
#          'LIC.133668259 1': 1,
#          'CONTRCATOR': 2,
#          'CONTRACTOR 1341': 8,
#          'LIC.LAND SURVEY': 14,
#          'CONTRACTOR 2037': 1,
#          'CONTRUCTOR': 1,
#          'LLS': 1,
#          'SURVEYER': 4,
#          'LANDSURVEYOR': 1,
#          'LIC.SURVEYOR': 1,
#          'DENO': 1,
#          'LIC LAND SURVEY': 1,
#          'G.C 1341082': 1,
#          'G.C 2037982': 1,
#          'LLP': 8,
#          'X 1341946': 1,
#          'CEMO CONTRACTOR': 1,
#          'LLC': 3,
#          'CINTRACTOR': 1,
#          'DENO CONTRACTOR': 1,
#          'Treasurer': 3,
#          'PLLLC': 2,
#          'SIGH PERMIT AGT': 1,
#          'DEMO CONTRACTOE': 3,
#          'DOMO CONTRACTOR': 1,
#          'CONTRACTTOR': 1,
#          'LandscapeArchit': 1,
#          'OWWNER': 1,
#          'PLS': 12,
#          'DEMO/CONTRATOR': 2,
#          'DEMO/CONTRACTOR': 1,
#          'GENERAL CONRTAC': 1,
#          '23392 1159774': 1,
#          'CONTRACROR': 1,
#          'D CONTRA': 1,
#          'D CONTRACTOR': 6,
#          'GC/OWNER': 2,
#          'P;;C': 1,
#          'CONTACTOR 11330': 1,
#          'DEMO 20451': 1,
#          'DEMO  CONT': 1,
#          'DEMP CORTRACTOR': 1,
#          'HO': 2,
#          'PCCL': 1,
#          'PLLS': 1,
#          'G.C 1341946': 1,
#          'OLLC': 1,
#          'DEMO CORNT': 1,
#          'CONTRA': 1,
#          'P.L.L.C': 2,
#          'SIGN PERMIT AGY': 2,
#          'PLLC 9599691': 1,
#          'LICENSE SURVEYO': 1,
#          'DEMON CONTR': 1,
#          'OG': 1,
#          'SGN PERMIT AGT': 1,
#          'GR': 1,
#          'H.O': 1,
#          'DEMO CNTRACTOR': 1,
#          'GENERAL CONSTRA': 1,
#          'LEGALIZATION': 1,
#          'DEMO. CONT': 4,
#          'PERMIT BRKER': 1,
#          'SIGN MAKER': 4,
#          'PATNERSHIP': 1,
#          'GCX': 38,
#          'GC\\': 1,
#          'SIGN CONT': 6,
#          'AGT': 3,
#          'GX': 2,
#          'PRES': 2,
#          'AGENT FOR OWNER': 1,
#          'Site Safety Mgr': 2,
#          'PERMIT HILLS': 2,
#          'SUB CONTR': 2,
#          'SUDCONTRACTOR': 1,
#          'CONSTER': 1,
#          'GRD': 1,
#          'S PERMIT AGT': 4,
#          'RIA': 1,
#          "GC'": 5,
#          'PERMIT  BROKER': 1,
#          'GTC': 3,
#          'M.F.S.P.C.': 1,
#          'C': 3,
#          '.X': 4,
#          'HOME IMPRMT CON': 1,
#          'signhanger': 5,
#          'L ARCH': 3,
#          '`GC': 2,
#          'G.G': 4,
#          'GEC CON': 1,
#          'L A': 1,
#          'DEMO.CON': 1,
#          'GXC': 1,
#          'SUB': 3,
#          'COPNTR': 1,
#          'LAND SWURVEYOR': 1,
#          'EXPED': 5,
#          "GC;'": 1,
#          'GC¦': 3,
#          'SHED CONT': 2,
#          'GCC': 1,
#          'SSP': 1,
#          'SUBCON': 1,
#          'DEM CONTRA': 1,
#          'S PERMIT SGT': 1,
#          'PERMITN BROKER': 1,
#          'VICE PRESIDENT': 1,
#          'filing rep': 1,
#          'SHED': 6,
#          'SCAFFOLD': 1,
#          'APPLICANT': 3,
#          'SCAFFOLDING': 4,
#          'PARTNER': 2,
#          'LANDSCAPE ARCH': 16,
#          'PERMITBROKER': 1,
#          'L ARCHTECT': 1,
#          '1GC': 1,
#          'g.c': 2,
#          'MASTER RIGGER': 1,
#          'g.c.': 7,
#          'OWNER REP': 2,
#          'PEERMIT BROKER': 2,
#          'CODE CONSULQANT': 1,
#          'G.N': 1,
#          'HOME IMPROVEMT': 1,
#          'SIGN HANGER NY1': 1,
#          'GC 2293': 1,
#          'R.L.A': 3,
#          'SIGN CONST': 2,
#          'SIGN AHNGER': 4,
#          'AWNING/CONST': 3,
#          'LANDSCAPE ARCH.': 4,
#          'Demolition Con': 7,
#          'PERMIT AGENT': 1,
#          'LSNDSCAPE ARCH': 1,
#          'CONMTRACTOR': 1,
#          'SHED INSTALLER': 1,
#          'Gen. Constr': 8,
#          'G.C NY11101': 1,
#          'CONSTR/CONTRAC': 1,
#          'Sign Hanger': 2,
#          'Gen Constr': 1,
#          'SIG HANGER': 1,
#          'LANDSCAPE': 1,
#          'AWNING/SIGN COR': 1,
#          'SOIGN PERMIT AG': 1,
#          'PERMITSIGN AGT': 1,
#          'SIGN HANGR': 1,
#          'LANDSCPAE ARCHI': 1,
#          'EXPD/CONTRACTOR': 2,
#          'SIGN POERMIT AG': 1,
#          'SEC/TREAS': 1,
#          'GEMERAL CONTRAC': 1,
#          'General Contr.': 10,
#          'PEMIT BROKER': 1,
#          '1390': 4,
#          'SH': 31,
#          'G.CONTR.': 1,
#          'SIGNH HANGER': 1,
#          'SIIGNHANGER': 1,
#          'BROKER': 6,
#          'SINGHANGER': 1,
#          'CONTRACTOR/EXPE': 1,
#          'CONTACTOR EXPED': 1,
#          'PERMIT BEROKER\\': 1,
#          'GEN. CONTR.': 1,
#          'PB': 27,
#          'Plan Promoter': 2,
#          'Gen Con': 3,
#          'SIGN HANER': 1,
#          'PERMIT SIGN AGT': 1,
#          'EXPT/CONTR': 1,
#          'GN CON': 2,
#          'BX': 1,
#          'SIGN H': 1,
#          'applicant': 14,
#          'SIGN PERMITS AG': 3,
#          'EXPEDTOR': 1,
#          'P.M.': 1,
#          'PERMIT BORKER': 1,
#          'D8615': 4,
#          'PERMIT BROKLER': 1,
#          'SPECIAL RIGGER': 1,
#          'F.C': 1,
#          'G.C 1110101': 1,
#          'FIRE PROPT PLAN': 1,
#          'SECRETARY': 1,
#          'FENCE': 2,
#          'GENERAL CONSTR': 1,
#          "GENE'L CONSTRUC": 1,
#          'DEMO CNTRCTR': 4,
#          'SA': 3,
#          'DEMO G C': 2,
#          'SP': 19,
#          'SING PERMIT AGE': 1,
#          '0215': 1,
#          'PM': 2,
#          'S': 1,
#          'OFFICE SITE FIL': 1,
#          "'": 1,
#          'Landscape Arch': 2,
#          'PS': 2,
#          'General Contr': 3,
#          '....DEMO': 3,
#          'LD': 2,
#          'P.B': 1,
#          'SING': 1,
#          'PERMIT BROKERS': 1,
#          'SPA': 12,
#          'gen. cont': 1,
#          '(CHECK)': 2,
#          'G. Contractor': 5,
#          'SHP': 1,
#          'DEMOCONTRACTOR': 1,
#          'gen constructio': 2,
#          'RLA-787': 1,
#          '(CHECKED)': 6,
#          'SING PERMIT AGT': 1,
#          'SAP': 1,
#          'Fence': 1,
#          'PPERMIT BROKER': 1,
#          'GB': 1,
#          'P': 1,
#          'GV': 2,
#          'CHECKED': 20,
#          'SIGN PMTS AGENT': 1,
#          'SIGN PMT AGT': 1,
#          'LANDSCAPE ARCHT': 2,
#          'SUB-CONTRACTOR': 5,
#          'DEMOLATION': 1,
#          'G.C 1194355': 1,
#          'SIG PERMIT AGT': 1,
#          'PERMOT BROKER': 1,
#          'GEN. CONSTRUCT': 1,
#          'Permit Broker': 1,
#          'gen.cont.': 1,
#          'CONTAACTOR': 1,
#          'DESIGN/CONSULTA': 1,
#          'HIC': 6,
#          'agent': 1,
#          'SUBCONTR': 1,
#          'LAND SURVEY': 5,
#          'DEMO/CONTR': 3,
#          'REGISTERED LAND': 1,
#          'GENERAL CNTRCTR': 4,
#          'G/X': 1,
#          'G/C 10114H9': 1,
#          'HOMEOWNERS': 1,
#          'HOMOWNER': 1,
#          'WC10114H99': 2,
#          'CGWC10114H99': 1,
#          'LEAE': 1,
#          'DEMOLITION C': 1,
#          'CTR': 4,
#          'D/CONT': 2,
#          'CNTR': 1,
#          'TRACK #1390': 1,
#          '.OWNER': 1,
#          'DEMO CONT CRICH': 1,
#          'PREMIT BROKER': 1,
#          'TRACK. #1390': 1,
#          'CO0OWNER': 1,
#          'G.C TK#4592': 5,
#          'S.H': 2,
#          'DEMOCONT': 1,
#          'EMO CONTRACTOR': 1,
#          'C10892': 2,
#          'OWNERS': 1,
#          'GENRAL CONSTRAC': 1,
#          'GENERLA CONT': 1,
#          'DEM. CONTRACT': 4,
#          'REG. AGENT': 2,
#          'SIHN HANGER': 1,
#          'N/S': 1,
#          'DEMON CONRACTOR': 1,
#          'SAND SURVEYOR': 1,
#          'Consultant': 1,
#          'Demoltion Contr': 1,
#          'GEN CONTACTOR': 1,
#          'DEC': 2,
#          'GCV': 1,
#          'CITY OF N Y': 2,
#          'Gen. Contr.': 1,
#          'HPD': 1,
#          'General Const.': 1,
#          'agent for owner': 1,
#          'OWNER/CONTRACT': 1,
#          'GENERAL CONTACT': 1,
#          'SUPER': 1,
#          '378': 1,
#          'SITE-SAFETY': 1,
#          'RLA 16077': 1,
#          'GC 1170386': 1,
#          'PROFES LAND SUR': 1,
#          'GA': 4,
#          'PERMIT BROKER.': 1,
#          'PERMITT BROKER': 1,
#          'SITE SAFETY COR': 1,
#          'SIGN /CONT': 1,
#          'General contrac': 2,
#          'DEMOCONTR': 1,
#          'OWER': 1,
#          'DEMO.CONTR': 1,
#          'DEMOLCONTRACTOR': 1,
#          'CONTRACTOR VASA': 1,
#          'DEMO {': 1,
#          'OW NER': 1,
#          'DEMO SANTANT': 1,
#          'SC': 1,
#          'DEMOO': 1,
#          'GENRL CONTRACTR': 2,
#          'OWNER VASAPOL': 1,
#          'GC CRICHLO': 1,
#          'DEMO CONTR STEL': 1,
#          'PARKING ACCESSO': 1,
#          'gen. contrctr': 1,
#          'GENERAL CONSTRC': 1,
#          'G.C NEGRON/': 1,
#          'DEMO ONTR': 1,
#          'SIGN PERMITS': 2,
#          '......GC': 2,
#          'GNRAL CONTRACTR': 3,
#          'DEM CONST': 1,
#          'X S000155': 4,
#          'LAND SURVERYOR': 1,
#          'G.C.CONTRACTOR': 1,
#          '..DEMO': 1,
#          '....GC': 4,
#          'DEMO¦': 1,
#          'GC/DEMO': 1,
#          'Demo Cntractor': 2,
#          'CONTRACTOR DEMO': 1,
#          'Home owner': 1,
#          '....OWNER': 1,
#          '...DEMO': 1,
#          'DEMILITION': 1,
#          'CONTRACTOR YHOM': 1,
#          '.....OWNER': 1,
#          'GC BOAHENE': 1,
#          'Gen. Contract': 1,
#          'TRACK# 1390': 2,
#          'CONSULTANT': 1,
#          'gen. con.': 1,
#          'Gen Con.': 1,
#          'Gen.Con': 2,
#          'SURVEYING': 1,
#          '..GC': 3,
#          'SIGN AGT': 1,
#          'GEN CONRT': 1,
#          '.....GC': 1,
#          'member': 2,
#          '.LAND SURVEYIN': 1,
#          'SIGN PERIT AGT': 1,
#          'DEM CON': 2,
#          'gen const': 1,
#          '..SIGN HANGER': 1,
#          'DEM CONTRACT': 1,
#          'LAND SURYER': 1,
#          'LAND SURYVER': 1,
#          'G, Contractor': 1,
#          'G.C CRICHLO': 1,
#          'DEM GC': 2,
#          'CENERAL CONT': 2,
#          'SIGN INSTALLER': 1,
#          'DEMO CONTRACROR': 1,
#          'C.G': 1,
#          'HEALTH': 1,
#          'HELP': 1,
#          'SIGN PERNTI AGT': 1,
#          'HOME OWNR': 1,
#          'DEMOR': 1})

# %%
#remove rows where "Applicant Professional Title" has the int value, abnormal value and empty value
ds_Update = ds_Update.filter(And(IsNotEmpty("Applicant Professional Title"), Col("Applicant Professional Title") != '00', Col("Applicant Professional Title") != '0215', Col("Applicant Professional Title") != '029649', Col("Applicant Professional Title") != '050069', Col("Applicant Professional Title") != '10457', Col("Applicant Professional Title") != '11234', Col("Applicant Professional Title") != '13328', Col("Applicant Professional Title") != '1390', Col("Applicant Professional Title") != '16294', Col("Applicant Professional Title") != '32820', Col("Applicant Professional Title") != '378', Col("Applicant Professional Title") != 'N/A', Col("Applicant Professional Title") != 'N/S', Col("Applicant Professional Title") != 'NONE', Col("Applicant Professional Title") != '?', Col("Applicant Professional Title") != '--', Col("Applicant Professional Title") != "'" ))

# %%
#We can see that there is a row with datetime that is outliers. We will remove it (60/20/2021)
profiles[44]
# Out:
# {'column': 'Approved',
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 329920,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'date': 1445977, 'str': 1}),
#                'distinct': Counter({'date': 6909, 'str': 1})}),
#   'minmaxValues': {'date': {'minimum': datetime.datetime(1992, 10, 21, 0, 0),
#     'maximum': datetime.datetime(2021, 12, 10, 0, 0)},
#    'str': {'minimum': '60/20/2001', 'maximum': '60/20/2001'}},
#   'distinctValueCount': 6910,
#   'entropy': 12.410716187369031,
#   'topValues': [('06/26/2008', 663),
#    ('06/25/2008', 529),
#    ('06/27/2019', 521),
#    ('06/28/2019', 514),
#    ('05/21/2015', 500),
#    ('11/10/2005', 476),
#    ('12/03/2015', 474),
#    ('08/03/2016', 446),
#    ('10/11/2017', 444),
#    ('09/30/2016', 442)]}}

# %%
#remove the row with abnormal date in "Approved" that recognized as string type
ds_Update = ds_Update.filter(Col("Approved") != '60/20/2001')

# %%
#As we can see from the result, there are 6 rows that having datetime outliers so it was converted to string type. We will remove them
profiles[45]
# Out:
# {'column': 'Fully Permitted',
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 464955,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'date': 1310937, 'str': 6}),
#                'distinct': Counter({'date': 6135, 'str': 6})}),
#   'minmaxValues': {'date': {'minimum': datetime.datetime(1209, 3, 20, 0, 0),
#     'maximum': datetime.datetime(3008, 3, 31, 0, 0)},
#    'str': {'minimum': '02/0/2012', 'maximum': '85/09/2010'}},
#   'distinctValueCount': 6141,
#   'entropy': 12.365721303823369,
#   'topValues': [('11/12/2015', 487),
#    ('05/17/2017', 439),
#    ('11/15/2016', 439),
#    ('07/25/2017', 435),
#    ('11/04/2015', 429),
#    ('08/15/2001', 429),
#    ('11/06/2013', 429),
#    ('11/09/2006', 425),
#    ('09/13/2016', 422),
#    ('11/09/2017', 421)]}}

# %%
#remove the 6 rows in "Fully Permitted" that have abnormal date which recognized as string type
ds_Update = ds_Update.filter(IsDatetime("Fully Permitted"))

# %%
#As the result, we can see that there are 4 rows that has value which is abnormal character. We will remove them
profiles[59]
# Out:
# {'column': 'Existing Dwelling Units',
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 1131058,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'int': 644836, 'str': 4}),
#                'distinct': Counter({'int': 1079, 'str': 3})}),
#   'minmaxValues': {'int': {'minimum': 0, 'maximum': 52121},
#    'str': {'minimum': '.', 'maximum': '....4'}},
#   'distinctValueCount': 1082,
#   'entropy': 5.977224770103707,
#   'topValues': [('1', 118145),
#    ('2', 95195),
#    ('0', 40080),
#    ('3', 28820),
#    ('4', 20867),
#    ('6', 16949),
#    ('8', 15408),
#    ('5', 9768),
#    ('10', 9575),
#    ('20', 9306)]}}

# %%
#remove the 4 rows in "Existing Dwelling Units" that include abnormal characters
ds_Update = ds_Update.filter(IsInt("Existing Dwelling Units"))

# %%
#As the result, we can see that there are 6 rows which has abnormal values including "NONE". We will remove them
profiles[60]
# Out:
# {'column': 'Proposed Dwelling Units',
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 856512,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'int': 919380, 'str': 6}),
#                'distinct': Counter({'int': 1168, 'str': 5})}),
#   'minmaxValues': {'int': {'minimum': 0, 'maximum': 52121},
#    'str': {'minimum': '.', 'maximum': 'NONE'}},
#   'distinctValueCount': 1173,
#   'entropy': 5.684398162740477,
#   'topValues': [('1', 172367),
#    ('2', 166523),
#    ('3', 57942),
#    ('0', 38886),
#    ('4', 30846),
#    ('6', 24245),
#    ('8', 23538),
#    ('5', 14771),
#    ('10', 14424),
#    ('20', 12757)]}}

# %%
#remove the 6 rows in "Proposed Dwelling Units" that include abnormal characters or None value
ds_Update = ds_Update.filter(IsInt("Proposed Dwelling Units"))

# %%
# As the result, we can see that there are 1 row which is integer 1 and is not existed in the "Existing Occupancy".
# Therefore, we can conclude that this is the archive data, we can remove it
profiles[62]
# Out:
# {'column': 'Proposed Occupancy',
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 712472,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 1063425, 'int': 1}),
#                'distinct': Counter({'str': 48, 'int': 1})}),
#   'minmaxValues': {'str': {'minimum': '.RES', 'maximum': 'U'},
#    'int': {'minimum': 1, 'maximum': 1}},
#   'distinctValueCount': 49,
#   'entropy': 3.6478079442382008,
#   'topValues': [('RES', 290176),
#    ('COM', 169571),
#    ('J-3', 82431),
#    ('R-3', 79845),
#    ('J-2', 75153),
#    ('R-2', 74802),
#    ('E', 74087),
#    ('B', 38291),
#    ('PUB', 26799),
#    ('C', 17271)]}}

# %%
#remove the row in "Proposed Occupancy" with Occupancy that is "1"
ds_Update = ds_Update.filter(Col("Proposed Occupancy") != 1)

# %% [markdown]
# ## Data Standardization
#
# In some case, different values may actually represent the same thing. For example, "5th Avenue" and "Fifth AVE" both point to "5th AVE". Thus, we need to standardize the data.

# %%
# Street name is a example that needs to be standardized. 
# Uncomment the lines below and see the clustering of the street names.

'''
from openclean.cluster.key import KeyCollision
from openclean_geo.address.usstreet import USStreetNameKey

street_names = ds_Update.update('Street Name', str.upper).distinct('Street Name')
clusters = KeyCollision(func=USStreetNameKey(), threads=3).clusters(street_names)

def print_k_clusters(clusters, k=5):
    clusters = sorted(clusters, key=lambda x: len(x), reverse=True)
    val_count = sum([len(c) for c in clusters])
    print('Total number of clusters is {} with {} values'.format(len(clusters), val_count))
    for i in range(min(k, len(clusters))):
        print('\nCluster {}'.format(i + 1))
        for key, cnt in clusters[i].items():
            if key == '':
                key = "''"
            print(f'  {key} (x {cnt})')
print_k_clusters(clusters)
'''
# Out:
# '\nfrom openclean.cluster.key import KeyCollision\nfrom openclean_geo.address.usstreet import USStreetNameKey\n\nstreet_names = ds_Update.update(\'Street Name\', str.upper).distinct(\'Street Name\')\nclusters = KeyCollision(func=USStreetNameKey(), threads=3).clusters(street_names)\n\ndef print_k_clusters(clusters, k=5):\n    clusters = sorted(clusters, key=lambda x: len(x), reverse=True)\n    val_count = sum([len(c) for c in clusters])\n    print(\'Total number of clusters is {} with {} values\'.format(len(clusters), val_count))\n    for i in range(min(k, len(clusters))):\n        print(\'\nCluster {}\'.format(i + 1))\n        for key, cnt in clusters[i].items():\n            if key == \'\':\n                key = "\'\'"\n            print(f\'  {key} (x {cnt})\')\nprint_k_clusters(clusters)\n'

# %%
# Standardize the "Street Name"
from openclean_geo.address.usstreet import StandardizeUSStreetName
ds_Update = ds_Update.update(columns="Street Name", func=StandardizeUSStreetName(characters='upper'))

# %%
# Fix "Community - Board" so the column has consistent format
def fixCommunityBoard(num):
  if len(num) == 1:
    try:
      if int(num) <= 5:
        return num + '--'
      else:
        return '---'
    except:
      return '---'
  elif len(num) == 3:
    try:
      if int(num) <= 5:
        return str(int(num)) + '--'
      elif int(num) < 100:
        return '---'
      return num
    except:
      return '---'
  return '---'

ds_Test = ds_Update.update(columns="Community - Board", func=fixCommunityBoard)

# %%
# There are some rows that use "X" for positive representation and empty for negative representation.
# We decided to standardize them to "Y" and "N" where "Y" for positive and "N" for negative.
def fixYN(x):
  if x == 'X' or x == 'Y':
    return 'Y'
  return 'N'
ds_Update = ds_Update\
  .update(columns="Adult Estab", func=fixYN)\
  .update(columns="Loft Board", func=fixYN)\
  .update(columns="PC Filed", func=fixYN)\
  .update(columns="Plumbing", func=fixYN)\
  .update(columns="Mechanical", func=fixYN)\
  .update(columns="Boiler", func=fixYN)\
  .update(columns="Fuel Burning", func=fixYN)\
  .update(columns="Fuel Storage", func=fixYN)\
  .update(columns="Standpipe", func=fixYN)\
  .update(columns="Sprinkler", func=fixYN)\
  .update(columns="Fire Alarm", func=fixYN)\
  .update(columns="Equipment", func=fixYN)\
  .update(columns="Fire Suppression", func=fixYN)\
  .update(columns="Curb Cut", func=fixYN)\
  .update(columns="Other", func=fixYN)

# The column "Cluster" has similar problem.
def insertN(x):
  if x not in ['Y', 'N']:
    return 'N'
  return x
ds_Update = ds_Update.update(columns="Cluster", func=insertN)

# %%
# As the previous result from profiling. We can see that there are uppercase and lowercase in the column "Applicant Professional Title"
# Thus, we will standarize them to uppercase
ds_Update = ds_Update.update('Applicant Professional Title', str.upper)

# %% [markdown]
# ## Fix characters
#
# There are some weird typo in the dataset. For example, in numeric values, what should be "0" is replaced by "O". We also want to deal with those problems.

# %%
# As we can see in "Lot", the maximum value 'OOO58' should actually be '00058' and '...28' should be '00028'.
profiles[6]
# Out:
# {'column': 'Lot',
#  'stats': {'totalValueCount': 1775898,
#   'emptyValueCount': 756,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'int': 1775138, 'str': 4}),
#                'distinct': Counter({'int': 1967, 'str': 4})}),
#   'minmaxValues': {'int': {'minimum': 0, 'maximum': 99917},
#    'str': {'minimum': '...28', 'maximum': 'OOO58'}},
#   'distinctValueCount': 1971,
#   'entropy': 6.5884201494392265,
#   'topValues': [('00001', 216517),
#    ('07501', 68592),
#    ('00029', 35314),
#    ('00033', 28077),
#    ('00005', 27864),
#    ('00021', 25912),
#    ('00014', 25428),
#    ('00020', 24894),
#    ('00023', 24827),
#    ('00010', 24573)]}}

# %%
# Fix the characters in "Block" and "Lot" that actually represent "0"
def fixNum(num):
  if num.isdigit():
    return num
  res = ""
  for c in num:
    if c.isdigit():
      res += c
    elif c in ['O', '.', '-']:
      res += '0'
  return res

ds_Update = ds_Update.update(columns="Block", func=fixNum)
ds_Update = ds_Update.update(columns="Lot", func=fixNum)

# %%
profiles_Update = ds_Update.profile(default_profiler=DefaultColumnProfiler)

# %%
profiles_Update[4]
# Out:
# {'column': 'Street Name',
#  'stats': {'totalValueCount': 517975,
#   'emptyValueCount': 0,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 516786, 'int': 522, 'date': 667}),
#                'distinct': Counter({'str': 11125, 'int': 45, 'date': 251})}),
#   'minmaxValues': {'str': {'minimum': ', MYRTLE AVE',
#     'maximum': '` WEST 61 ST'},
#    'int': {'minimum': 1, 'maximum': 271},
#    'date': {'minimum': datetime.datetime(100, 12, 11, 0, 0),
#     'maximum': datetime.datetime(2070, 12, 11, 0, 0)}},
#   'distinctValueCount': 11421,
#   'entropy': 10.907129629612166,
#   'topValues': [('BROADWAY', 8691),
#    ('5 AVE', 7611),
#    ('PARK AVE', 5892),
#    ('3 AVE', 4426),
#    ('WEST END AVE', 3392),
#    ('2 AVE', 3130),
#    ('MADISON AVE', 3095),
#    ('LEXINGTON AVE', 3003),
#    ('1 AVE', 2832),
#    ('RIVERSIDE DR', 2784)]}}

# %%
profiles_Update[35]
# Out:
# {'column': "Applicant's First Name",
#  'stats': {'totalValueCount': 517975,
#   'emptyValueCount': 0,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 517975}),
#                'distinct': Counter({'str': 5279})}),
#   'minmaxValues': {'str': {'minimum': 'A', 'maximum': 'leonid'}},
#   'distinctValueCount': 5279,
#   'entropy': 8.551922424344673,
#   'topValues': [('PAUL', 16982),
#    ('AKM', 14346),
#    ('MICHAEL', 12456),
#    ('JOHN', 12092),
#    ('JAMES', 10863),
#    ('ROBERT', 9900),
#    ('DANIEL', 9369),
#    ('DAVID', 8502),
#    ('JOSEPH', 8393),
#    ('NEAL', 7611)]}}

# %%
profiles_Update[36]
# Out:
# {'column': "Applicant's Last Name",
#  'stats': {'totalValueCount': 517975,
#   'emptyValueCount': 0,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 517973, 'int': 2}),
#                'distinct': Counter({'str': 11073, 'int': 2})}),
#   'minmaxValues': {'str': {'minimum': "'OSCANO", 'maximum': 'shamloo'},
#    'int': {'minimum': 21029677, 'maximum': 73020012}},
#   'distinctValueCount': 11075,
#   'entropy': 10.263904105090829,
#   'topValues': [('HOQUE', 14350),
#    ('BAILEY', 7119),
#    ('PETERSEN', 5771),
#    ('PARIHAR', 5742),
#    ('SYED-NAQVI', 5160),
#    ('LEE', 4472),
#    ('DUNZIK', 4320),
#    ('RUDIKOFF', 4029),
#    ('PHAGOO', 4002),
#    ('BAZINI', 3992)]}}

# %%
profiles_Update[37]
# Out:
# {'column': 'Applicant Professional Title',
#  'stats': {'totalValueCount': 517975,
#   'emptyValueCount': 0,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 517975}),
#                'distinct': Counter({'str': 12})}),
#   'minmaxValues': {'str': {'minimum': 'DEMO', 'maximum': 'YES'}},
#   'distinctValueCount': 12,
#   'entropy': 1.0379896626392748,
#   'topValues': [('PE', 268661),
#    ('RA', 246894),
#    ('OT', 2360),
#    ('LA', 27),
#    ('DEMO', 15),
#    ('SI', 6),
#    ('DEMO CONTRACTOR', 4),
#    ('OWNER', 3),
#    ('G.C', 2),
#    ('YES', 1)]}}

# %%
profiles_Update[44]
# Out:
# {'column': 'Approved',
#  'stats': {'totalValueCount': 517975,
#   'emptyValueCount': 180,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'date': 517795}),
#                'distinct': Counter({'date': 5845})}),
#   'minmaxValues': {'date': {'minimum': datetime.datetime(1992, 10, 21, 0, 0),
#     'maximum': datetime.datetime(2021, 12, 10, 0, 0)}},
#   'distinctValueCount': 5845,
#   'entropy': 11.779777089257928,
#   'topValues': [('06/26/2008', 351),
#    ('05/21/2015', 307),
#    ('12/03/2015', 306),
#    ('06/25/2008', 286),
#    ('06/28/2019', 285),
#    ('10/11/2017', 276),
#    ('09/27/2016', 271),
#    ('05/10/2017', 269),
#    ('06/27/2016', 267),
#    ('09/30/2016', 265)]}}

# %%
profiles_Update[45]
# Out:
# {'column': 'Fully Permitted',
#  'stats': {'totalValueCount': 517975,
#   'emptyValueCount': 0,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'date': 517975}),
#                'distinct': Counter({'date': 4941})}),
#   'minmaxValues': {'date': {'minimum': datetime.datetime(1994, 12, 7, 0, 0),
#     'maximum': datetime.datetime(2021, 12, 10, 0, 0)}},
#   'distinctValueCount': 4941,
#   'entropy': 11.72932337293512,
#   'topValues': [('11/12/2015', 327),
#    ('11/15/2016', 317),
#    ('05/17/2017', 292),
#    ('11/04/2015', 279),
#    ('05/27/2015', 274),
#    ('05/16/2017', 273),
#    ('08/21/2017', 271),
#    ('08/03/2017', 265),
#    ('11/23/2015', 263),
#    ('09/26/2017', 262)]}}

# %%
profiles_Update[59]
# Out:
# {'column': 'Existing Dwelling Units',
#  'stats': {'totalValueCount': 517975,
#   'emptyValueCount': 0,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'int': 517975}),
#                'distinct': Counter({'int': 1065})}),
#   'minmaxValues': {'int': {'minimum': 0, 'maximum': 52121}},
#   'distinctValueCount': 1065,
#   'entropy': 6.154918769227873,
#   'topValues': [('1', 85234),
#    ('2', 72558),
#    ('0', 31994),
#    ('3', 22065),
#    ('4', 16521),
#    ('6', 13615),
#    ('8', 12560),
#    ('20', 8007),
#    ('10', 7973),
#    ('5', 7885)]}}

# %%
profiles_Update[60]
# Out:
# {'column': 'Proposed Dwelling Units',
#  'stats': {'totalValueCount': 517975,
#   'emptyValueCount': 0,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'int': 517975}),
#                'distinct': Counter({'int': 1080})}),
#   'minmaxValues': {'int': {'minimum': 0, 'maximum': 52121}},
#   'distinctValueCount': 1080,
#   'entropy': 6.166488459568517,
#   'topValues': [('1', 81465),
#    ('2', 75301),
#    ('0', 30996),
#    ('3', 22743),
#    ('4', 16579),
#    ('6', 13745),
#    ('8', 12832),
#    ('5', 8067),
#    ('10', 8026),
#    ('20', 8019)]}}

# %%
profiles_Update[62]
# Out:
# {'column': 'Proposed Occupancy',
#  'stats': {'totalValueCount': 517975,
#   'emptyValueCount': 1604,
#   'datatypes': defaultdict(collections.Counter,
#               {'total': Counter({'str': 516371}),
#                'distinct': Counter({'str': 45})}),
#   'minmaxValues': {'str': {'minimum': '.RES', 'maximum': 'U'}},
#   'distinctValueCount': 45,
#   'entropy': 2.812582499990315,
#   'topValues': [('RES', 228525),
#    ('J-2', 56214),
#    ('R-3', 54824),
#    ('R-2', 49855),
#    ('COM', 45137),
#    ('J-3', 31608),
#    ('E', 8809),
#    ('PUB', 4991),
#    ('B', 4889),
#    ('R-1', 4842)]}}

# %% [markdown]
# # Correct misspelled city name
# In the "City " column, some cities' name are misspelled. Take BROOKLYN for example, some values maight be like BROKKLYN, BROOLKYN,...,etc. Therefore, we use soundex() to find the misspelled city names and correct them with the matching city name.

# %%
ds_Full.select('City ').distinct()
# Out:
# Counter({'': 1774895,
#          'NEW YORK': 273,
#          'BROOKLYN': 309,
#          'BKLYN': 14,
#          'ROOKLYN': 1,
#          'RICHMOND HILL': 4,
#          'BX': 1,
#          'NY': 37,
#          'BRONX': 32,
#          'STATEN ISLAND': 19,
#          'QUEENS': 56,
#          'OLD WESTBURY': 1,
#          'N.Y.': 8,
#          'ASTORIA': 2,
#          'HOLLIS': 7,
#          'MAHATTAN': 2,
#          'LAKE SUCCESS': 2,
#          'BROKKLYN': 2,
#          'BETHESDA': 1,
#          'JAMAICA': 6,
#          'Albany': 1,
#          'HOBOKEN': 1,
#          'SECAUCUS': 1,
#          'NEW ROCHELLE': 1,
#          'PORT WASHINGTON': 3,
#          'LIC': 18,
#          'MASPETH': 6,
#          'FLUSHING': 15,
#          'JAMAICA ESTATES': 2,
#          'SOUTH OZONE PAR': 2,
#          'BAYSIDE': 4,
#          'FOREST HILLS': 8,
#          'JAM': 1,
#          'PARMUS': 1,
#          'KEW GARDENS': 2,
#          'WOONSECKET': 1,
#          'MANHATTAN': 8,
#          'LI': 1,
#          'ST. ALBANS': 1,
#          'MASSAPEQUA': 1,
#          'SI': 2,
#          'HEMPSTEAD': 1,
#          'LOS ANGELES': 2,
#          'FLORAL PARK': 11,
#          'Brooklyn': 9,
#          'HILLSBOROUGH': 1,
#          'ROSLYN HEIGHTS': 1,
#          'BOSTON': 1,
#          'GREAT NECK': 5,
#          'New York': 18,
#          'RIDGEWOOD': 1,
#          'HOWARD BEACH': 1,
#          'GARDEN CITY': 5,
#          'WHITEPLAINS': 1,
#          'JACKSON HEIGHTS': 1,
#          'REGO PARK': 3,
#          'NEW HYDE PARK': 2,
#          'REGO': 1,
#          'WILLIAMSBURG': 1,
#          'ARVERNE': 1,
#          'OZONE PARK': 1,
#          'CORONA': 2,
#          'VALLEY STREAM': 1,
#          'New York City': 1,
#          'NEPONSIT': 4,
#          'NEW YORK CITY': 2,
#          'RIVERSIDE': 1,
#          'ROCKVILLE CENTR': 1,
#          'BRIARWOOD': 3,
#          'BRKLYN': 1,
#          'MOUNT LAUREL': 1,
#          'QUEEEN': 1,
#          'ELMSFORD': 1,
#          'NYC': 5,
#          'GILLFORD': 2,
#          'PARSIPPANY': 2,
#          'WOODSIDE': 4,
#          'LONG ISLAND CIT': 3,
#          'Astoria': 1,
#          'QUEEN': 2,
#          'VAALLEY STREAAM': 1,
#          'BRONS': 1,
#          'College Point': 1,
#          'ROCKAWAY POINT': 1,
#          'ELMHURST': 2,
#          'MORRISTOWN': 1,
#          'E. ELMHURST': 1,
#          'DOUGLASTON': 1,
#          'ENGLEWOOD CLIFF': 1,
#          'QNS': 1,
#          'LYNBROOK': 1,
#          'FORT LEE': 1,
#          'TARRYTOWN': 1,
#          'SYOSSET': 1,
#          'FRESH MEADOWS': 3,
#          'LAKEWOOD': 1,
#          'LITTLE NECK': 1,
#          'LOUISVILLE': 1,
#          'WOODHAVEN': 1,
#          'HARTSDALE': 1,
#          'ATLANTIC BEACH': 1,
#          'SAN JUAN CAPIST': 1,
#          'ROANOKE': 1,
#          'YONKERS': 2,
#          'WHITE PLAINS': 1,
#          'HUNTINGTON': 1,
#          'CALDE PLACE': 1,
#          'RIVERDALE': 1,
#          'TUCKAHOE': 1,
#          'KANSAS CITY': 1,
#          'SEAFORD': 1,
#          'L.I.C.': 2,
#          'REGO PK': 1,
#          'Queens': 1,
#          "B'KLYN": 2})

# %%
from openclean.function.eval.base import Col, Eval
from openclean.function.eval.logic import And
from openclean.function.value.phonetic import Soundex, soundex

brooklyn = ds_Full\
    .select('City ')\
    .update('City ', str.upper)\
    .filter(And(Eval('City ', Soundex()) == soundex('BROOKLYN'), Col('City ') != 'BROOKLYN'))\
    .distinct()

# %%
# Print (potential) misspellings in decreasing order of their
# frequency.

print('RANK\tCOUNT\tNAME')
for i, entry in enumerate(brooklyn.most_common()):
    key, count = entry
    print('{}.\t{}\t{}'.format(i + 1, count, key))
# Out:
# RANK	COUNT	NAME
# 1.	2	BROKKLYN
# 2.	1	BRKLYN

# %%
# Fix the name
def fixBrooklyn(name):
  if soundex(name)==soundex("BROOKLYN"):
    name="BROOKLYN"
  return name

ds_Update = ds_Update.update(columns="City ", func=fixBrooklyn)

# %%
brooklyn = ds_Update\
    .select('City ')\
    .update('City ', str.upper)\
    .filter(And(Eval('City ', Soundex()) == soundex('BROOKLYN'), Col('City ') != 'BROOKLYN'))\
    .distinct()

# %% [markdown]
# After correcting the city names, we can see that there are no more misspelled city names.

# %%
# Print (potential) misspellings of BROOKLYN in decreasing order of their
# frequency.

print('RANK\tCOUNT\tNAME')
for i, entry in enumerate(brooklyn.most_common()):
    key, count = entry
    print('{}.\t{}\t{}'.format(i + 1, count, key))
# Out:
# RANK	COUNT	NAME

# %% [markdown]
# And then we will do the same steps for other cities' names.

# %%
#Fix the name
def fixBronx(name):
  if soundex(name)==soundex("BRONX"):
    name="BRONX"
  return name

ds_Update = ds_Update.update(columns="City ", func=fixBronx)

# %%
bronx = ds_Update\
    .select('City ')\
    .update('City ', str.upper)\
    .filter(And(Eval('City ', Soundex()) == soundex('BRONX'), Col('City ') != 'BRONX'))\
    .distinct()

# %%
# Print (potential) misspellings of BRONX in decreasing order of their
# frequency.

print('RANK\tCOUNT\tNAME')
for i, entry in enumerate(bronx.most_common()):
    key, count = entry
    print('{}.\t{}\t{}'.format(i + 1, count, key))
# Out:
# RANK	COUNT	NAME

# %%
#Fix the name
def fixManhattan(name):
  if soundex(name)==soundex("MANHATTAN"):
    name="MANHATTAN"
  return name

ds_Update = ds_Update.update(columns="City ", func=fixManhattan)

# %%
manhattan = ds_Update\
    .select('City ')\
    .update('City ', str.upper)\
    .filter(And(Eval('City ', Soundex()) == soundex('MANHATTAN'), Col('City ') != 'MANHATTAN'))\
    .distinct()

# %%
# Print (potential) misspellings of MANHATTAN in decreasing order of their
# frequency.

print('RANK\tCOUNT\tNAME')
for i, entry in enumerate(manhattan.most_common()):
    key, count = entry
    print('{}.\t{}\t{}'.format(i + 1, count, key))
# Out:
# RANK	COUNT	NAME

# %% [markdown]
# And we can see that the cities' names are corrected.

# %%
ds_Update.select('City ').distinct()
# Out:
# Counter({'': 517924,
#          'NEW YORK': 12,
#          'BROOKLYN': 20,
#          'LIC': 6,
#          'PORT WASHINGTON': 1,
#          'BRONX': 1,
#          'RIDGEWOOD': 1,
#          'BKLYN': 1,
#          'NY': 5,
#          'L.I.C.': 2,
#          'N.Y.': 1,
#          'GREAT NECK': 1})
